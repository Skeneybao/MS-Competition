# %%
import os
import time

import pandas as pd
import numpy as np
import json
import matplotlib.pyplot as plt
import re
import matplotlib

from nltk.stem.snowball import SnowballStemmer
import nltk
import gensim
import spacy

import matplotlib.cm as cm

stemmer = SnowballStemmer("english")
nlp = spacy.load("en_core_web_sm")

# %%
from tool import *
# unique(x)
# find_kol(data,rank)
# unique_time(data)
# exforeign(data)
# duplicate(data)
# remove_link(data)
# remove_sign(data)
# total_clean(indata)
# toword(data,stem=False,stop=True)
# get_words(url), pos, neg, opinion
# debug2(sentence)
# month(start,end)
# search(data,keywords)
# LDA(data, topics, words,otherwords)
# NMF(data,topics,words,otherwords)

# %%
otherwords={'hi','wealthfront','betterment','robo','roboadvisor','roboadvisors',
            'wealthfronts','happy','im','vs','thanks','like','love','yet','yeah','via','want','one','a','an','advisor',
            'advisors','dont','didnt','financial','investment','wealth','finance'}

otherwords=otherwords.union(set(gensim.parsing.preprocessing.STOPWORDS))

# %%
m=month('2017-06','2020-05')
root_path=os.getcwd()
category=os.listdir(root_path+'\\SentiStrength\\final')
category
# Out:
# ['Bank Brokerage', 'Discount Brokerage', 'Full Brokerage', 'Robo Advisor']

# %%
def read_data(path):
    structure=list(os.walk(path))
    summary=[]
    for i in structure:
        if not i[1]:
            temp=[]
            for j in i[2]:
                #print(i[0]+'\\'+j)
                #temp.append([(x['text'],x['positive'],x['negative']) for x in anothertemp])
                if j=='TDAmeritrade2017-07.json': 
                    temp.append([])
                if j=='Wealthfront2017-08.json':
                    temp.append([])
                temp.append([{'text':x['text'],'positive':x['positive'],'negative':x['negative']} for x in json.load(open(i[0]+'\\'+j))[:-1]])
            summary.append(temp)
    #return summary
    def lsum(list_):
        result=[]
        num=len(list_[0])
        for i in range(num):
            temp=[]
            for j in list_:
                temp+=j[i]
            result.append(temp)
        return result
    return lsum(summary)

# %%
#list(os.walk(root_path+'\\SentiStrength\\final\\Bank Brokerage'))

# %%
metadata=[]
for i in category:
    metadata.append([])
    metadata[-1]=read_data(root_path+'\\SentiStrength\\final\\'+i)

# %%
for i in metadata:
    print(len(i))
# Out:
# 36
# 36
# 36
# 36

# %%
msdata=[]
temp=os.listdir(root_path+'\\MS_weekly')
for i in temp:
    msdata.append(total_clean(json.load(open(root_path+'\\MS_weekly\\'+i)))[:-1])

# %%
for i in msdata:
    print(len(i))
# Out:
# 4573
# 4964
# 4673
# 4889
# 4176
# 5006
# 5374
# 5126
# 3959
# 3996
# 3604
# 5129
# 4839
# 4095
# 3973
# 5671
# 4345
# 3860
# 3627
# 3467
# 3541
# 4300
# 3987
# 5316
# 3796
# 3263
# 3160
# 3563
# 3453
# 3429
# 3078
# 3414
# 3825
# 4729
# 4456
# 4504

# %%
def subanalyze(data,keywords): # data hierarchy: months*(text,score)*piece
    pospolarity=[]
    negpolarity=[]
    freq=[]
    for k in data:
        pos=0
        neg=0
        count=0
        for i in k:
            for j in keywords:
                if j in i['text'].lower():
                    pos+=i['positive']
                    neg+=i['negative']
                    count+=1
                    break
        pospolarity.append(pos/max(1,count))
        negpolarity.append(neg/max(1,count))
        freq.append(count)
    return pospolarity,negpolarity,freq

def double(data,keyword_list):
    app=subanalyze(data,keyword_list)
    matplotlib.rcParams['figure.dpi'] = 100
    fig, ax1 = plt.subplots()
    ax1.plot(np.array(m),app[0],color='C1')
    ax1.set_xticks(np.arange(36))
    ax1.set_xticklabels([i if x%3==0 else '' for x,i in enumerate(m)],rotation=45)
    ax1.set_ylabel('Positive')
    for t in ax1.xaxis.get_ticklines():
        t.set_visible(False)
    for t in ax1.xaxis.get_ticklines()[::2][::3]:
        t.set_visible(True)
    ax2 = ax1.twinx()
    for t in ax2.xaxis.get_ticklines():
        t.set_visible(False)
    for t in ax2.xaxis.get_ticklines()[::2][::3]:
        t.set_visible(True)
    ax2.set_xticks(np.arange(36))
    ax2.set_xticklabels([i if x%3==0 else '' for x,i in enumerate(m)],rotation=45)
    ax2.plot(m,app[1],color='C2')
    ax2.set_ylabel('Negative')
    ax1.set_title('Keywords: '+', '.join(keyword_list[:3]))
    plt.show()
    
def trend(data,hint,keyword_list): # hint=0 for pos, 1 for neg
    app=subanalyze(data,keyword_list)
    matplotlib.rcParams['figure.dpi'] = 100
    fig, ax1 = plt.subplots()
    ax1.plot(np.array(m),app[hint],color='C'+str(hint+1))
    ax1.set_xticks(np.arange(36))
    ax1.set_xticklabels([i if x%3==0 else '' for x,i in enumerate(m)],rotation=45)
    ax1.set_ylabel('Sentiment Polarity')
    for t in ax1.xaxis.get_ticklines():
        t.set_visible(False)
    for t in ax1.xaxis.get_ticklines()[::2][::3]:
        t.set_visible(True)
    ax2 = ax1.twinx()
    for t in ax2.xaxis.get_ticklines():
        t.set_visible(False)
    for t in ax2.xaxis.get_ticklines()[::2][::3]:
        t.set_visible(True)
    ax2.set_xticks(np.arange(36))
    ax2.set_xticklabels([i if x%3==0 else '' for x,i in enumerate(m)],rotation=45)
    ax2.bar(m,app[2],alpha=0.3)
    ax2.set_ylabel('Sentiment Frequency')
    ax1.set_title('Keywords: '+', '.join(keyword_list[:3]))
    plt.show()
    
def all_trend(data,hint,keyword_list):
    app=[subanalyze(i,keyword_list) for i in data]
    matplotlib.rcParams['figure.dpi'] = 200
    fig, ax = plt.subplots(2,2,sharex=True,sharey=True,figsize=(12,8))
    for i in range(2):
        for j in range(2):
            temp=2*i+j
            
            ax[i][j].plot(np.array(m),app[temp][hint],color='C'+str(hint+1))
            ax[i][j].set_xticks(np.arange(36))
            ax[i][j].set_xticklabels([i if x%3==0 else '' for x,i in enumerate(m)],rotation=45)
            if not j:
                ax[i][j].set_ylabel('Sentiment Polarity')
            for t in ax[i][j].xaxis.get_ticklines():
                t.set_visible(False)
            for t in ax[i][j].xaxis.get_ticklines()[::2][::3]:
                t.set_visible(True)
            ax2 = ax[i][j].twinx()
            for t in ax2.xaxis.get_ticklines():
                t.set_visible(False)
            for t in ax2.xaxis.get_ticklines()[::2][::3]:
                t.set_visible(True)
            ax2.set_xticks(np.arange(36))
            ax2.set_xticklabels([i if x%3==0 else '' for x,i in enumerate(m)],rotation=45)
            ax2.bar(m,app[temp][2],alpha=0.3)
            if j:
                ax2.set_ylabel('Sentiment Frequency')
            ax[i][j].set_title(category[temp])
    plt.suptitle('Keywords: '+', '.join(keyword_list[:3]))
    plt.show()

def show(entity,month,keyword):
    a,b=0,0
    result=[]
    for i in metadata[entity][month]:
        s=0
        for j in keyword:
            if j in i['text'].lower():
                s=1
        if s:
            #print(i,data[entity][month][1][x])
            result.append(i)
    return sorted(result,key=lambda x : x['text'])

def classify(monthdata):
    pos=[]
    neg=[]
    for i in monthdata:
        poscnt=0
        negcnt=0
        for k in i:
            if k['positive']>=-1.5*k['negative']:
                poscnt+=1
            elif -k['negative']>=1.5*k['positive']:
                negcnt+=1
        pos.append(poscnt/max(len(i),1))
        neg.append(negcnt/max(len(i),1))
    return pos,neg

# %% [markdown]
# ## MS

# %%
m=month('2017-06','2020-05')
m.index('2019-05')
# Out:
# 23

# %%
trend(msdata,0,[''])

# %%
trend(msdata,1,[''])

# %%
double(msdata,['']) # 1,4,5, 11(morgan stanley garden, justin rose), 23, -3

# %%
#temp=classify(msdata)
#plt.plot(temp[0],color='C1')
#plt.plot(temp[1],color='C2')

# %% [markdown]
# ### Word cloud

# %%
from wordcloud import WordCloud, STOPWORDS

def wordcloud(data):
    matplotlib.rcParams['figure.dpi'] = 100
    wordcloud = WordCloud(width = 500, height = 500, max_words=30,
                background_color ='white',
                stopwords = STOPWORDS.union({})).generate(' '.join([i['text'].lower() for i in data]))
    plt.axis('off')
    plt.imshow(wordcloud)

# %% [markdown]
# #### 1 (withdraw the U.S. from the 2015 Paris Agreement)

# %%
unique([(i['positive'],i['negative']) for i in msdata[0]])
# Out:
# [((1, -1), 2217, 48.48),
#  ((1, -2), 849, 18.57),
#  ((2, -1), 561, 12.27),
#  ((3, -1), 271, 5.93),
#  ((1, -3), 198, 4.33),
#  ((2, -2), 190, 4.15),
#  ((1, -4), 71, 1.55),
#  ((3, -2), 64, 1.4),
#  ((2, -3), 62, 1.36),
#  ((4, -1), 27, 0.59),
#  ((2, -4), 23, 0.5),
#  ((3, -3), 22, 0.48),
#  ((3, -4), 9, 0.2),
#  ((1, -5), 3, 0.07),
#  ((5, -1), 1, 0.02),
#  ((5, -4), 1, 0.02),
#  ((4, -4), 1, 0.02),
#  ((4, -3), 1, 0.02),
#  ((4, -2), 1, 0.02),
#  ((2, -5), 1, 0.02)]

# %%
unique([(i['positive'],i['negative']) for i in msdata[1]])
# Out:
# [((1, -1), 2229, 44.9),
#  ((1, -2), 995, 20.04),
#  ((2, -1), 621, 12.51),
#  ((1, -3), 337, 6.79),
#  ((2, -2), 213, 4.29),
#  ((3, -1), 204, 4.11),
#  ((1, -4), 113, 2.28),
#  ((2, -3), 85, 1.71),
#  ((3, -2), 57, 1.15),
#  ((2, -4), 35, 0.71),
#  ((3, -3), 26, 0.52),
#  ((3, -4), 15, 0.3),
#  ((4, -1), 14, 0.28),
#  ((4, -2), 6, 0.12),
#  ((1, -5), 5, 0.1),
#  ((5, -2), 2, 0.04),
#  ((5, -3), 2, 0.04),
#  ((2, -5), 1, 0.02),
#  ((5, -4), 1, 0.02),
#  ((5, -1), 1, 0.02),
#  ((4, -4), 1, 0.02),
#  ((4, -3), 1, 0.02)]

# %%
wordcloud([i for i in msdata[1] if i['positive']*i['negative']==-3])

# %%
#text(search(search(msdata[1],['trump']),['great']))
text(search(msdata[1],['trump']))
# Out:
# 212
# [' Like trump right',
#  ' Morgan Stanley says renewables are cheaper than oil gas by far Trump not a factor',
#  ' million illegal voters Trumps birther lie Obama wire tapped his phone ect ect',
#  ' of scientists think otherwise I trust science not Trump who says it is a Chinese hoax',
#  ' years Trump then comes Mike Pence',
#  'A picture of the Trump Trains pulling in how beautiful',
#  'Ahhh naaaah youre a bit paranoid there Michael Breathe let Trump lead us out of the fog of globalist propaganda',
#  'America First President Trump revitalizes the economy which was stagnant under Big Government Establishment Rule and Debet begins to fall',
#  'And HRC is not relevant as election is over Trump still has done nothing her or any else he promised to jail',
#  'And Trump is hell bent on diminishing women s empowerment in every way possible',
#  'And move it to Brussels lock stock and barrel and have Eric Trump redevelop that NYC site into affordable apts for his fathers supporters',
#  'And on the front of Saudis They have sourced most of the worlds terrorists directly or indirectly And Trump just gave them huge arms deal',
#  'Another Dtrump supporter who thinks a Strong Intelligent Black Man must be a Muslim or a terrorist God where do they get this stuff',
#  'Based on how much Trump golfs i would say no',
#  'Besides truth we want Earth to survive for many many centuries Trump is a chaotic destroyer by orientation Bannon is in control',
#  'Better Trump and the people than the thieving banks',
#  'Between Trump Clinton Trump was the only one who eloquently spoke about the plight of the inner cities Not even Obama did that',
#  'Boon to investments in wind and sun hopefully will continue We need keep public pressure on manufacturers IN SPITE OF TRUMPs KNUCKLE DRAG',
#  'Both sides are saying but but Obama when referring to positivenegatives are done by trump and also ',
#  'Britain will survive not the same as Trump situation as he may only last years',
#  'Britains sovereignty was not in question Youve shot yourselves in the foot just like we did by electing Trump',
#  'Bullshit Im glad he got out TRUMP ',
#  'But a few rich people can For everyone Hey I wanna be richim trying but not at everyone elses expense Trump is soulless myopic tit',
#  'But realDonaldTrump and his followers are too stupid to realize anything you said His withdrawal was all showbiz ',
#  'CNN JoyAnnReid FoxNews Trump a poor excuse a president He has lost our standing in the world in less then months USA laughing stock',
#  'Can we rename the massive glacier than recently broke off from after realDonaldTrump I think a global disaster needs a name',
#  'Cant stop the Trump train Its full steam ahead to Hop in or get out of the way its a straight shot to MAGA ',
#  'CelaineF I didnt give him permission to pull out of the global accords AMERICANS did you give Trump permission to pull out of the',
#  'CelaineF global accords KamalaHarris NAACP CBSNews ABC Isnt Trump supposed to be celebrating BASTILLE DAY EmmanuelMacron',
#  'Cheap wind and solar mean US will meet beat Paris targets despite Trump Morgan Stanley ',
#  'China is already way ahead of the US in alternative energy Trumps tarrifs against alternative energy businesses will hurt people ',
#  'Clapper said no evidence Brennan said no evidence The chick who met with jr has ties to Fusion GPS responsible for bs Trump dossier',
#  'Climate crap was just to get USA money Not a good deal Glad Pres Trump got us out',
#  'Clinton got more votes Trump had the smallest electoral victory in what years',
#  'Coal mining will eventually be a thing of the past Nothing Trump can do to bring these jobs back',
#  'Combat Climate Change ugggghhas anyone ever won against Mother Nature Prez Trump saved USA Trillion our contribution over Yrs',
#  'Comical its a leftist taxing scheme that will do little if anything to affect Clark mate change cheers for Trump ',
#  'Completely given money by the governmentif not they would completely lose A known fact Wake up losers Go Trump',
#  'Damn Go realDonaldTrump ',
#  'Dems dont put illegals on welfare Its the current policy U r spewing trump propoganda again',
#  'Dems r not rewriting healthcare I thot trump was doing that U know gop has maj in house so it shd be easy Y blame dems when its not them',
#  'Despite Trump withdrawing MorganStanley is bullish on US meeting its Paris commitments v ',
#  'Didnt mention Stop with the blame game Trump has been in office less then days Hes not the one that FUCKED Washington up',
#  'Divest from and boycott anything that has to do with Morgan Stanley Any friend of trump is enemy to the republic',
#  'Do not invest with Morgan Stanley Before last election they prohibited their employees from donating to Trump',
#  'Every single time When they cant defend Dtrump they attack Obama or Hillary Every Single One Every Single Time',
#  'Exactly Im beginning to feel like a third world country Cheney Trump selling out off natural resources who needs clean air water',
#  'Factually inaccurate US never ratified the agreement Unilateral action done by Obama undone by Trump',
#  'GOP Trump will destroy the economy',
#  'Giselle You say God is always on control I agree So God allowed Trump to win for some reason',
#  'Global business that Trump doesnt want USA to be a part of No one is going to buy Coal more countries are banning Oil based vehicles',
#  'Go Trump',
#  'Good move Go Trump',
#  'Good move Trump',
#  'Great list President Trump is truely a great man who is working for the American people It makes me sad to see how he is being treated',
#  'Great move Trump except he is still polluting',
#  'Ha ha ha ha and what is trump doing',
#  'Hahahahhajaj you are all so pathetic Really clueless in America Trump is the President USA We will lock up your DNC criminals',
#  'Hello trump and company is under FBI investigation news ',
#  'Hey Morgan Stanley Could You Please Explain Exactly What This Photo Represents All I See Is A Train HOPE ITS THE TRUMP TRAIN',
#  'History will judge mercilessly Trumps decision to pull out of climate agreement Greed cynicism triumph over leadership intelligence',
#  'Hmmm Who to believe a whole bunch of scientists or a trump groupie',
#  'I muted trump from my timeline thank god twitter I wish this would apply to ads too',
#  'I support President Trumps move OUT of the CLIMATE CHANGE BS',
#  'I think Morgan Stanley is comprised in their opinion They are taking the Corporate Globalist approach Trump is for the average American',
#  'I think the next President will be a Democrat so will Congress we will catch up in spite of Trump GOP We Will Save The Planet',
#  'I wish Twitter would quit inserting these automatic antiTrump ads after every proTrump tweet Big Brother in action',
#  'If Pres Trump pulls US out of the Climate Accords the US will not be wasting more money on these fear tactics from the left',
#  'If only Trump were so irrelevant regarding human rights democracy',
#  'If the other players were serious about climate change they would allow Trump back to negotiations Its all just one big ',
#  'If you dont want to start an argument dont accuse me of being a trumper Look at my timeline for one thing',
#  'In your opinion The ipcc was fraud and abiding by it is the stupidity Trump promised to cease',
#  'It was until Trump Trump is not an Oligarch trump isnt a part of the system He is what the people actually wanted',
#  'Its a Team Trump fake webbalan MorganStanley',
#  'Its all thanks to President Trump',
#  'Its ridiculous And stop with the whataboutism anyway Who is president now Who in WH Who is under investigation TRUMP Thats who',
#  'Just think if Trump said that hed be called a bully Of course we all know that the left are the real bullies',
#  'Know why EVERY DAMN TIME yall cant defend Dtrump you bring Hillary into the conversation Because you CANT DEFEND DTRUMP',
#  'Lets face it Trump doesnt give a shit about the environment look at who he appointed to EPA Energy etc',
#  'Lmao wait a minute Are you talking about Trump or Obama Because Trump thinks climate change is a hoax and a liberal conspiracy',
#  'Loan act lol what trump did is give up our leadership in the world Now invested know for years usa will not invest in infrastructure',
#  'Lol HRC is a career politician She didnt need to cheat Trump was a buffoon huffing and puffing I dont see any point yet',
#  'Lol u know nothing about it then if thats your response I mean I know trump told u that but try learning the truth and researching it',
#  'Morgan Stanley Cheap wind and solar mean US will meet beat Paris targets despite Trump ',
#  'Morgan Stanley calls realDonaldTrump an ignoramus liar in a promoted tweet Day of Trump Everyone is comfortable calling POTUS a liar',
#  'Morgan Stanley says renewables are becoming so cheap the US will meet Paris pledge despite Trump admin policies ',
#  'Morgan Stanley waited for Trump Jr to dump emails to sneak in the snap downgrade genius',
#  'Morgan We can only hope FAKETRUMP is standing on a sink hole that might awaken him as he slides down to yet another Trump TOWER ',
#  'Morgan stanley put the mor in morons come on trump alone should be worth a price target of PRICELESS',
#  'MorganStanley I am so happy that President Trump pulled us out of the climate accord it was a suckers game and we were the suckers',
#  'Most folk at Morgan Stanley ask them whether they voted for Trump ',
#  'My dog has more brains then all you trumpsters together',
#  'Nah lets just sit back let Mueller put him behind bars maybe wipe the Orange Clown clean too get the the people Trump ripped off',
#  'Name calling Typical for a trump follower or bot IF u have something valuable to say then im happy listen and discuss',
#  'No evidence on affects of EPA due to Trumps decisions investors should hold Corps accountable U should do an article on EPA failures',
#  'No global socialism under President Trumps watch ',
#  'No impact In theory Trump could have done nothing on Paris still rolled back environmental policies and suffered no real repercussions',
#  'No thats not why trump got elected he got elected bc he cheated lied used foreign nation win also paid off members of elect collge',
#  'Nope just think Trump is a lying sack of shit and definitely is not a Republican I am Polish Midwest Grad School Degree ',
#  'Not ratified by US congress Not US law Thank you President Trump',
#  'OBama illegally entered the U S into the Paris climate agreement Dont blame President Trump for OBamas unconstitutional move',
#  'Obama accomplished things made J Carter happy bc obama replaced him as worst pres ever and got Trump elected',
#  'Oh like Trump did',
#  'Oxymoron trump and climate change in same sentence without the word denier',
#  'POTUS realDonaldTrump Exit altogether the parent treaty which presumably would void US obligations to both agreements in one year',
#  'Past time to Dump realDonaldTrump',
#  'PfizerBoeingfordPepsiCoProctergambleMcDonaldsmondelez intGMJonsonjonsonCargillAlcoaGeneral ElektricTrump IntMorgan Stanley',
#  'Piece is horrible Blind to trump attacks on EPA his push for more fossil fuel exploitation attacks on fuel efficiencyMorganStanley',
#  'Pls cite what u mean by progress The propoganda from the trump camp Coal mining and fracking are not progress',
#  'President Trump by pulling out of Climate Change saved millions of good jobs making us energy independent and trillions of dollars MAGA',
#  'President Trump is trying to stop the prostitution of the American people Wake up',
#  'Quick question how does a trump supporter support LBGTQ community Have you read the Republican Party platform',
#  'Red hat trumpist supporter needs more Tinfoil',
#  'Renewable energy is becoming so cheap the US will meet Paris commitments even if Trump withdraws Morgan Stanley research forecasts renewabl',
#  'Republicans hated that pile of Muslim OBAMA But we delt with it for yrs Now it is your turn America voted Trump won quit your crying',
#  'Shut up MorganStanley Your hate for trump is evident',
#  'Sing that song to Trump',
#  'So there you go Trump won fair and square And say you',
#  'Somebody might want to tell the trump admin',
#  'Something I actually agree with Trump on',
#  'Soon realDonaldTrump ',
#  'Stay tune for the ongoing battle of FACTS vs TRUMPISM Our democracy lies in the balance Fin',
#  'TRUMPISM has a very boisterous showing of alternate reality following Will FACTS REALITY be enough to stave of the rampant stupidity ',
#  'Thank God Trump in undoing all of Obamas damage Trump is the only reason American will still here in the future',
#  'Thank God for POTUS Trump pulling us out of such a terrible deal of pure NONSENSEWe should care our earthbut this was a bum deal U S',
#  'Thank God for President Trump He keeps his promises Go Trump',
#  'Thank God for Trump',
#  'Thank you President Trump',
#  'Thank you really informative article Has CEO of Morgan Stanley shared with Trump Convert to graphs so he can understand',
#  'Thanks Trump There is no proof climate change even exists Climate change a big scam to control you',
#  'That is so evident by the crowds that gather to hear him speak in other countries Contrast with protests for Trump',
#  'Thats why Trump could get us out by himself It was never ratified therefore was an accord not a treaty',
#  'The biggest impact is that Trump has turnef the USA into a rogue state along side North Korea and Iran',
#  'The climate change is really world government control thank goodness Trump is trying to fix Obama messobama gave un to much power over usa',
#  'The impact will be that every American will have more money in their pockets Trump and America WIN again ',
#  'The planet will just become uninhabitable faster under Trump and the GOP Both Parties suck bankers dicks the GOP just sucks a bit harder',
#  'The real impact of MorganStanley not knowing the truth of climate change on our living breathing planet and blaming President Trump GOD ',
#  'The real impact of President Trumps move to pull the US out of the global accords to combat climate change ',
#  'The two times weve tried laissez faire economics they have been miserable failures So what does realDonaldTrump want to do Try it AGAIN',
#  'The world moves on and leaves the Trump White House behind',
#  'This basically says that TRUMPREPs backasswards stance on climate change will do little stop progress by realistic forward thinkin folks',
#  'This didnt go wellbankers win with this accord not me and my familythank God for Pres Trump realDonaldTrump POTUS',
#  'This is my country land that I love I pledge thee my allegiance America the great Someone pls sing that son to Trump he is trashing us',
#  'This is not due to trump Do u know when and how a job is created',
#  'This is why Trump won why you all cant win any elections Good luck w that Traitor strategylets see how many votes u get w that',
#  'Trump GOP will destroy the economy',
#  'Trump GOP will destroy the environment',
#  'Trump also spoke to a congregation in a Black church in Detroit He won the support of Roy Innissr jr the leaders of CORE',
#  'Trump creates wounds in snowflakes causing mental anguishand its kind of fun to watch',
#  'Trump did the right thing',
#  'Trump has cut funding to the arts PP EPA NPR parks etc He has made weapons deals with Saudis who r known to back most terrorist grps',
#  'Trump is affiliated with Rothschild Rockefeller Big Phama Merck Pfizer Henry Kravis KKR Morgan Stanley UXT Chase etc ALL HUGE CORP ',
#  'Trump is exactly what the Dr ordered Hes a gift from God to save our country from a cesspool of failing socialist policies',
#  'Trump is limitedthat brand stinks',
#  'Trump is nuts GOP will destroy the economy',
#  'Trump is right No president should run International welfare American tax money cant solve China India pollution Not working',
#  'Trump is showing the world what a true world leader is USA bows to nobody at G Trump was only leader that supports only his country',
#  'Trump is wise Nothing to be gained in this big lie and billions of literally thrown away One of the major accomplishments thus far',
#  'Trump isnt really much of a Republican Hes better',
#  'Trump knows business which is far greater than BS economics',
#  'Trump once again has nominated a nonscientist to direct this issue Trump intends to get what he wants what then shut down the dept',
#  'Trump pulled out of Paris Accord benefits Russia Saudi Arabia countries whos economy is based strictly Oil Producing Putins pawn',
#  'Trump still doesnt beleive in climate change He is so ignorant',
#  'Trump was right There r better ways to address this problem vs throwing billions of US and pretend its helping Find real solutions ',
#  'Trump will make our country great again if only the Dems with step back and get outoftheway',
#  'Trumps decision to withdraw from Paris Accord just server Russian interest Plain simple',
#  'Trumps not running this show like the Republicans want though is he',
#  'US doesnt need to give billions to other countries Each should help their own country on climate change Trump is right',
#  'Unemployed Lol No where to go He was a kind man who loves his family Not sure what that is trump feels ',
#  'Ur just stating nothing discuss It was proven thru fact checking that HRC has lied less than any and trump has lied more than any',
#  'Very little changes except President Trump saves US taxpayers Trillion over this century Awopbopaloobopawopbamboom',
#  'Very revealing about the mindset of the majority of trumpettes Its the same mindset as the disgruntled disenchanted Brexit demographic',
#  'WELCOME To FACTS VS TRUMPISM TOURNAMENT facts is facing strong push back from conspiraciesPropaganda pull it out your ass opinions ',
#  'We are a consumer nation but I am buying nothing but food till trump is out of office',
#  'We can do our part without joining a onesided club Thanks Trump for foregoing the accord',
#  'We spend more than the next countries Who are you kidding Defend us from what Russian hacking Trump stupidity',
#  'We stand with President Trump',
#  'We will have plenary of money for infrastructure now that we are not waisting our money and bringing business home like factorys Trump ',
#  'Whats trump doing right now',
#  'When they cant defend Dtrump they bring up and attack Obama It Never Fails',
#  'Who cares Mr Trump as an old ally why did Morgan Stanley give us the fingers up and move to Germany putting s out of work ',
#  'Why do these Dumbster Trumpsters make up so many fake facts but scream about fake news that often isnt',
#  'Why dont you jump for trump',
#  'Why post all these I hate Trump but does this help Reminds me of WH posting election commission comments private info Antiintegrity',
#  'Wildfires droughts rising seas floodsTrump policy bad for cities farms forests food jobs usaforyoubruv MorganStanley POTUS',
#  'Without congressional approval we were never really in the Paris Accord realDonaldTrump was able to nullify Obamas signature w his pen',
#  'Wow You will support trump facts be damed OK Ok trump is soo compassionate He loves both daighters he is for the little guy lol',
#  'Yeah I am not paying to breathe Go Trump No more global warming hoax',
#  'Yeah he did all that I guess thats why hes more respected than Trump around the world and in the US',
#  'Yes Thank you Trump pretending to be savvy businessman when clearly he is not Hes bad for the people economy environment ',
#  'Yes remember when Trump bow before the leaders of Saudi Arabia Oh LOL nevermind it was Obama the great cuckold',
#  'You are talking about Obama arent youThat is exactly what he did and why we are in the position we are in today realDonaldTrump',
#  'You both are proving my point that politicians are liars ALL of them One of the main reasons Trump got elected',
#  'You do trumps trying to start a war with anybody he can He has stock in military arsenal',
#  'You dont read people very well Watch trump with his robots I mean kids compared to Michelle and kids Genuine love',
#  'You know Beachgal youre starting to bore me You dont add to any conversation life is too damn short to have to put up wa Dtrump fan',
#  'You think Trump is a Christian with his secret favorite Bible verse and eating the little cracker and the way he respects women ',
#  'Your the problem Not Trump International Bankers are going down soon',
#  'absolutelyImy beauty margbrennan discussedthere is no facts in WH Trump statement reagrding climate changefind opportunity in climate',
#  'algore MorganStanley Can make if they convince you they can the realDonaldTrump ',
#  'allidoisowen has become popular compiling this authoritarian list on Trump Ironically she used to be a principal at Morgan Stanley',
#  'expanded security and useless wars trump will escalate',
#  'foxnation realDonaldTrump we dont want world using us as their ATM ',
#  'great move by president Trump',
#  'i for one am so glad President Trump left the Paris Agreement',
#  'if you donate money to Trumps campaign it will be used to pay his sons legal fees you good with that',
#  'rereleases puff piece that ignores impact of Trump regimes denialism',
#  'so thankful Trump got us out of this bad climate deal America st ',
#  'tRump is so pitifulI think he cheated on ECnumbers were weird at end',
#  'trump is in Poland telling Lie after Lie after Lie',
#  'u hv failed see the bigger picture Trump abdicated USA status as a global leaderteam player just weakened entire USA',
#  'you mean Trump pulling out from Obamas globalist wealth distribution plan under the guise of climate control ']

# %% [markdown]
# #### 5

# %%
wordcloud([i for i in msdata[5] if i['positive']==1 and i['negative']==-2])

# %% [markdown]
# #### 11 (Fort Worth Invitational)

# %%
wordcloud([i for i in msdata[11] if i['positive']==3 and i['negative']==-1])

# %% [markdown]
# #### 15 (Those finishes moved Rose to World Number One in the Official World Golf Ranking)

# %%
unique([(i['positive'],i['negative']) for i in msdata[14]])
# Out:
# [((1, -1), 1743, 43.87),
#  ((1, -2), 644, 16.21),
#  ((2, -1), 563, 14.17),
#  ((2, -2), 265, 6.67),
#  ((3, -1), 244, 6.14),
#  ((1, -3), 173, 4.35),
#  ((3, -2), 104, 2.62),
#  ((2, -3), 81, 2.04),
#  ((1, -4), 48, 1.21),
#  ((3, -3), 31, 0.78),
#  ((4, -1), 23, 0.58),
#  ((2, -4), 23, 0.58),
#  ((3, -4), 21, 0.53),
#  ((4, -2), 3, 0.08),
#  ((2, -5), 3, 0.08),
#  ((4, -3), 2, 0.05),
#  ((3, -5), 1, 0.03),
#  ((5, -1), 1, 0.03)]

# %%
unique([(i['positive'],i['negative']) for i in msdata[15]])
# Out:
# [((1, -1), 2278, 40.17),
#  ((3, -1), 976, 17.21),
#  ((2, -1), 763, 13.45),
#  ((1, -2), 711, 12.54),
#  ((2, -2), 242, 4.27),
#  ((1, -3), 203, 3.58),
#  ((3, -2), 150, 2.65),
#  ((2, -3), 106, 1.87),
#  ((4, -1), 65, 1.15),
#  ((1, -4), 52, 0.92),
#  ((3, -3), 51, 0.9),
#  ((2, -4), 26, 0.46),
#  ((4, -2), 21, 0.37),
#  ((3, -4), 16, 0.28),
#  ((4, -3), 4, 0.07),
#  ((1, -5), 3, 0.05),
#  ((5, -1), 2, 0.04),
#  ((4, -4), 1, 0.02),
#  ((5, -2), 1, 0.02)]

# %%
print(11,m[11])
print(15,m[15])
# Out:
# 11 2018-05
# 15 2018-09

# %%
wordcloud([i for i in msdata[15] if i['positive']==3 and i['negative']==-1])

# %% [markdown]
# #### 24 2019-06

# %%
unique([(i['positive'],i['negative']) for i in msdata[25]])
# Out:
# [((1, -1), 1359, 41.65),
#  ((1, -2), 589, 18.05),
#  ((2, -1), 421, 12.9),
#  ((3, -1), 211, 6.47),
#  ((2, -2), 208, 6.37),
#  ((1, -3), 201, 6.16),
#  ((3, -2), 87, 2.67),
#  ((2, -3), 74, 2.27),
#  ((1, -4), 35, 1.07),
#  ((3, -3), 29, 0.89),
#  ((2, -4), 18, 0.55),
#  ((4, -1), 16, 0.49),
#  ((3, -4), 7, 0.21),
#  ((4, -2), 5, 0.15),
#  ((4, -3), 2, 0.06),
#  ((1, -5), 1, 0.03)]

# %%
unique([(i['positive'],i['negative']) for i in msdata[24]+msdata[23]])
# Out:
# [((1, -1), 3032, 33.27),
#  ((1, -2), 1636, 17.95),
#  ((2, -1), 1186, 13.02),
#  ((1, -3), 919, 10.09),
#  ((3, -1), 684, 7.51),
#  ((2, -2), 617, 6.77),
#  ((2, -3), 291, 3.19),
#  ((3, -2), 237, 2.6),
#  ((1, -4), 163, 1.79),
#  ((4, -1), 84, 0.92),
#  ((3, -3), 84, 0.92),
#  ((2, -4), 78, 0.86),
#  ((3, -4), 48, 0.53),
#  ((4, -2), 19, 0.21),
#  ((1, -5), 13, 0.14),
#  ((4, -3), 9, 0.1),
#  ((4, -4), 4, 0.04),
#  ((2, -5), 3, 0.03),
#  ((5, -2), 2, 0.02),
#  ((5, -1), 2, 0.02),
#  ((3, -5), 1, 0.01)]

# %%
wordcloud([i for i in msdata[24] if i['positive']==1 and i['negative']==-3])

# %% [markdown]
# #### 33 2020-03

# %%
wordcloud([i for i in msdata[33] if i['positive']==1 and i['negative']==-2])

# %% [markdown]
# ### broker protocol

# %%
protocol=[search(search(i,['protocol']),['broker']) for i in msdata][4:11]
for i in protocol:
    print(len(i))
# Out:
# 22
# 61
# 8
# 4
# 3
# 4
# 2

# %%
text(protocol[0])
# Out:
# 22
# [' leaving the Protocol for Broker Recruiting',
#  'BREAKING Morgan Stanley dumps broker recruiting protocol newsfromIN BDNEWSGUY',
#  'Brian Hamburger JD CRPC MarketCounsel leads with the recent news of MorganStanley dumping broker recruiting protocol ',
#  'Broker protocol exit by morganstanley due to loss Let the begin AndrewWelsch great article',
#  'California Securities Lawyers Morgan Stanley Ditches the Broker Protocol ',
#  'Did MorganStanley just kill the broker protocol agreement by JeffBenjamin',
#  'Lawsuits by BDs for TRO breach of restrictive covenants to come Morgan Stanley dumps broker recruiting protocol ',
#  'Morgan Stanley Withdrawing from the Protocol for Broker Recruiting Read more on our Transitions in Employment blog ',
#  'Morgan Stanley dumps broker recruiting protocol ',
#  'Morgan Stanley dumps broker recruiting protocol via newsfromIN',
#  'Morgan Stanley exits Broker Protocol Huge news in the financial services recruiting world',
#  'Morgan Stanley exits Broker Protocol will others follow ',
#  'Morgan Stanley to exit Protocol for Broker Nov paving path for more Story at FundFire ',
#  'Morgan Stanley will exit the protocol for broker recruiting via WSJ',
#  'Morgan Stanley withdraws from the protocol screwing their current brokers Sucks to be at a wirehouse Your business is worthless to you',
#  'Morgan Stanleys Broker Protocol withdrawal unleashes chaos in RIA legal and recruiting circles ',
#  'Morgan Stanleys exit from the Broker Protocol begs the question Will anyone follow next via onwallstreet',
#  'MorganStanley broker protocol split could quickly spread across brokerage industry says MarketCounsels Brian Hamburger HDelux ',
#  'Questions Abound After Morgan Stanley Leaves Broker Protocol ',
#  'RT MikeThrasher Morgan Stanley is leaving the Protocol for Broker Recruiting if you didnt hear about this already ',
#  'WOA Red Alert wirehouse brokers This is a dangerous precedent Morgan Stanley to Pull Out of Broker Protocol ',
#  'What Morgan Stanleys Broker Protocol Exit Means for Advisors ']

# %%
text(protocol[1])
# Out:
# 61
# [' files first TRO postwithdrawal from Broker Protocol Rumored won',
#  ' takeaways from exiting Broker Protocol new solicitation strategies will need to be used whos next Merrill',
#  'Ahead of Broker Protocol exit M Morgan Stanley team jumps to Baird ',
#  'Another Firm Follows UBS and Morgan Stanley Out of the Broker Protocol Are you among these firms and has it affected you ',
#  'As Morgan Stanley exits the Broker Protocol Alan Foxman reminds advisors to check their employment contracts',
#  'As Morgan Stanley exits the Broker Protocol Alan Foxman reminds advisors to check their employment contracts ',
#  'BD Advisor Valuations To Compress As Morgan Stanley Withdrawal Unravels The Broker Protocol other Weekend Reading for Financial Planners Nov ',
#  'BDNewsGuy continues to dig into the UBS decision to exit the broker recruiting protocol finds this move and Morgan Stanleys show independent channel is bleeding wirehouses of advisers via newsfromIN',
#  'BREAKING NEWS UBS Follows Morgan Stanley Out of Broker Protocol ',
#  'BREAKING UBS exits protocol for broker recruiting following Morgan Stanleys lead BDNEWSGUY newsfromIN',
#  'Broker Protocol Administrator Delayed Public Notice of Morgan Stanleys Exit ',
#  'Broker Protocol Administrator Delayed Public Notice of Morgan Stanleys Exit wealthmgmt ',
#  'Broker Protocol Administrator Delayed Public Notice of Morgan StanleysExit ',
#  'Broker Protocol Administrator Questioned as Morgan Stanley Exits ',
#  'By Rejecting the Broker Protocol Morgan Stanley is Building a Wall ',
#  'CEO mattsonnenpfi discusses Morgan Stanleys exit from Broker Protocol with FAmagazine ',
#  'Did Morgan Stanley just kill the broker protocol agreement ',
#  'Doesnt sound like a clientcentric business practice Rejecting the Broker Protocol Morgan Stanley Builds a Wall ',
#  'DynastyFP CEO Shirl Penney talked at about how Morgan Stanley leaving the broker protocol will affect small RIAs ',
#  'Excellent perspective from PFIadvisors on Morgan Stanley leaving the broker Protocol ',
#  'Exclusive UBS exits Broker Protocol following Morgan Stanleys lead via onwallstreet',
#  'Good GregIacurci discussion of some of the games that competing brokerage firms were playing with the Protocol Though ultimately this was just an excuse to leave not the cause Morgan Stanleys broker protocol exit How did we get here ',
#  'Good read from ReformedBroker DynastyFP on Morgan Stanley leaving the Broker Protocol Jump Now or Boil Slowly ',
#  'Hence Morgan Stanleys withdrawal from the Broker Protocol The asset slippage is becoming meaningful',
#  'Horrific example of what happens without the Broker Protocol Morgan Stanley hit him w TRO a k lawsuiit for doing nothing more than taking his client names basic contact info His new firm then fired him bc he couldnt bring his clients anymore Livelihood destroyed ',
#  'How UBS exited the Broker Protocol and why the aftereffects may surpass those of Morgan Stanleys earlier departure ',
#  'I shared my thoughts on Morgan Stanleys exit from the Broker Protocol with dvjamieson FAmagazine',
#  'In the Newsroom video rhordt BDNEWSGUY discuss Morgan Stanleys rationale for exiting the broker protocol ',
#  'In the latest at the Fountain of Wealth our COO CrossingSTLine discusses the fiduciary model and the impact that will be felt across the industry as a consequence of Morgan Stanleys withdrawal from The Protocol for Broker Recruiting ',
#  'Is MorganStanley starting a movement of firms abandoning the Protocol for Broker Recruiting',
#  'Morgan Stanley Brokers Jump Early Under Protocol Pressure ',
#  'Morgan Stanley Brokers Jump to Regionals Under Protocol Pressure ',
#  'Morgan Stanley Ties Hands of Broker Who Jumped After Protocol ExitSources via advisorhubinc',
#  'Morgan Stanley advisers feel burned by broker protocol exit ',
#  'Morgan Stanley advisers feel burned by broker protocol exit Excellent reporting here by BDNEWSGUY ',
#  'Morgan Stanley advisers feel burned by broker protocol exit via newsfromIN',
#  'Morgan Stanley joins Schwab treating employees as indentured servants Exits from Broker Protocol ',
#  'Morgan Stanley lost advisors managing about B in Broker Protocol exodus by YueqiYang',
#  'Morgan Stanley nixes protocol pact blocking brokers exits ',
#  'Morgan Stanley nixes protocol pact blocking brokers exits via nypost',
#  'Morgan Stanleys Exit from Broker Protocol is Stern Warning to BrokerDealers Competition ',
#  'Morgan Stanleys Withdrawal from the Broker Protocol Shocks the Industry via KTSLaw',
#  'Morgan Stanleys broker protocol exit How did we get here ',
#  'Morgan Stanleys broker protocol exit How did we get here Great piece by GregIacurci ',
#  'MorganStanley recruiting is effectively over after leaving Broker Protocol says Elzweig recruiter ',
#  'MorganStanley recruiting is effectively over now that the firm is leaving the Broker Protocol says Elzweig executive recruiter by Elzweig',
#  'My latest Morgan Stanleys broker protocol exit How did we get here newsfromIN',
#  'One month after Morgan Stanley said it was leaving the Protocol for Broker Recruiting UBS says it will too ',
#  'Open season on financial advisors leaving brokerage firms More financial advisors face litigation risk as UBS joins Morgan Stanley in pulling out of broker recruiting protocol via WSJ',
#  'Our corporate response to Morgan Stanley exiting broker protocol ',
#  'Our take on Broker Protocol Savvy RIAs should take advantage of opportunity presented to them by Morgan Stanley ',
#  'Questions Abound After Morgan Stanley Leaves BrokerProtocol ',
#  'Schwab execs sound off on Bitcoin HSAs and Morgan Stanley exit from broker protocol ',
#  'Scoop from late last night Broker Protocol Administrator Delayed Public Notice of Morgan Stanleys Exit ',
#  'TRENDING Schwab execs sound off on HSAs Bitcoin and Morgan Stanley exit from broker protocol ',
#  'UBS exits Broker Protocol following Morgan Stanleys lead ',
#  'Wealth managers in shackles Morgan Stanley nixes protocol pact blocking brokers exits via nypost via mgray',
#  'What does Morgan Stanley leaving the Recruiting Protocol mean for your business brokerdefender Explains ',
#  'Whats Morgan Stanleys rationale for exiting the Broker Protocol Join BDNEWSGUY rhordt for First Look Video ',
#  'Why stay with a wirehouseGo independent Questions Abound After Morgan Stanley Leaves Broker Protocol ',
#  'Will More Firms Leave Broker ProtocolAfter Morgan Stanleys exit the recruiting scene could shift in a variety of ways says one industry watcher ']

# %%
text(protocol[2])
# Out:
# 8
# ['As effects from the broker protocol continue to take shape execs formerly of Morgan Stanley Smith Barney find success recruiting teams from their old firms via newsfromIN',
#  'BREAKING Merrill Lynch to remain in the broker protocol contrary to rivals UBS and Morgan Stanley BDNEWSGUY',
#  'Merrill Lynch wont follow Morgan Stanley UBS out of broker protocol via BarronsOnline',
#  'MerrillLynch to Stay in Broker Protocol Wells Fargo on FenceOne recruiter wonders why the BofA wealth unit is staying in the recruiting deal while Morgan Stanley and UBS have left ',
#  'Morgan Stanley broker leaves with only Protocol client information Morgan Stanley hits the broker with a restraining order because its not in the Protocol For those who didnt believe Morgan Stanley would be aggressive against their former brokers ',
#  'Morgan Stanley will boost savings with brokerprotocol exit UBS analysts say ',
#  'The postBroker Protocol exodus continues RaymondJames nabs million producer from Morgan Stanley ',
#  'UBS Exits Broker Protocol Following Morgan Stanleys Lead other Weekend Reading for Financial Planners Dec ']

# %%
text(protocol[3])
# Out:
# 4
# ['Broker Protocol Gets New AdministratorThe news comes about three months after questions were raised over law firms handling of Morgan Stanley information ',
#  'Broker had just M of AUM Morgan Stanley has trillions Appears MS was sending another postProtocol warning to the rest of their brokers Another Former Morgan Stanley Broker Loses New Job After TRO via AdvisorHubINC',
#  'Lost brokers in Q biggest quarterly loss of the year But its still only of their k brokers Breakaways are a trickle not a flood Morgan Stanley reports a loss of advisers after exiting the protocol for broker recruiting via ',
#  'Morgan Stanley continues to take a whack at departing brokers now that it left the Broker Protocol But this time the court denied the TRO and sided with the departing broker In Texas even Morgan Stanley Brokers Jump to Ameriprise Win in Court ']

# %%
protocol=[search(i,['protocol']) for i in msdata]
for i in protocol:
    print(len(i))
# Out:
# 0
# 0
# 2
# 0
# 25
# 81
# 12
# 6
# 4
# 5
# 6
# 1
# 0
# 2
# 2
# 2
# 2
# 2
# 0
# 0
# 0
# 0
# 1
# 0
# 0
# 1
# 0
# 1
# 0
# 0
# 0
# 1
# 0
# 0
# 1
# 0
