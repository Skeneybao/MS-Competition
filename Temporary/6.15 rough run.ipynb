# %%
import pandas as pd
import numpy as np
import json
import matplotlib.pyplot as plt
import re
import matplotlib

from nltk.stem.snowball import SnowballStemmer
import nltk
import gensim
import spacy

import matplotlib.cm as cm

stemmer = SnowballStemmer("english")
nlp = spacy.load("en_core_web_sm")

# %% [markdown]
# ### Data Cleaning Functions

# %%
def unique(x):
    d={}
    for i in x:
        d[i]=d.get(i,0)+1
    return sorted(d.items(),key=lambda x: -x[1])

def find_kol(data,rank):
    user=[]
    for i in data:
        user.append(i['user_id'])
    user_d={}
    for i in user:
        user_d[i]=user_d.get(i,0)+1
    user_frequency=unique(user)
    kol_id=[i[0] for i in user_frequency[:rank]]
    kol_name=[]
    for j in kol_id:
        for i in data:
            if i['user_id']==j:
                kol_name.append(i['username'])
                break
    return kol_name

def unique_time(data):
    time=[]
    for i in data:
        time.append(i['timestamp'][:10])
    return sorted(unique(time),key=lambda x: x[0])

def exforeign(data):
    eng_data=[]
    for i in data:
        pos=i['text_html'].find('>')
        if 'lang="en"' in i['text_html'][:pos]:
            eng_data.append(i)
    return eng_data

def duplicate(data):
    result=[]
    text=[]
    for i in data:
        if i['text'] not in text:
            result.append(i)
            text.append(i['text'])
    return result

def remove_link(data):
    for x,i in enumerate(data):
        if '/' in i['text']:
            result = re.sub(r"(https|http)\S+", "", i['text'])
            #result=re.sub(r'(https|http)?:\/(\w|\.|\/|\?|\=|\&|\%)*\b','',i['text'])
            result = re.sub(r"\S+.com\S+", "", result)
            data[x]['text']=result
    return data

def remove_sign(data):
    for x,i in enumerate(data):
        # hash tag
        result=re.sub(r'#\S+', '', i['text'])
        # user mention
        #result=re.sub(r'#\S+', '', result)
        # emoji
        result=re.sub(r'[^\x00-\x7F]+', '', result)
        # html tags
        result=re.sub(r'<.*?>', '', result)
        # punctuation
        from string import punctuation as punc
        result=re.sub('[{}]'.format(punc), '', result)
        # extra spaces
        result=re.sub(r'\s+', ' ', result)
        data[x]['text']=result
    return data

def total_clean(indata):
    data=exforeign(indata)
    data=duplicate(data)
    data=remove_link(data)
    data=remove_sign(data)
    return data
        
def toword(data,stem=False,stop=True):
    result=[]
    t=nltk.tokenize.TweetTokenizer(strip_handles=True, reduce_len=True)
    f=(stemmer.stem) if (stem) else (lambda x: x)
    STOPWORDS= gensim.parsing.preprocessing.STOPWORDS if stop else set()
    for x,i in enumerate(data):
        temp=[f(j).lower() for j in t.tokenize(i['text'])\
              if j.isalnum() and (f(j).lower() not in STOPWORDS)]
        result.append(temp)
    return result#stemmer.stem(j)

# %% [markdown]
# ### Sentiment Words Lexicon

# %%
def get_words(url):
    import requests
    words = requests.get(url).content.decode('latin-1')
    word_list = words.split('\n')
    index = 0
    while index < len(word_list):
        word = word_list[index]
        if ';' in word or not word:
            word_list.pop(index)
        else:
            index+=1
    return word_list
p_url = 'http://ptrckprry.com/course/ssd/data/positive-words.txt'
n_url = 'http://ptrckprry.com/course/ssd/data/negative-words.txt'
pos=set(get_words(p_url))
neg=set(get_words(n_url))
opinion=pos.union(neg)

# %% [markdown]
# ### Model

# %%
# create a list of globally defined positive and negative words to identify sentiment
# sentiment score based on the laxicon neg, pos words
def debug2(sentence, pos=pos, neg=neg):
    '''
    input: dictionary and sentence
    function: appends dictionary with new features if the feature
              did not exist previously,then updates sentiment to
              each of the new or existing features
    output: updated dictionary
    '''
    sent_dict = dict()
    noun_mark=[]
    sentence = nlp(sentence)
    opinion_words = neg.union(pos)
    op=0
    for token in sentence:
        # check if the word is an opinion word, then assign sentiment
        if token.text in opinion_words:
            op=1
            sentiment = 1 if token.text in pos else -1
            # if target is an adverb modifier (i.e. pretty, highly, etc.)
            # but happens to be an opinion word, ignore and pass
            if (token.dep_ == "advmod"):
                continue
            else:
                for child in token.children:
                    # if there's a adj modifier (i.e. very, pretty, etc.) add more weight to sentiment
                    # This could be better updated for modifiers that either positively or negatively emphasize
                    if ((child.dep_ == "amod") or (child.dep_ == "advmod")) and (child.text in opinion_words):
                        sentiment *= 2
                    # check for negation words and flip the sign of sentiment
                    if child.dep_ == "neg":
                        sentiment *= -1
                if (token.pos_) == "VERB":
                    for child in token.children:
                        # if verb, check if there's a direct object
                        if (child.dep_ == "dobj") or (child.dep_=="nsubj"):                        
                            sent_dict[child] = sentiment
                            if child not in noun_mark: noun_mark.append(child)
                            # check for conjugates (a AND b), then add both to dictionary
                            subchildren = []
                            conj = 0
                            for subchild in child.children:
                                if (subchild.text == "and"):
                                    conj=1
                                if (conj == 1) and (subchild.text != "and"):
                                    subchildren.append(subchild)
                                    conj = 0
                            for subchild in subchildren:
                                sent_dict[subchild] = sentiment
                                if subchild not in noun_mark: noun_mark.append(subchild)

                if (token.dep_ == "amod"):
                    #print('a')
                    sent_dict[token.head] = sentiment
                    noun_mark.append(token.head)
                
                    subchildren = []
                    conj = 0
                    for subchild in token.head.children:
                        if (subchild.text == "and"):
                            conj=1
                        if (conj == 1) and (subchild.text != "and"):
                            subchildren.append(subchild)
                            conj = 0
                    for subchild in subchildren:
                        sent_dict[subchild] = sentiment
                        if subchild not in noun_mark: noun_mark.append(subchild)
                
                for child in token.head.children:
                    if (child.pos_ == "NOUN") and (child.text not in sent_dict) \
                    and (child.dep_ not in ["npadvmod"]):
                        sent_dict[child] = sentiment
                        if child not in noun_mark: noun_mark.append(child)
                        #print(token,sent_dict)
                        #print(token.text+':','compund noun',sent_dict)

    temp=[]  
    for noun in set(noun_mark):
        #print(noun,noun_mark,sent_dict)
        #print('1:',temp)
        sentiment = sent_dict[noun]
        if (noun.pos_ == "NOUN" or noun.pos_ == "PROPN") and (noun not in temp):
            temp.append(noun)
            s=noun.text
            current=noun
            state=1
            while current.children and state:
                temp.append(current)
                state=0
                for child in list(current.children)[::-1]:
                    if ((child.pos_ == "NOUN") or (child.pos_ == "PROPN")) and (child.dep_ == "compound"):
                        s = child.text + " " + s
                        current=child
                        temp.append(child)
                        state=1
            del sent_dict[noun]
            sent_dict[s] = sentiment
    #print(sent_dict)
    sent_dict=dict([i for i in sent_dict.items() if type(i[0])==str])
    #print(sent_dict)
    '''
    # check for nouns
    for child in token.head.children:
        noun = ""
        if (child.pos_ == "NOUN") and (child.text not in sent_dict):
            noun = child.text
            # Check for compound nouns
            for subchild in child.children:
                if subchild.dep_ == "compound":
                    noun = subchild.text + " " + noun
            sent_dict[noun] = sentiment
    '''
    if (not sent_dict) and op:
        for token in sentence:
            if token.pos_=="NOUN":
                sent_dict[token.text]=sentiment
    #print(sent_dict)
    return sent_dict

# %% [markdown]
# ### Model Running

# %%
'''
# run only one time
data=[]
import time
begin=time.time()
for i in range(2015,2021):
    for j in range(1,13):
        print(i,j)
        result=[]
        try:
            data=json.load(open('.\wm\Wealth_Management{}-{:02d}.json'.format(i,j)))
        except FileNotFoundError:
            break
        temp=[]
        for z in data:
            if z['retweets']>0 or z['likes']>0 or z['is_replied'] or z['is_reply_to'] or z['replies']:
                temp.append(z)
        data1=total_clean(temp)
        
        for x,k in enumerate(data1):
            d=debug2(k['text']).items()
            if d: result.append(list(d))
        with open("C:\\Users\\rfmen\\Desktop\\Competition\\rough\\{}-{:02d}.txt".format(i,j), "w") as file:
            file.write(str(result))
        print(time.time()-begin,':',len(result),len(data))
        begin=time.time()
'''
# Out:
# '\n# run only one time\ndata=[]\nimport time\nbegin=time.time()\nfor i in range(2015,2021):\n    for j in range(1,13):\n        print(i,j)\n        result=[]\n        try:\n            data=json.load(open(\'.\\wm\\Wealth_Management{}-{:02d}.json\'.format(i,j)))\n        except FileNotFoundError:\n            break\n        temp=[]\n        for z in data:\n            if z[\'retweets\']>0 or z[\'likes\']>0 or z[\'is_replied\'] or z[\'is_reply_to\'] or z[\'replies\']:\n                temp.append(z)\n        data1=total_clean(temp)\n        \n        for x,k in enumerate(data1):\n            d=debug2(k[\'text\']).items()\n            if d: result.append(list(d))\n        with open("C:\\Users\\rfmen\\Desktop\\Competition\\rough\\{}-{:02d}.txt".format(i,j), "w") as file:\n            file.write(str(result))\n        print(time.time()-begin,\':\',len(result),len(data))\n        begin=time.time()\n'

# %% [markdown]
# # Without removing duplicate

# %%
data=[]
for i in range(2015,2021):
    for j in range(1,13):
        try:
            data+=json.load(open('.\wm\Wealth_Management{}-{:02d}.json'.format(i,j)))
        except:
            pass

# %%
len(data)
# Out:
# 621133

# %%
overall=[]
for i in result:
    temp=analyze(i)
    for j in temp:
        if j[0]=='wealth management':
            overall.append(j[1][0]/j[1][1])
overall1=[]
for i in result:
    temp=analyze(i)
    for j in temp:
        if j[0]=='wealth':
            overall1.append(j[1][0]/j[1][1])
overall2=[]
for i in result:
    temp=analyze(i)
    for j in temp:
        if j[0]=='management':
            overall2.append(j[1][0]/j[1][1])
crisis=[]
for i in result:
    temp=analyze(i)
    state=1
    for j in temp:
        if j[0]=='crisis':
            crisis.append(j[1][0]/j[1][1])
            state=0
    if state: crisis.append(0)
plt.figure(figsize=(10,4))
matplotlib.rcParams['figure.dpi']=100
plt.plot(overall,label='wealth management')
plt.plot(overall1,label='wealth')
plt.plot(overall2,label='management')
plt.legend()
plt.xlabel('Month')
plt.title('Average Polarity')
plt.show()

# %% [markdown]
# ### Dependency Parsing and POS Tagging Example

# %%
example=[]
for j in range(1,7):
    try: #Wealth_Management2017-02.json
        temp=json.load(open('.\wm\Wealth_Management{}-{:02d}.json'.format(2017,j)))
        example+=temp
    except:
        break
example=exforeign(example)
example=duplicate(example)
example=remove_link(example)
example=remove_sign(example)
words=toword(example,stop=False)
texts=[' '.join(i) for i in words]

# %%
a=nlp('RT Money 5 new ways your 401k will make you richer by retirement ')
spacy.displacy.render(a, style="dep",jupyter=True, options={'distance': 120})
# Out:
# <span class="tex2jax_ignore"><svg xmlns="http://www.w3.org/2000/svg" xmlns:xlink="http://www.w3.org/1999/xlink" xml:lang="en" id="fea12980adbe41a29e75fd7ddb6d504e-0" class="displacy" width="1610" height="377.0" direction="ltr" style="max-width: none; height: 377.0px; color: #000000; background: #ffffff; font-family: Arial; direction: ltr">
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="287.0">
#     <tspan class="displacy-word" fill="currentColor" x="50">RT</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="50">PROPN</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="287.0">
#     <tspan class="displacy-word" fill="currentColor" x="170">Money</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="170">PROPN</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="287.0">
#     <tspan class="displacy-word" fill="currentColor" x="290">5</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="290">NUM</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="287.0">
#     <tspan class="displacy-word" fill="currentColor" x="410">new</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="410">ADJ</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="287.0">
#     <tspan class="displacy-word" fill="currentColor" x="530">ways</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="530">NOUN</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="287.0">
#     <tspan class="displacy-word" fill="currentColor" x="650">your</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="650">DET</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="287.0">
#     <tspan class="displacy-word" fill="currentColor" x="770">401k</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="770">NOUN</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="287.0">
#     <tspan class="displacy-word" fill="currentColor" x="890">will</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="890">VERB</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="287.0">
#     <tspan class="displacy-word" fill="currentColor" x="1010">make</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="1010">VERB</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="287.0">
#     <tspan class="displacy-word" fill="currentColor" x="1130">you</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="1130">PRON</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="287.0">
#     <tspan class="displacy-word" fill="currentColor" x="1250">richer</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="1250">ADJ</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="287.0">
#     <tspan class="displacy-word" fill="currentColor" x="1370">by</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="1370">ADP</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="287.0">
#     <tspan class="displacy-word" fill="currentColor" x="1490">retirement</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="1490">NOUN</tspan>
# </text>
#
# <g class="displacy-arrow">
#     <path class="displacy-arc" id="arrow-fea12980adbe41a29e75fd7ddb6d504e-0-0" stroke-width="2px" d="M70,242.0 C70,182.0 155.0,182.0 155.0,242.0" fill="none" stroke="currentColor"/>
#     <text dy="1.25em" style="font-size: 0.8em; letter-spacing: 1px">
#         <textPath xlink:href="#arrow-fea12980adbe41a29e75fd7ddb6d504e-0-0" class="displacy-label" startOffset="50%" side="left" fill="currentColor" text-anchor="middle">compound</textPath>
#     </text>
#     <path class="displacy-arrowhead" d="M70,244.0 L62,232.0 78,232.0" fill="currentColor"/>
# </g>
#
# <g class="displacy-arrow">
#     <path class="displacy-arc" id="arrow-fea12980adbe41a29e75fd7ddb6d504e-0-1" stroke-width="2px" d="M190,242.0 C190,62.0 525.0,62.0 525.0,242.0" fill="none" stroke="currentColor"/>
#     <text dy="1.25em" style="font-size: 0.8em; letter-spacing: 1px">
#         <textPath xlink:href="#arrow-fea12980adbe41a29e75fd7ddb6d504e-0-1" class="displacy-label" startOffset="50%" side="left" fill="currentColor" text-anchor="middle">nsubj</textPath>
#     </text>
#     <path class="displacy-arrowhead" d="M190,244.0 L182,232.0 198,232.0" fill="currentColor"/>
# </g>
#
# <g class="displacy-arrow">
#     <path class="displacy-arc" id="arrow-fea12980adbe41a29e75fd7ddb6d504e-0-2" stroke-width="2px" d="M310,242.0 C310,122.0 520.0,122.0 520.0,242.0" fill="none" stroke="currentColor"/>
#     <text dy="1.25em" style="font-size: 0.8em; letter-spacing: 1px">
#         <textPath xlink:href="#arrow-fea12980adbe41a29e75fd7ddb6d504e-0-2" class="displacy-label" startOffset="50%" side="left" fill="currentColor" text-anchor="middle">nummod</textPath>
#     </text>
#     <path class="displacy-arrowhead" d="M310,244.0 L302,232.0 318,232.0" fill="currentColor"/>
# </g>
#
# <g class="displacy-arrow">
#     <path class="displacy-arc" id="arrow-fea12980adbe41a29e75fd7ddb6d504e-0-3" stroke-width="2px" d="M430,242.0 C430,182.0 515.0,182.0 515.0,242.0" fill="none" stroke="currentColor"/>
#     <text dy="1.25em" style="font-size: 0.8em; letter-spacing: 1px">
#         <textPath xlink:href="#arrow-fea12980adbe41a29e75fd7ddb6d504e-0-3" class="displacy-label" startOffset="50%" side="left" fill="currentColor" text-anchor="middle">amod</textPath>
#     </text>
#     <path class="displacy-arrowhead" d="M430,244.0 L422,232.0 438,232.0" fill="currentColor"/>
# </g>
#
# <g class="displacy-arrow">
#     <path class="displacy-arc" id="arrow-fea12980adbe41a29e75fd7ddb6d504e-0-4" stroke-width="2px" d="M670,242.0 C670,182.0 755.0,182.0 755.0,242.0" fill="none" stroke="currentColor"/>
#     <text dy="1.25em" style="font-size: 0.8em; letter-spacing: 1px">
#         <textPath xlink:href="#arrow-fea12980adbe41a29e75fd7ddb6d504e-0-4" class="displacy-label" startOffset="50%" side="left" fill="currentColor" text-anchor="middle">poss</textPath>
#     </text>
#     <path class="displacy-arrowhead" d="M670,244.0 L662,232.0 678,232.0" fill="currentColor"/>
# </g>
#
# <g class="displacy-arrow">
#     <path class="displacy-arc" id="arrow-fea12980adbe41a29e75fd7ddb6d504e-0-5" stroke-width="2px" d="M790,242.0 C790,122.0 1000.0,122.0 1000.0,242.0" fill="none" stroke="currentColor"/>
#     <text dy="1.25em" style="font-size: 0.8em; letter-spacing: 1px">
#         <textPath xlink:href="#arrow-fea12980adbe41a29e75fd7ddb6d504e-0-5" class="displacy-label" startOffset="50%" side="left" fill="currentColor" text-anchor="middle">nsubj</textPath>
#     </text>
#     <path class="displacy-arrowhead" d="M790,244.0 L782,232.0 798,232.0" fill="currentColor"/>
# </g>
#
# <g class="displacy-arrow">
#     <path class="displacy-arc" id="arrow-fea12980adbe41a29e75fd7ddb6d504e-0-6" stroke-width="2px" d="M910,242.0 C910,182.0 995.0,182.0 995.0,242.0" fill="none" stroke="currentColor"/>
#     <text dy="1.25em" style="font-size: 0.8em; letter-spacing: 1px">
#         <textPath xlink:href="#arrow-fea12980adbe41a29e75fd7ddb6d504e-0-6" class="displacy-label" startOffset="50%" side="left" fill="currentColor" text-anchor="middle">aux</textPath>
#     </text>
#     <path class="displacy-arrowhead" d="M910,244.0 L902,232.0 918,232.0" fill="currentColor"/>
# </g>
#
# <g class="displacy-arrow">
#     <path class="displacy-arc" id="arrow-fea12980adbe41a29e75fd7ddb6d504e-0-7" stroke-width="2px" d="M550,242.0 C550,2.0 1010.0,2.0 1010.0,242.0" fill="none" stroke="currentColor"/>
#     <text dy="1.25em" style="font-size: 0.8em; letter-spacing: 1px">
#         <textPath xlink:href="#arrow-fea12980adbe41a29e75fd7ddb6d504e-0-7" class="displacy-label" startOffset="50%" side="left" f

# %%
a=nlp('7 Things Investors Need to Know for Building a Better Path in 2017 ABinsights')
spacy.displacy.render(a, style="dep",jupyter=True, options={'distance': 120})
# Out:
# <span class="tex2jax_ignore"><svg xmlns="http://www.w3.org/2000/svg" xmlns:xlink="http://www.w3.org/1999/xlink" xml:lang="en" id="781c726e06ab46f09744ace2732d0f00-0" class="displacy" width="1730" height="377.0" direction="ltr" style="max-width: none; height: 377.0px; color: #000000; background: #ffffff; font-family: Arial; direction: ltr">
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="287.0">
#     <tspan class="displacy-word" fill="currentColor" x="50">7</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="50">NUM</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="287.0">
#     <tspan class="displacy-word" fill="currentColor" x="170">Things</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="170">NOUN</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="287.0">
#     <tspan class="displacy-word" fill="currentColor" x="290">Investors</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="290">NOUN</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="287.0">
#     <tspan class="displacy-word" fill="currentColor" x="410">Need</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="410">VERB</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="287.0">
#     <tspan class="displacy-word" fill="currentColor" x="530">to</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="530">PART</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="287.0">
#     <tspan class="displacy-word" fill="currentColor" x="650">Know</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="650">VERB</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="287.0">
#     <tspan class="displacy-word" fill="currentColor" x="770">for</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="770">ADP</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="287.0">
#     <tspan class="displacy-word" fill="currentColor" x="890">Building</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="890">VERB</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="287.0">
#     <tspan class="displacy-word" fill="currentColor" x="1010">a</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="1010">DET</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="287.0">
#     <tspan class="displacy-word" fill="currentColor" x="1130">Better</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="1130">ADJ</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="287.0">
#     <tspan class="displacy-word" fill="currentColor" x="1250">Path</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="1250">NOUN</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="287.0">
#     <tspan class="displacy-word" fill="currentColor" x="1370">in</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="1370">ADP</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="287.0">
#     <tspan class="displacy-word" fill="currentColor" x="1490">2017</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="1490">NUM</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="287.0">
#     <tspan class="displacy-word" fill="currentColor" x="1610">ABinsights</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="1610">NOUN</tspan>
# </text>
#
# <g class="displacy-arrow">
#     <path class="displacy-arc" id="arrow-781c726e06ab46f09744ace2732d0f00-0-0" stroke-width="2px" d="M70,242.0 C70,182.0 155.0,182.0 155.0,242.0" fill="none" stroke="currentColor"/>
#     <text dy="1.25em" style="font-size: 0.8em; letter-spacing: 1px">
#         <textPath xlink:href="#arrow-781c726e06ab46f09744ace2732d0f00-0-0" class="displacy-label" startOffset="50%" side="left" fill="currentColor" text-anchor="middle">nummod</textPath>
#     </text>
#     <path class="displacy-arrowhead" d="M70,244.0 L62,232.0 78,232.0" fill="currentColor"/>
# </g>
#
# <g class="displacy-arrow">
#     <path class="displacy-arc" id="arrow-781c726e06ab46f09744ace2732d0f00-0-1" stroke-width="2px" d="M190,242.0 C190,122.0 400.0,122.0 400.0,242.0" fill="none" stroke="currentColor"/>
#     <text dy="1.25em" style="font-size: 0.8em; letter-spacing: 1px">
#         <textPath xlink:href="#arrow-781c726e06ab46f09744ace2732d0f00-0-1" class="displacy-label" startOffset="50%" side="left" fill="currentColor" text-anchor="middle">npadvmod</textPath>
#     </text>
#     <path class="displacy-arrowhead" d="M190,244.0 L182,232.0 198,232.0" fill="currentColor"/>
# </g>
#
# <g class="displacy-arrow">
#     <path class="displacy-arc" id="arrow-781c726e06ab46f09744ace2732d0f00-0-2" stroke-width="2px" d="M310,242.0 C310,182.0 395.0,182.0 395.0,242.0" fill="none" stroke="currentColor"/>
#     <text dy="1.25em" style="font-size: 0.8em; letter-spacing: 1px">
#         <textPath xlink:href="#arrow-781c726e06ab46f09744ace2732d0f00-0-2" class="displacy-label" startOffset="50%" side="left" fill="currentColor" text-anchor="middle">nsubj</textPath>
#     </text>
#     <path class="displacy-arrowhead" d="M310,244.0 L302,232.0 318,232.0" fill="currentColor"/>
# </g>
#
# <g class="displacy-arrow">
#     <path class="displacy-arc" id="arrow-781c726e06ab46f09744ace2732d0f00-0-3" stroke-width="2px" d="M550,242.0 C550,182.0 635.0,182.0 635.0,242.0" fill="none" stroke="currentColor"/>
#     <text dy="1.25em" style="font-size: 0.8em; letter-spacing: 1px">
#         <textPath xlink:href="#arrow-781c726e06ab46f09744ace2732d0f00-0-3" class="displacy-label" startOffset="50%" side="left" fill="currentColor" text-anchor="middle">aux</textPath>
#     </text>
#     <path class="displacy-arrowhead" d="M550,244.0 L542,232.0 558,232.0" fill="currentColor"/>
# </g>
#
# <g class="displacy-arrow">
#     <path class="displacy-arc" id="arrow-781c726e06ab46f09744ace2732d0f00-0-4" stroke-width="2px" d="M430,242.0 C430,122.0 640.0,122.0 640.0,242.0" fill="none" stroke="currentColor"/>
#     <text dy="1.25em" style="font-size: 0.8em; letter-spacing: 1px">
#         <textPath xlink:href="#arrow-781c726e06ab46f09744ace2732d0f00-0-4" class="displacy-label" startOffset="50%" side="left" fill="currentColor" text-anchor="middle">xcomp</textPath>
#     </text>
#     <path class="displacy-arrowhead" d="M640.0,244.0 L648.0,232.0 632.0,232.0" fill="currentColor"/>
# </g>
#
# <g class="displacy-arrow">
#     <path class="displacy-arc" id="arrow-781c726e06ab46f09744ace2732d0f00-0-5" stroke-width="2px" d="M670,242.0 C670,182.0 755.0,182.0 755.0,242.0" fill="none" stroke="currentColor"/>
#     <text dy="1.25em" style="font-size: 0.8em; letter-spacing: 1px">
#         <textPath xlink:href="#arrow-781c726e06ab46f09744ace2732d0f00-0-5" class="displacy-label" startOffset="50%" side="left" fill="currentColor" text-anchor="middle">prep</textPath>
#     </text>
#     <path class="displacy-arrowhead" d="M755.0,244.0 L763.0,232.0 747.0,232.0" fill="currentColor"/>
# </g>
#
# <g class="displacy-arrow">
#     <path class="displacy-arc" id="arrow-781c726e06ab46f09744ace2732d0f00-0-6" stroke-width="2px" d="M790,242.0 C790,182.0 875.0,182.0 875.0,242.0" fill="none" stroke="currentColor"/>
#     <text dy="1.25em" style="font-size: 0.8em; letter-spacing: 1px">
#         <textPath xlink:href="#arrow-781c726e06ab46f09744ace2732d0f00-0-6" class="displacy-label" startOffset="50%" side="left" fill="currentColor" text-anchor="middle">pcomp</textPath>
#     </text>
#     <path class="displacy-arrowhead" d="M875.0,244.0 L883.0,232.0 867.0,232.0" fill="currentColor"/>
# </g>
#
# <g class="displacy-arrow">
#     <path class="displacy-arc" id="arrow-781c726e06ab46f09744ace2732d0f00-0-7" stroke-width="2px" d="M1030,2

# %%
s=['RT Money 5 new ways your 401k will make you richer by retirement',
   'Why intergenerational wealth transfer could be bad for the industry',
   '7 Things Investors Need to Know for Building a Better Path in 2017 ABinsights',
   'Morgan Stanley said it gave a significant number of wealthmanagement clients incorrect tax information']
for i in s:
    print(i)
    print(debug2(i),'\n')
# Out:
# RT Money 5 new ways your 401k will make you richer by retirement
# {'401k': 1}
#
# Why intergenerational wealth transfer could be bad for the industry
# {'wealth transfer': -1}
#
# 7 Things Investors Need to Know for Building a Better Path in 2017 ABinsights
# {}
#
# Morgan Stanley said it gave a significant number of wealthmanagement clients incorrect tax information
# {'number': 1, 'tax information': -1}

# %% [markdown]
# # 6/17: Loading Result

# %%
# import 
result=[]
for i in range(2015,2021):
    for j in range(1,13):
        try:
            with open("C:\\Users\\rfmen\\Desktop\\Competition\\rough\\{}-{:02d}.txt".format(i,j), "r") as file:
                temp=eval(file.readline())
                result.append(temp)
        except:
            break

# %%
def analyze(x):
    result={}
    for i in x:
        d=dict(i)
        for j in d:
            if j not in result:
                result[j]=(d[j],1)
            else:
                result[j]=(result[j][0]+d[j],result[j][1]+1)
    return list(result.items())

# %%
a=analyze(result[0])
a
# Out:
# [('way', (2, 2)),
#  ('wisdom', (1, 1)),
#  ('Farnsley Johnston Wealth Management', (1, 1)),
#  ('AmeripriseNews', (1, 1)),
#  ('Thanks', (2, 2)),
#  ('bank', (2, 2)),
#  ('Hollywoods', (2, 2)),
#  ('advisors', (0, 2)),
#  ('doubledigit AUM growth', (1, 1)),
#  ('places', (-1, 1)),
#  ('financing', (-1, 1)),
#  ('junk', (-1, 1)),
#  ('Okotokslawyer', (-1, 1)),
#  ('access', (1, 1)),
#  ('process', (1, 1)),
#  ('proven', (1, 1)),
#  ('post', (1, 1)),
#  ('explanation', (1, 1)),
#  ('work', (2, 2)),
#  ('plenty', (1, 1)),
#  ('dinner time', (-1, 1)),
#  ('US companies', (-1, 1)),
#  ('dollar', (-3, 3)),
#  ('email', (1, 1)),
#  ('questions', (-1, 1)),
#  ('momentum', (-1, 1)),
#  ('SNB policy shock', (-1, 1)),
#  ('worth', (1, 1)),
#  ('firm', (3, 2)),
#  ('wealth', (16, 18)),
#  ('management', (8, 13)),
#  ('insurance', (1, 1)),
#  ('time', (0, 4)),
#  ('expertise', (1, 1)),
#  ('Cubas talks', (1, 1)),
#  ('Castro', (1, 1)),
#  ('returns', (2, 2)),
#  ('approach', (1, 1)),
#  ('confidence', (1, 1)),
#  ('advice', (3, 3)),
#  ('quality', (1, 1)),
#  ('Debt', (1, 1)),
#  ('Relief', (1, 1)),
#  ('bluegreentweet', (1, 1)),
#  ('duties', (1, 1)),
#  ('terms', (1, 1)),
#  ('learnership', (1, 1)),
#  ('idea', (2, 2)),
#  ('business', (1, 1)),
#  ('finances', (1, 1)),
#  ('progress', (2, 2)),
#  ('tool', (1, 1)),
#  ('debt', (-2, 2)),
#  ('person', (4, 4)),
#  ('contenders', (1, 1)),
#  ('supporter', (1, 1)),
#  ('Year award', (1, 1)),
#  ('part', (2, 2)),
#  ('UOBusiness', (1, 1)),
#  ('tonight', (1, 1)),
#  ('efficiency', (1, 1)),
#  ('disruption', (-2, 2)),
#  ('product problem', (-1, 1)),
#  ('Use', (1, 1)),
#  ('Author', (1, 1)),
#  ('man', (1, 1)),
#  ('help', (1, 1)),
#  ('investment professionals', (2, 2)),
#  ('wealth services', (1, 1)),
#  ('center', (1, 1)),
#  ('investments', (1, 1)),
#  ('track', (2, 2)),
#  ('wealth management firm', (1, 3)),
#  ('Trust Fund loophole', (-1, 1)),
#  ('PSAFinancial', (1, 1)),
#  ('innovation', (3, 3)),
#  ('website', (3, 2)),
#  ('Portfolio', (2, 1)),
#  ('support', (3, 3)),
#  ('BPR skills', (1, 1)),
#  ('Wealth Management opportunities', (1, 1)),
#  ('wealth management industry', (1, 1)),
#  ('Developer', (1, 1)),
#  ('RBC', (1, 1)),
#  ('seats', (1, 1)),
#  ('Investment bankers', (1, 1)),
#  ('survival', (1, 1)),
#  ('strategy', (1, 1)),
#  ('air', (1, 1)),
#  ('shit', (-1, 1)),
#  ('bait', (-1, 1)),
#  ('partnership', (1, 1)),
#  ('branding', (1, 1)),
#  ('talent', (14, 11)),
#  ('investment risk', (-5, 5)),
#  ('client data', (-3, 3)),
#  ('Morgan Stanley management employee', (-1, 1)),
#  ('skill', (1, 1)),
#  ('RMUMBasketball', (1, 1)),
#  ('sponsor', (1, 1)),
#  ('industry', (1, 1)),
#  ('music', (1, 1)),
#  ('cassette', (1, 1)),
#  ('tapes', (1, 1)),
#  ('BouChalmers', (1, 1)),
#  ('fun', (1, 1)),
#  ('Wealth management', (-1, 1)),
#  ('demand', (1, 1)),
#  ('trust', (2, 2)),
#  ('newsletter', (1, 1)),
#  ('lot', (1, 1)),
#  ('services', (1, 1)),
#  ('Lets', (1, 1)),
#  ('risk', (-1, 1)),
#  ('IFA networks', (1, 1)),
#  ('presentation', (1, 1)),
#  ('piece', (3, 3)),
#  ('AnieAkpe', (1, 1)),
#  ('messy', (-1, 1)),
#  ('Happy New Year', (-1, 1)),
#  ('future', (1, 1)),
#  ('ease', (1, 1)),
#  ('planning', (1, 1)),
#  ('app', (1, 1)),
#  ('wealth management', (7, 9)),
#  ('wealth management tech content', (1, 1)),
#  ('Advisors', (1, 1)),
#  ('Biz Dinner', (1, 1)),
#  ('crisis', (-2, 2)),
#  ('Eurozone', (-1, 1)),
#  ('Wealth Management Company', (1, 1)),
#  ('flexibility', (1, 1)),
#  ('money', (-1, 1)),
#  ('response', (-1, 1)),
#  ('consumers', (1, 1)),
#  ('today', (1, 1)),
#  ('venue', (1, 1)),
#  ('YouTube video', (1, 1)),
#  ('market', (1, 1)),
#  ('beginners', (1, 1)),
#  ('wealth management brokers', (1, 1)),
#  ('millennials', (1, 1)),
#  ('values', (1, 1)),
#  ('wealth management employee', (-2, 2)),
#  ('problem', (-1, 1)),
#  ('frictionless', (1, 1)),
#  ('tax conditions', (1, 1)),
#  ('weather', (1, 1)),
#  ('4Q', (1, 1)),
#  ('OTHERS award', (1, 1)),
#  ('wealth management solutions', (1, 1)),
#  ('application', (-1, 1)),
#  ('banking', (-1, 1)),
#  ('grad', (-1, 1)),
#  ('scheme', (-1, 1)),
#  ('link', (-1, 1)),
#  ('Fam', (-1, 1)),
#  ('Details', (1, 1)),
#  ('route', (1, 1)),
#  ('digitalisation', (1, 1)),
#  ('leapfrog', (1, 1)),
#  ('markets', (0, 2)),
#  ('pig', (-1, 1)),
#  ('quarter', (-1, 1)),
#  ('marketing', (1, 1)),
#  ('independence', (1, 1)),
#  ('journey', (1, 1)),
#  ('inspiration', (1, 1)),
#  ('media', (1, 1)),
#  ('lobster dinner', (1, 1)),
#  ('waste', (-1, 1)),
#  ('firms', (3, 3)),
#  ('race', (3, 3)),
#  ('choices', (1, 1)),
#  ('grant', (1, 1)),
#  ('growth', (1, 1)),
#  ('focus', (1, 1)),
#  ('part wealth management', (1, 1)),
#  ('wellbeing', (1, 1)),
#  ('investment strategy', (1, 1)),
#  ('success', (2, 2)),
#  ('prosperity', (1, 1)),
#  ('BS', (1, 1)),
#  ('conversation', (1, 1)),
#  ('career', (1, 1)),
#  ('US pattern', (-1, 1)),
#  ('client loyalty', (1, 1)),
#  ('term outlook', (-1, 1)),
#  ('JCIManchester jmwsolicitors', (1, 1)),
#  ('trader bloke', (-1, 1)),
#  ('savings', (1, 1)),
#  ('victory', (2, 1)),
#  ('communication', (1, 1)),
#  ('information', (1, 1)),
#  ('investment work', (1, 1)),
#  ('Royal Bank', (-1, 1)),
#  ('Newspapers', (-1, 1)),
#  ('blog', (-1, 1)),
#  ('creation', (1, 1)),
#  ('Simon', (1, 1)),
#  ('tail risk', (-1, 1)),
#  ('danger', (-1, 1)),
#  ('value', (-1, 1)),
#  ('RussThornton', (1, 1)),
#  ('Wealthcare', (1, 1)),
#  ('Ruh roh Partial account info', (-1, 1)),
#  ('banks', (1, 1)),
#  ('biz', (1, 1)),
#  ('vacancy', (1, 1)),
#  ('wow', (1, 1)),
#  ('pain', (-1, 1)),
#  ('data', (-1, 1)),
#  ('acquisition', (2, 2)),
#  ('issues', (-1, 1)),
#  ('diversification', (1, 1)),
#  ('RBCs management business', (1, 1)),
#  ('age', (-1, 1)),
#  ('Back9 Events', (1, 1)),
#  ('article', (1, 1)),
#  ('Face', (1, 1)),
#  ('Management', (1, 1)),
#  ('issue', (-1, 1)),
#  ('copy', (1, 1)),
#  ('LJKawa wealth management', (-1, 1)),
#  ('error', (-1, 1)),
#  ('wealth need', (-1, 1)),
#  ('JohnPalicka FX moves', (-1, 1)),
#  ('Tax', (1, 1)),
#  ('crossborder wealth management', (-1, 1)),
#  ('players', (-1, 1)),
#  ('position', (1, 1)),
#  ('value proposition', (1, 1)),
#  ('Dinner', (1, 1)),
#  ('radar', (1, 1)),
#  ('financialpost', (1, 1)),
#  ('T', (1, 1)),
#  ('win', (2, 2)),
#  ('lender', (1, 1)),
#  ('buying', (1, 1)),
#  ('chat', (1, 1)),
#  ('hunt', (1, 1)),
#  ('RT LIMRACRS Digital transformation', (-1, 1)),
#  ('transformation', (-1, 1)),
#  ('wife', (1, 1)),
#  ('office', (1, 1)),
#  ('things', (1, 1)),
#  ('character', (1, 1)),
#  ('Side', (1, 1)),
#  ('williamtrout discusses', (1, 1)),
#  ('people', (1, 1)),
#  ('decisions', (1, 1)),
#  ('team', (1, 1)),
#  ('team player', (1, 1)),
#  ('place', (-1, 1)),
#  ('year', (-1, 1)),
#  ('arm', (1, 1)),
#  ('becalm', (1, 1)),
#  ('fuss', (-1, 1)),
#  ('side', (-1, 1))]

# %%
a=[analyze(i) for i in result]

# %%
sum()

# %%
month=[]
for i in range(2015,2021):
    for j in range(1,13):
        if i<2020 or j<=5:
            month.append('{}-{:02d}'.format(i,j))

# %%
for i in range(len(month)):
    temp=sorted(analyze(result[i]),key=lambda x: -x[1][1])[:10]
    #word=[i[0]+': '+str(round(i[1][0]/i[1][1],2)) for i in temp]
    word=[i[0] for i in temp]
    print(month[i],'\t',word[2:])
# Out:
# 2015-01 	 ['talent', 'wealth management', 'investment risk', 'time', 'person', 'dollar', 'advice', 'wealth management firm']
# 2015-02 	 ['cost savings', 'wealth management', 'investment risk', 'team', 'firms', 'problem', 'trust', 'benefits']
# 2015-03 	 ['wealth management', 'investment risk', 'advisors', 'advisor', 'wealth management guide', 'disruption', 'standard', 'risk']
# 2015-04 	 ['favour', 'wealth management', 'banking', 'support', 'clients', 'group', 'issues', 'millennials']
# 2015-05 	 ['wealth management', 'actions', 'dreams', 'advisors', 'courage', 'Wealth', 'investment risk', 'people']
# 2015-06 	 ['management', 'investment', 'investment portfolio', 'wealth management boutique', 'money', 'firm', 'effects', 'wealth management industry']
# 2015-07 	 ['wealth management', 'results', 'MerrillLynch', 'advisor loss', 'UBS', 'MorganStanley', 'disruption', 'risk']
# 2015-08 	 ['wealth management', 'money', 'market share', 'success', 'time', 'work', 'decline', 'Salesforce']
# 2015-09 	 ['wealth management', 'management', 'trends', 'time', 'LEAKED Oppenheimer', 'advisors', 'day', 'way']
# 2015-10 	 ['wealth management', 'wealth management pros', 'industry', 'wealth management failures', 'talent', 'innovation', 'Profit Formula platform', 'percentage']
# 2015-11 	 ['industry', 'disruption', 'reasons', 'Wealth management', 'data', 'money', 'Wealth', 'people']
# 2015-12 	 ['client trust', 'reasons', 'industry', 'Survivorship', 'investment', 'disruption', 'wealth management', 'future']
# 2016-01 	 ['reasons', 'investment decisions', 'Survivorship', 'wealth management', 'clients', 'luxury', 'fashion', 'management trends']
# 2016-02 	 ['reasons', 'Survivorship', 'wealth management', 'investment decisions', 'innovation', 'money', 'luxury', 'fashion']
# 2016-03 	 ['wealth management', 'reasons', 'approach', 'investment', 'one', 'market', 'investment decisions', 'harm']
# 2016-04 	 ['Shanghai wealth management', 'wealth management', 'reasons', 'disruption', 'approach', 'trends', 'investors', 'today']
# 2016-05 	 ['wealth management', 'reasons', 'savings', 'risk', 'disruption', 'day', 'time', 'business']
# 2016-06 	 ['questions', 'reasons', 'wealth management', 'wave', 'firms', 'Ty', 'investors', 'report']
# 2016-07 	 ['wealth management', 'reasons', 'success', 'risk', 'wealth management game', 'Wealth', 'hiring freeze', 'time']
# 2016-08 	 ['wealth management', 'reasons', 'risk', 'firm', 'customer service', 'disruption', 'wave', 'clients']
# 2016-09 	 ['wealth management', 'winner', 'category', 'technology', 'reasons', 'Congrats', 'money', 'risk']
# 2016-10 	 ['planning', 'wealth management', 'newsletter', 'Deutsche', 'disruption', 'clients', 'innovation', 'market']
# 2016-11 	 ['cost savings', 'Trump', 'DS practitioners', 'planning', 'role', 'clients', 'disruption', 'head']
# 2016-12 	 ['planning', 'enemy', 'DS practitioners', 'one', 'market', 'skill', 'moves', 'wealth management']
# 2017-01 	 ['management', 'one', 'market', 'enemy', 'risk', 'trust', 'year', 'firms']
# 2017-02 	 ['management', 'wealth', 'people', 'business', 'firms', 'one', 'risk', 'market']
# 2017-03 	 ['wealth', 'wealth management advice', 'one', 'market', 'intelligence', 'enemy', 'doubt', 'risks']
# 2017-04 	 ['market', 'enemy', 'mess', 'wealth management', 'luxury', 'one', 'clients', 'wealth management success']
# 2017-05 	 ['management', 'wealth management', 'intelligence', 'thing', 'risk slavery', 'enemy', 'work', 'economics']
# 2017-06 	 ['wealth management', 'enemy', 'work', 'advice', 'Wealth management firms', 'intelligence', 'clients', 'one']
# 2017-07 	 ['wealth', 'wealth management firms', 'Morgan Stanley expertise', 'life', 'boom', 'spans', 'roboadviser boom', 'wealth management']
# 2017-08 	 ['market', 'one', 'ways', 'business', 'wealth management', 'intelligence', 'DS practitioners', 'day']
# 2017-09 	 ['wealth', 'management', 'wealth management', 'work', 'industry', 'clients', 'firm', 'future']
# 2017-10 	 ['one', 'market', 'intelligence', 'wealth management', 'winner', 'success', 'Congrats', 'clients']
# 2017-11 	 ['wealth management', 'risk', 'work', 'success', 'industry', 'time', 'learning', 'market']
# 2017-12 	 ['clients', 'bonus', 'wealth management', 'business', 'one', 'market', 'success', 'advisors']
# 2018-01 	 ['management', 'wealth management', 'clients', 'world', 'market', 'business', 'success', 'year']
# 2018-02 	 ['wealth management', 'clients', 'time', 'services', 'future', 'support', 'team', 'success']
# 2018-03 	 ['wealth management', 'support', 'discussion', 'success', 'harassment', 'way', 'advisor', 'time']
# 2018-04 	 ['clients', 'wealth management', 'advice', 'firms', 'support', 'work', 'success', 'team']
# 2018-05 	 ['team', 'clients', 'wealth management', 'crypto wealth management platform', 'crypto wealth management', 'support', 'business', 'time']
# 2018-06 	 ['team', 'wealth management', 'clients', 'support', 'services', 'time', 'success', 'risk']
# 2018-07 	 ['team', 'clients', 'crypto wealth management platform', 'support', 'success', 'wealth management', 'risk', 'time']
# 2018-08 	 ['team', 'clients', 'crypto wealth management platform', 'wealth management', 'money', 'industry', 'success', 'business']
# 2018-09 	 ['team', 'winner', 'support', 'category', 'clients', 'wealth management', 'work', 'Congratulations']
# 2018-10 	 ['clients', 'team', 'wealth management', 'business', 'industry', 'time', 'today', 'risk']
# 2018-11 	 ['clients', 'wealth management', 'success', 'team', 'people', 'money', 'risk', 'support']
# 2018-12 	 ['time', 'clients', 'wealth management', 'meeting', 'work', 'services', 'retirement planning', 'risk']
# 2019-01 	 ['clients', 'wealth management', 'team', 'service', 'advisors', 'year', 'money', 'support']
# 2019-02 	 ['clients', 'wealth management', 'team', 'advisors', 'future', 'time', 'people', 'money']
# 2019-03 	 ['influencers', 'list', 'blog', 'people', 'support', 'wealth management', 'clients', 'business']
# 2019-04 	 ['clients', 'wealth management', 'team', 'people', 'support', 'firms', 'time', 'benefits']
# 2019-05 	 ['support', 'clients', 'risk', 'business', 'people', 'time', 'wealth management', 'team']
# 2019-06 	 ['clients', 'risk', 'work', 'support', 'wealth management', 'people', 'time', 'firms']
# 2019-07 	 ['wealth management', 'clients', 'support', 'time', 'risk', 'work', 'business', 'industry']
# 2019-08 	 ['clients', 'wealth management', 'people', 'risk', 'success', 'advice', 'business', 'team']
# 2019-09 	 ['winner', 'Congratulations', 'wealth management', 'clients', 'category', 'time', 'people', 'team']
# 2019-10 	 ['clients', 'wealth management', 'firms', 'team', 'support', 'time', 'firm', 'risk']
# 2019-11 	 ['clients', 'people', 'wealth management', 'firms', 'time', 'money', 'investment', 'advisors']
# 2019-12 	 ['wealth management', 'clients', 'people', 'risks', 'work', 'money', 'investment', 'year']
# 2020-01 	 ['support', 'place', 'wealth management', 'clients', 'success', 'world', 'risk', 'money']
# 2020-02 	 ['risk', 'wealth management', 'clients', 'time', 'money', 'team', 'people', 'support']
# 2020-03 	 ['clients', 'time', 'wealth management', 'support', 'crisis', 'work', 'team', 'way']
# 2020-04 	 ['crisis', 'clients', 'time', 'times', 'wealth management', 'risk', 'money', 'work']
# 2020-05 	 ['clients', 'crisis', 'time', 'wealth management', 'support', 'work', 'team', 'risk']

# %%
block=['blockchain','cypto','bitcoin','btc','bch']

# %%
bresult=[]
for i in a:
    bresult.append([])
    for j in block:
        for k in i:
            if j in k[0].lower():
                bresult[-1].append(k)

# %%
num=[]
freq=[]
bresult
for i in bresult:
    if i:
        a,b=0,0
        for j in i:
            a+=j[1][0]
            b+=j[1][1]
        freq.append(b)
        num.append(a/b)
    else:
        num.append(0)
        freq.append(0)

# %%
BTC=pd.read_csv('BTC-USD.csv')
p=BTC['Adj Close'].values
num=np.array(num)
plt.plot(p,color='black',zorder=-1)
plt.scatter(np.arange(len(num))[num>0],p[num>0],c=num[num>0],cmap=cm.bwr)
plt.scatter(np.arange(len(num))[num<0],p[num<0],c=num[num<0],cmap=cm.bwr)
plt.title('BTC Price')
cbar = plt.colorbar()
cbar.set_label('Sentiment Polarity')
plt.show()
