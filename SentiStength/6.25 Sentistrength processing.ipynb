# %%
import os
import time

import pandas as pd
import numpy as np
import json
import matplotlib.pyplot as plt
import re
import matplotlib

from nltk.stem.snowball import SnowballStemmer
import nltk
import gensim
import spacy

import matplotlib.cm as cm

stemmer = SnowballStemmer("english")
nlp = spacy.load("en_core_web_sm")

# %%
from tool import *
# unique(x)
# find_kol(data,rank)
# unique_time(data)
# exforeign(data)
# duplicate(data)
# remove_link(data)
# remove_sign(data)
# total_clean(indata)
# toword(data,stem=False,stop=True)
# get_words(url), pos, neg, opinion
# debug2(sentence)
# month(start,end)
# search(data,keywords)

# %%
from Data_Processor import Data_Processor
from Data_Processor import clean
# Out:
# [nltk_data] Downloading package wordnet to
# [nltk_data]     C:\Users\rfmen\AppData\Roaming\nltk_data...
# [nltk_data]   Package wordnet is already up-to-date!
# [nltk_data] Downloading package punkt to
# [nltk_data]     C:\Users\rfmen\AppData\Roaming\nltk_data...
# [nltk_data]   Package punkt is already up-to-date!
# [nltk_data] Downloading package stopwords to
# [nltk_data]     C:\Users\rfmen\AppData\Roaming\nltk_data...
# [nltk_data]   Package stopwords is already up-to-date!

# %%
root_path=os.getcwd()
list(os.walk(root_path+'\\data'))
# Out:
# [('C:\\Users\\rfmen\\Desktop\\Competition\\data',
#   ['Betterment',
#    'BOA',
#    'Charles Schwab',
#    'eTrade',
#    'Fidelity',
#    'Goldman_Sachs',
#    'InteractiveBrokers',
#    'JPMorgan',
#    'Merrill Lynch',
#    'Morgan_Stanley',
#    'Personal Capital',
#    'Robinhood',
#    'Robo Advisor',
#    'TD Ameritrade',
#    'UBS',
#    'Vanguard',
#    'Wealth Management',
#    'wealthfront',
#    'Wells Fargo'],
#   []),
#  ('C:\\Users\\rfmen\\Desktop\\Competition\\data\\Betterment',
#   [],
#   ['Betterment2017-06.json',
#    'Betterment2017-07.json',
#    'Betterment2017-08.json',
#    'Betterment2017-09.json',
#    'Betterment2017-10.json',
#    'Betterment2017-11.json',
#    'Betterment2017-12.json',
#    'Betterment2018-01.json',
#    'Betterment2018-02.json',
#    'Betterment2018-03.json',
#    'Betterment2018-04.json',
#    'Betterment2018-05.json',
#    'Betterment2018-06.json',
#    'Betterment2018-07.json',
#    'Betterment2018-08.json',
# ...

# %%
filepath=[]
filename=[]
for i in list(os.walk(root_path+'\\data')):
    if not i[1]:
        for j in i[2]:
            filename.append(j)
            filepath.append(i[0]+'\\'+j)

# %%
def weird(path):
    DP=Data_Processor()
    DP.data=[json.load(open(path))]
    DP.specifylang()
    DP.removenoise()
    DP.clean()
    return DP.data[0]

# %%
#json.dumps(DP.data[0])

# %%
#a=open('123asdf.json','w')
#a.write(json.dumps(DP.data[0]))

# %%
'''
for i in range(len(filepath)):
    cleaned=weird(filepath[i])
    temp=open('./SentiStrength/temp/'+filename[i],'w')
    temp.write(json.dumps(cleaned))
'''

# %%
'''
for i in range(len(filepath)):
    temp=json.load(open('./SentiStrength/temp/'+filename[i]))
    txt=[' ',]+[x['text'] for x in temp]
    file=open('./SentiStrength/txt/'+filename[i][:-4]+'txt','w')
    file.writelines([i+'\n' for i in txt])
    file.close()
'''

# %%
'''
# simple verification
cnt=0
for i in range(len(filename)):
    a=json.load(open('./SentiStrength/temp/'+filename[i]))
    file=open('./SentiStrength/txt/'+filename[i][:-4]+'txt','r')
    if len(a)==(len(file.readlines())-1): 
        cnt+=1
        print(cnt)
        print(len(a),len(file.readlines())-1)
    #print(file.readlines())
    file.close()
'''
# Out:
# 1
# 2 -1
# 2
# 9 -1
# 3
# 7 -1
# 4
# 6 -1
# 5
# 3 -1
# 6
# 11 -1
# 7
# 2 -1
# 8
# 9 -1
# 9
# 8 -1
# 10
# 11 -1
# 11
# 10 -1
# 12
# 9 -1
# 13
# 10 -1
# 14
# 12 -1
# 15
# 11 -1
# 16
# 33 -1
# 17
# 10 -1
# 18
# 8 -1
# 19
# 7 -1
# 20
# 19 -1
# 21
# 6 -1
# 22
# 17 -1
# 23
# 24 -1
# 24
# 6 -1
# 25
# 14 -1
# 26
# 11 -1
# 27
# 17 -1
# 28
# 18 -1
# 29
# 19 -1
# 30
# 14 -1
# 31
# 9 -1
# 32
# 7 -1
# 33
# 12 -1
# 34
# 14 -1
# 35
# 11 -1
# 36
# 12 -1
# 37
# 4202 -1
# 38
# 3483 -1
# 39
# 3541 -1
# 40
# 3791 -1
# 41
# 4239 -1
# 42
# 4419 -1
# 43
# 4439 -1
# 44
# 4201 -1
# 45
# 4332 -1
# 46
# 4121 -1
# 47
# 4878 -1
# 48
# 5121 -1
# 49
# 5620 -1
# 50
# 4807 -1
# 51
# 5000 -1
# 52
# 5052 -1
# 53
# 4958 -1
# 54
# 5222 -1
# 55
# 5878 -1
# 56
# 5158 -1
# 57
# 5290 -1
# 58
# 6070 -1
# 59
# 5728 -1
# 60
# 5281 -1
# 61
# 5912 -1
# 62
# 6158 -1
# 63
# 6365 -1
# 64
# 6720 -1
# 65
# 6423 -1
# 66
# 6801 -1
# 67
# 6592 -1
# 68
# 5756 -1
# 69
# 5981 -1
# 70
# 6558 -1
# 71
# 7504 -1
# 72
# 6220 -1
# 73
# 490 -1
# ...

# %%
'''
d,b=0,0
for i in range(len(filename)):
    a=json.load(open('./SentiStrength/temp/'+filename[i]))
    txt=open('./SentiStrength/txt/'+filename[i][:-5]+'+results.txt','r')
    raw=txt.readlines()[1:]
    for x,j in enumerate(raw):
        match=re.search(r'\t\d\t-\d\t',j)
        d=j
        b=match
        sentiment=[int(k) for k in match.group().split()]
        a[x]['positive']=sentiment[0]
        a[x]['negative']=sentiment[1]
    temp=open('./SentiStrength/final/'+filename[i],'w')
    temp.write(json.dumps(a))
    temp.close()
'''
# Out:
# "\nd,b=0,0\nfor i in range(len(filename)):\n    a=json.load(open('./SentiStrength/temp/'+filename[i]))\n    txt=open('./SentiStrength/txt/'+filename[i][:-5]+'+results.txt','r')\n    raw=txt.readlines()[1:]\n    for x,j in enumerate(raw):\n        match=re.search(r'\t\\d\t-\\d\t',j)\n        d=j\n        b=match\n        sentiment=[int(k) for k in match.group().split()]\n        a[x]['positive']=sentiment[0]\n        a[x]['negative']=sentiment[1]\n    temp=open('./SentiStrength/final/'+filename[i],'w')\n    temp.write(json.dumps(a))\n    temp.close()\n"

# %%
temp=json.load(open('./SentiStrength/final/WellsFargo2018-07.json'))

# %%
temp[100]
# Out:
# {'has_media': False,
#  'hashtags': ['CommunityMVP', 'orlandocitysc'],
#  'img_urls': [],
#  'is_replied': False,
#  'is_reply_to': False,
#  'likes': 1,
#  'links': ['https://mlsworkscmvp.com/#orlandocitysc'],
#  'parent_tweet_id': '',
#  'replies': 0,
#  'reply_to_users': [],
#  'retweets': 0,
#  'screen_name': 'doorworker',
#  'text': 'I just voted for Grace Bowman the  OrlandoCitySC MLSWORKS presented by WellsFargo ',
# ...

# %%
dir(b)
# Out:
# ['__class__',
#  '__copy__',
#  '__deepcopy__',
#  '__delattr__',
#  '__dir__',
#  '__doc__',
#  '__eq__',
#  '__format__',
#  '__ge__',
#  '__getattribute__',
#  '__getitem__',
#  '__gt__',
#  '__hash__',
#  '__init__',
#  '__init_subclass__',
#  '__le__',
#  '__lt__',
#  '__ne__',
#  '__new__',
#  '__reduce__',
#  '__reduce_ex__',
#  '__repr__',
#  '__setattr__',
#  '__sizeof__',
#  '__str__',
#  '__subclasshook__',
#  'end',
#  'endpos',
#  'expand',
#  'group',
#  'groupdict',
#  'groups',
#  'lastgroup',
#  'lastindex',
#  'pos',
#  're',
#  'regs',
#  'span',
#  'start',
#  'string']

# %%
b.string
# Out:
# ' \t\t1\t-1\t[[[0,0 max of sentences]]]\n'

# %%
d
# Out:
# ' \t\t1\t-1\t[[[0,0 max of sentences]]]\n'

# %%
match=re.search(r'\t\d\t-\d\t',d)
match
# Out:
# <re.Match object; span=(2, 8), match='\t1\t-1\t'>

# %%
match.group().split()
# Out:
# ['1', '-1']

# %%
# Out:
# ['1', '-1']

# %%
for i in range(len(raw)):
    match=re.search(r'\t\d\t-\d\t',raw[i])
    print([int(x) for x in raw[i][match.start():match.end()+1].split()])
# Out:
# [2, -1]
# [2, -1]
# [2, -2]
# [1, -2]
# [2, -1]
# [1, -1]
# [3, -2]
# [2, -1]
# [3, -1]
# [3, -2]
# [1, -2]

# %%
file=open('./SentiStrength/txt/'+filename[1][:-4]+'txt','r')
file.readlines()
# Out:
# [' \n',
#  'Sir P M sir is planning with his Army Chief and Security Advisor Good Move for betterment of Our Nation\n',
#  'The Ikari corp kindly asks you to make good use of the advisors purchased from them for the betterment of all of us\n',
#  'Today advisors rely on to serve their clientshere are our for choosing a digital partner\n',
#  'TFP now offers socially responsible investing through our investment management partner Betterment For Advisors \n',
#  'b AUM and m valuation for robo advisor Startup Betterment Gets  Million Valuation \n',
#  'She is an appointed Advisor who has been working the very issue that was being discussed at that moment for Womens betterment Petty WAPO\n',
#  'RT MichaelKitces So much for roboadvisors Robo Betterment raises another M of VC to expand its HUMAN advice \n',
#  'So much for roboadvisors Robo Betterment raises another M of VC to expand its HUMAN advice \n',
# ...

# %%
cnt
# Out:
# 0

# %%
a

# %%
l=[' ','asdfadfa','nmsl','asdfadf']

# %%
temp=open('strength+results.txt','r')

# %%
temp.readlines()
# Out:
# ['\tTranslation\tPositive\tNegative\tEmotionRationale\n',
#  'these the same people that be postin who got usaa bank of america navy fed lem me help u make some today foh\tthese the same people that be postin who got usa bank of america navy fed lem me help you make some today foh\t1\t-1\t these[0] the[0] same[0] people[0] that[0] be[0] postin[0] who[0] got[0] usaa/usa[0] bank[0] of[0] america[0] navy[0] fed[0] lem[0] me[0] help[0] u[0] make[0] some[0] today[0] foh[0] [[Sentence=-1,1=word max, 1-5]][[[1,-1 max of sentences]]]\n',
# ...

# %%
def extract(path):
    result=[]
    temp=open('strength+results.txt','r')
    for i in temp[1:]:
        re.
