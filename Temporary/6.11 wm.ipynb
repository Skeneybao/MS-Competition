# %%
import pandas as pd
import numpy as np
import json
import matplotlib.pyplot as plt
import re

from nltk.stem.snowball import SnowballStemmer
import nltk
from gensim.parsing.preprocessing import STOPWORDS
import gensim

stemmer = SnowballStemmer("english")

# %%
def unique(x):
    d={}
    for i in x:
        d[i]=d.get(i,0)+1
    return sorted(d.items(),key=lambda x: -x[1])

def find_kol(data,rank):
    user=[]
    for i in data:
        user.append(i['user_id'])
    user_d={}
    for i in user:
        user_d[i]=user_d.get(i,0)+1
    user_frequency=unique(user)
    kol_id=[i[0] for i in user_frequency[:rank]]
    kol_name=[]
    for j in kol_id:
        for i in data:
            if i['user_id']==j:
                kol_name.append(i['username'])
                break
    return kol_name

def unique_time(data):
    time=[]
    for i in data:
        time.append(i['timestamp'][:10])
    return sorted(unique(time),key=lambda x: x[0])

def exforeign(data):
    eng_data=[]
    for i in data:
        pos=i['text_html'].find('>')
        if 'lang="en"' in i['text_html'][:pos]:
            eng_data.append(i)
    return eng_data

def duplicate(data):
    result=[]
    text=[]
    for i in data:
        if i['text'] not in text:
            result.append(i)
            text.append(i['text'])
    return result

def remove_link(data):
    for x,i in enumerate(data):
        if '/' in i['text']:
            result = re.sub(r"(https|http)\S+", "", i['text'])
            #result=re.sub(r'(https|http)?:\/(\w|\.|\/|\?|\=|\&|\%)*\b','',i['text'])
            result = re.sub(r"\S+.com\S+", "", result)
            data[x]['text']=result
    return data

def remove_sign(data):
    for x,i in enumerate(data):
        # hash tag
        result=re.sub(r'#\S+', '', i['text'])
        # user mention
        #result=re.sub(r'#\S+', '', result)
        # emoji
        result=re.sub(r'[^\x00-\x7F]+', '', result)
        # html tags
        result=re.sub(r'<.*?>', '', result)
        # extra spaces
        result=re.sub(r' +', ' ', result)
        # punctuation
        from string import punctuation as punc
        result=re.sub('[{}]'.format(punc), '', result)
        data[x]['text']=result
    return data
        
def toword(data,stem=False):
    result=[]
    t=nltk.tokenize.TweetTokenizer(strip_handles=True, reduce_len=True)
    f=(stemmer.stem) if (stem) else (lambda x: x)
    for x,i in enumerate(data):
        temp=[f(j).lower() for j in t.tokenize(i['text'])\
              if j.isalnum() and f(j).lower() not in STOPWORDS]
        result.append(temp)
    return result#stemmer.stem(j)

def LDA(texts,topics=20,num_words=15):
    from gensim import corpora
    from gensim.models.ldamodel import LdaModel
    import pprint
    from operator import itemgetter
    dictionary = corpora.Dictionary(texts) 
    corpus = [dictionary.doc2bow(text) for text in texts]
    num_topics = topics #The number of topics that should be generated
    passes = 20
    lda = LdaModel(corpus,
              id2word=dictionary,
              num_topics=num_topics,
              passes=passes)
    pp = pprint.PrettyPrinter(indent=4)
    pp.pprint(lda.print_topics(num_words=num_words))
    lda.get_document_topics(corpus[0],minimum_probability=0.05,per_word_topics=False)
    pp.pprint(sorted(lda.get_document_topics(corpus[0],minimum_probability=0,per_word_topics=False),key=itemgetter(1),reverse=True))

# %%
data=[]
for j in range(1,7):
    try: #Wealth_Management2017-02.json
        temp=json.load(open('.\wm\Wealth_Management{}-{:02d}.json'.format(2017,j)))
        print(2017,j,len(temp))
        data+=temp
    except:
        break
# Out:
# 2017 1 8252
# 2017 2 8047
# 2017 3 8068
# 2017 4 8070
# 2017 5 8255
# 2017 6 8682

# %%
len(data)
# Out:
# 49374

# %%
import copy
data=exforeign(data)
data=duplicate(data)
data0=copy.deepcopy(data)
data=remove_link(data)
data=remove_sign(data)
#data=duplicate(data)

# %%
''' 
import statsmodels.api as sm
a=np.array([i[1] for i in datedist])
#plt.plot(np.diff(a))
plt.bar(range(41),sm.tsa.stattools.pacf(a))
'''
# Out:
# ' \nimport statsmodels.api as sm\na=np.array([i[1] for i in datedist])\n#plt.plot(np.diff(a))\nplt.bar(range(41),sm.tsa.stattools.pacf(a))\n'

# %%
print(len(data),len(data0))
# Out:
# 40991 40991

# %%
words=toword(data)
nstem=toword(data,stem=True)

# %%
for i in range(100): 
    print(data0[i]['text'])
    print(data[i]['text'])
    print(nstem[i])
    print(words[i])
    print()
# Out:
# High growth doesn't mean higher stock returnshttps://wi.st/2i50e76 #Videoblog #WealthManagement #CapitalAtRisk
# High growth doesnt mean higher stock returns
# ['high', 'growth', 'doesnt', 'mean', 'higher', 'stock', 'return']
# ['high', 'growth', 'doesnt', 'mean', 'higher', 'stock', 'returns']
#
# Future ready: Seismic moves for digital wealth management via @finplan by @FinTechie http://ow.ly/z4Hr307lzjd pic.twitter.com/wpAhD7Xolm
# Future ready Seismic moves for digital wealth management via finplan by FinTechie
# ['futur', 'readi', 'seismic', 'digit', 'wealth', 'manag', 'finplan', 'fintechi']
# ['future', 'ready', 'seismic', 'moves', 'digital', 'wealth', 'management', 'finplan', 'fintechie']
#
# Northland Wealth Management up for Four Family Wealth Report "made in Canada" https://hedgeaccordingly.com/2016/12/northland-wealth-management-up-for-four-family-wealth-report-made-in-canada-awards.html … #canada #housing #portfoliomanagers
# Northland Wealth Management up for Four Family Wealth Report made in Canada
# ['northland', 'wealth', 'manag', 'famili', 'wealth', 'report', 'canada']
# ['northland', 'wealth', 'management', 'family', 'wealth', 'report', 'canada']
#
# http://www.accountingsoftwareexperts.com  update-> Stocks: Affinity Wealth Management Buys 1803 Shares of NetSuite Inc. (N) http://ow.ly/xcw95087gFz
#  update Stocks Affinity Wealth Management Buys 1803 Shares of NetSuite Inc N
# ['updat', 'stock', 'affin', 'wealth', 'manag', 'buy', '1803', 'share', 'netsuit', 'n']
# ['update', 'stocks', 'affinity', 'wealth', 'management', 'buys', '1803', 'shares', 'netsuite', 'n']
#
# PODCAST: Pregame Show Presented by Ruedi Wealth Management  1-1-17 http://www.news-gazette.com/audio/2017-01-01/podcast-pregame-show-presented-ruedi-wealth-management-1-1-17.html … with your host @stevekelly7
# PODCAST Pregame Show Presented by Ruedi Wealth Management 1117 with your host stevekelly7
# ['podcast', 'pregam', 'present', 'ruedi', 'wealth', 'manag', '1117', 'host', 'stevekelli', '7']
# ['podcast', 'pregame', 'presented', 'ruedi', 'wealth', 'management', '1117', 'host', 'stevekelly', '7']
#
# Wealth Management could be done differently. Find out how http://buff.ly/2i5d0Tf  #CapitalAtRisk
# Wealth Management could be done differently Find out how
# ['wealth', 'manag', 'differ']
# ['wealth', 'management', 'differently']
#
# if You have the money please do AstroScience But me, No Money i change 2 Wealth Management, i sttill remember
# if You have the money please do AstroScience But me No Money i change 2 Wealth Management i sttill remember
# ['money', 'pleas', 'astrosci', 'money', 'chang', '2', 'wealth', 'manag', 'sttill', 'rememb']
# ['money', 'astroscience', 'money', 'change', '2', 'wealth', 'management', 'sttill', 'remember']
#
# Should you consider reducing exposure to low-volatility ETFs? Morgan Stanley Wealth Management offers suggestions http://bcove.me/5dhpzorf
# Should you consider reducing exposure to lowvolatility ETFs Morgan Stanley Wealth Management offers suggestions
# ['consid', 'reduc', 'exposur', 'lowvolatil', 'etf', 'morgan', 'stanley', 'wealth', 'manag', 'offer', 'suggest']
# ['consider', 'reducing', 'exposure', 'lowvolatility', 'etfs', 'morgan', 'stanley', 'wealth', 'management', 'offers', 'suggestions']
#
# Many of these challenges in wealth management are also felt by others. via @Stevewal63https://twitter.com/Capgemini/status/815539376432287745 …
# Many of these challenges in wealth management are also felt by others via Stevewal63
# ['mani', 'challeng', 'wealth', 'manag', 'felt', 'stevew', '63']
# ['challenges', 'wealth', 'management', 'felt', 'stevewal', '63']
#
# Integrated Wealth Management Has $694,000 Stake in Colgate-Palmolive Company $CL http://zpr.io/PqXCJ
# Integrated Wealth Management Has 694000 Stake in ColgatePalmolive Company CL
# ['integr', 'wealth', 'manag', '694000', 'stake', 'colgatepalmol', 'compani', 'cl']
# ['integrated', 'wealth', 'management', '694000', 'stake', 'colgatepalmolive', 'company', 'cl']
#
# Integrated Wealth Management Has $694,000 Stake in Colgate-Palmolive Company (CL) http://ift.tt/2hDRcwE
# Integrated Wealth Management Has 694000 Stake in ColgatePalmolive Company CL
# ['integr', 'wealth', 'manag', '694000', 'stake', 'colgatepalmol', 'compani', 'cl']
# ['integrated', 'wealth', 'management', '694000', 'stake', 'colgatepalmolive', 'company', 'cl']
#
# 3 Keys to #Wealth Management http://buff.ly/2iPLfxG  What does your advisor do for you?
# 3 Keys to Management What does your advisor do for you
# ['3', 'key', 'manag', 'doe', 'advisor']
# ['3', 'keys', 'management', 'advisor']
#
# Segment Wealth Management LLC Sells 293 Shares of Apple Inc. (AAPL) #wealth #makemoneyonline http://soco.space/FWaVRt
# Segment Wealth Management LLC Sells 293 Shares of Apple Inc AAPL
# ['segment', 'wealth', 'manag', 'llc', 'sell', '293', 'share', 'appl', 'aapl']
# ['segment', 'wealth', 'management', 'llc', 'sells', '293', 'shares', 'apple', 'aapl']
#
# HAPPY NEW YEAR from all of us at Caccese Wealth Management and Janney Montgomery Scott. Let's plan those New Year's Financial Resolutions. pic.twitter.com/WDeIhJwdMe
# HAPPY NEW YEAR from all of us at Caccese Wealth Management and Janney Montgomery Scott Lets plan those New Years Financial Resolutions
# ['happi', 'new', 'year', 'cacces', 'wealth', 'manag', 'janney', 'montgomeri', 'scott', 'let', 'plan', 'new', 'year', 'financi', 'resolut']
# ['happy', 'new', 'year', 'caccese', 'wealth', 'management', 'janney', 'montgomery', 'scott', 'lets', 'plan', 'new', 'years', 'financial', 'resolutions']
#
# 12,784 Shares in Chevron Corporation (CVX) Acquired by Cornerstone Wealth Management LLC http://ift.tt/2hZNEpA
# 12784 Shares in Chevron Corporation CVX Acquired by Cornerstone Wealth Management LLC
# ['12784', 'share', 'chevron', 'corpor', 'cvx', 'acquir', 'cornerston', 'wealth', 'manag', 'llc']
# ['12784', 'shares', 'chevron', 'corporation', 'cvx', 'acquired', 'cornerstone', 'wealth', 'management', 'llc']
#
# Do or die: Robo-advice & Psychometry. What drives wealth management winners in 2020?
# https://www.finextra.com/blogposting/13494/do-or-die-robo-advice-amp-psychometry-what-drives-wealth-management-winners-in-2020 … via @Finextra
# Do or die Roboadvice  Psychometry What drives wealth management winners in 2020
#  via Finextra
# ['die', 'roboadvic', 'psychometri', 'drive', 'wealth', 'manag', 'winner', '2020', 'finextra']
# ['die', 'roboadvice', 'psychometry', 'drives', 'wealth', 'management', 'winners', '2020', 'finextra']
#
# 12,784 Shares in Chevron Corporation $CVX Acquired by Cornerstone Wealth Management LLC http://zpr.io/PqXhs
# 12784 Shares in Chevron Corporation CVX Acquired by Cornerstone Wealth Management LLC
# ['12784', 'share', 'chevron', 'corpor', 'cvx', 'acquir', 'cornerston', 'wealth', 'manag', 'llc']
# ['12784', 'shares', 'chevron', 'corporation', 'cvx', 'acquired', 'cornerstone', 'wealth', 'management', 'llc']
#
# Hey John Lusher  thanks for the follow! Find our #company page on #Facebook, Paragon International Wealth Management.
# Hey John Lusher thanks for the follow Find our page on Paragon International Wealth Management
# ['hey', 'john', 'lusher', 'thank', 'follow', 'page', 'paragon', 'intern', 'wealth', 'manag']
# ['hey', 'john', 'lusher', 'thanks', 'follow', 'page', 'paragon', 'international', 'wealth', 'management']
#
# The Hidden Cost of #Digital Immaturity :
# TO GAIN VALUABLE YOUNG CLIENTS, #WEALTHMANAGEMENT MUST ADAPT. https://lnkd.in/ef7pa8v
# The Hidden Cost of Immaturity
# TO GAIN VALUABLE YOUNG CLIENTS MUST ADAPT
# ['hidden', 'cost', 'immatur', 'gain', 'valuabl', 'young', 'client', 'adapt']
# ['hidden', 'cost', 'immaturity', 'gain', 'valuable', 'young', 'clients', 'adapt']
#
# Imagine being a consultant for a wealth management firm and just telling people, like it's ok. https://twitter.com/kishan_devani/status/815628573159657472 …
# Imagine being a consultant for a wealth management firm and just telling people like its ok
# ['imagin', 'consult', 'wealth', 'manag', 'firm', 'tell', 'peopl', 'like', 'ok']
# ['imagine', 'consultant', 'wealth', 'management', 'firm', 'telling', 'people', 'like', 'ok']
#
# The #Scottrade / #TDAmeritrade #Merger is a great example of #WealthManagement sector consolidation: http://hubs.ly/H05J0Jv0  by @tmullen610pic.twitter.com/HQMx8pfDIb
# The  is a great example of sector consolidation by
# ['great', 'exampl', 'sector', 'consolid']
# ['great', 'example', 'sector', 'consolidation']
#
# What Can be Learned from 20 Years Tracking Wealth Management Trends http://ow.ly/g7Na307AmDs  @WFSULLIVAN3 #trend #tracking #research #finance
# What Can be Learned from 20 Years Tracking Wealth Management Trends WFSULLIVAN3
# ['learn', '20', 'year', 'track', 'wealth', 'manag', 'trend', 'wfsullivan', '3']
# ['learned', '20', 'years', 'tracking', 'wealth', 'management', 'trends', 'wfsullivan', '3']
#
# The top ten #trends in #WealthManagement in2017  - @capgemini https://www.capgemini.com/resources/top-ten-trends-in-wealth-management-2017 … via @WFSULLIVAN3 #fintech #roboadvisors
# The top ten in in2017  capgemini via WFSULLIVAN3
# ['in2017', 'capgemini', 'wfsullivan', '3']
# ['in2017', 'capgemini', 'wfsullivan', '3']
#
# Financial Advisor - Wealth Management Services - Virtual - Base $150k - OTE: $500k - Many Openings - http://dld.bz/fhMgD
# Financial Advisor  Wealth Management Services  Virtual  Base 150k  OTE 500k  Many Openings
# ['financi', 'advisor', 'wealth', 'manag', 'servic', 'virtual', 'base', '150k', 'ote', '500k', 'mani', 'open']
# ['financial', 'advisor', 'wealth', 'management', 'services', 'virtual', 'base', '150k', 'ote', '500k', 'openings']
#
# The Financial Literacy Crisis | Snow Garrett Wealth Management http://paper.li/dcolgren/1466950242?read=http%3A%2F%2Fwww.sg-wealth.com%2Fresource-center%2Flifestyle%2Fthe-financial-literacy-crisis%2F …
# The Financial Literacy Crisis  Snow Garrett Wealth Management
# ['financi', 'literaci', 'crisi', 'snow', 'garrett', 'wealth', 'manag']
# ['financial', 'literacy', 'crisis', 'snow', 'garrett', 'wealth', 'management']
#
# 5 megatrends that are reshaping wealth management: http://trib.al/F3vWxxP  | by @NexusStrategy
# 5 megatrends that are reshaping wealth management  by NexusStrategy
# ['5', 'megatrend', 'reshap', 'wealth', 'manag', 'nexusstrategi']
# ['5', 'megatrends', 'reshaping', 'wealth', 'management', 'nexusstrategy']
#
# or getting finically independent/wealth management. If you have any assets you get cut off. So you keep accounts under X amount
# or getting finically independentwealth management If you have any assets you get cut off So you keep accounts under X amount
# ['finic', 'independentwealth', 'manag', 'ani', 'asset', 'cut', 'account', 'x']
# ['getting', 'finically', 'independentwealth', 'management', 'assets', 'cut', 'accounts', 'x']
#
# FB - Facebook, Inc. (FB) Shares Bought by RKL Wealth Management LLC http://ow.ly/kwGc5086RMF
# FB  Facebook Inc FB Shares Bought by RKL Wealth Management LLC
# ['fb', 'facebook', 'fb', 'share', 'bought', 'rkl', 'wealth', 'manag', 'llc']
# ['fb', 'facebook', 'fb', 'shares', 'bought', 'rkl', 'wealth', 'management', 'llc']
#
# Don't assume outperformance is down to skill http://buff.ly/2hgmTAY  #Videoblog #WealthManagement #ETFs #CapitalAtRisk
# Dont assume outperformance is down to skill
# ['dont', 'assum', 'outperform', 'skill']
# ['dont', 'assume', 'outperformance', 'skill']
#
# Use a Balance Transfer Card for #CreditCard Consolidation http://buff.ly/2hBsX1T  #PersonalFinance #Money #WealthManagement
# Use a Balance Transfer Card for Consolidation
# ['use', 'balanc', 'transfer', 'card', 'consolid']
# ['use', 'balance', 'transfer', 'card', 'consolidation']
#
# Happy New Year!
# Global Wealth Management wishes you a happy and safe holiday with your friends and family :) pic.twitter.com/oqKJC9QD0Y
# Happy New Year
# Global Wealth Management wishes you a happy and safe holiday with your friends and family
# ['happi', 'new', 'year', 'global', 'wealth', 'manag', 'wish', 'happi', 'safe', 'holiday', 'friend', 'famili']
# ['happy', 'new', 'year', 'global', 'wealth', 'management', 'wishes', 'happy', 'safe', 'holiday', 'friends', 'family']
#
# Interview with H.E Ken Rinpoche about @TsemTulku Rinpoche
# https://www.youtube.com/watch?v=PK-09ocMk7Q …
# #wealthmanagement
# #openyourmind
# #evolution
# #zen
# #yogapic.twitter.com/PV3b6SyNiE
# Interview with HE Ken Rinpoche about TsemTulku Rinpoche
#
#
#
#
#
#
# ['interview', 'ken', 'rinpoch', 'tsemtulku', 'rinpoch']
# ['interview', 'ken', 'rinpoche', 'tsemtulku', 'rinpoche']
#
# What do Gaden monks think of @Tsemtulku Rinpoche?
# https://www.youtube.com/watch?v=CwG-agzwK24 …
# #wealthmanagement
# #openyourmind
# #evolution
# #zen
# #yoga
# #wisdompic.twitter.com/sLcWaqRMLI
# What do Gaden monks think of Tsemtulku Rinpoche
#
#
#
#
#
#
#
# ['gaden', 'monk', 'think', 'tsemtulku', 'rinpoch']
# ['gaden', 'monks', 'think', 'tsemtulku', 'rinpoche']
#
# High growth doesn't mean higher stock returnshttps://wi.st/2i1kf1a #Videoblog #WealthManagement #ETFs #CapitalAtRisk
# High growth doesnt mean higher stock returns
# ['high', 'growth', 'doesnt', 'mean', 'higher', 'stock', 'return']
# ['high', 'growth', 'doesnt', 'mean', 'higher', 'stock', 'returns']
#
# Facebook, Inc. $FB Shares Bought by RKL Wealth Management LLC http://zpr.io/PqN4u
# Facebook Inc FB Shares Bought by RKL Wealth Management LLC
# ['facebook', 'fb', 'share', 'bought', 'rkl', 'wealth', 'manag', 'llc']
# ['facebook', 'fb', 'shares', 'bought', 'rkl', 'wealth', 'management', 'llc']
#
# What the Gaden Tripa thinks of Tsem Tulku Rinpoche?
# https://www.youtube.com/watch?v=bS7wYF6B8kg …
# #wealthmanagement
# #openyourmind
# #evolution
# #zen
# #yoga
# #wisdompic.twitter.com/nlddT3Pzlu
# What the Gaden Tripa thinks of Tsem Tulku Rinpoche
#
#
#
#
#
#
#
# ['gaden', 'tripa', 'think', 'tsem', 'tulku', 'rinpoch']
# ['gaden', 'tripa', 'thinks', 'tsem', 'tulku', 'rinpoche']
#
# QUALCOMM Incorporated $QCOM is Mutual of Omaha Bank Wealth Management’s 6th Largest Position http://ift.tt/2is9dQy
# QUALCOMM Incorporated QCOM is Mutual of Omaha Bank Wealth Managements 6th Largest Position
# ['qualcomm', 'incorpor', 'qcom', 'mutual', 'omaha', 'bank', 'wealth', 'manag', '6th', 'largest', 'posit']
# ['qualcomm', 'incorporated', 'qcom', 'mutual', 'omaha', 'bank', 'wealth', 'managements', '6th', 'largest', 'position']
#
# QUALCOMM Incorporated $QCOM is Mutual of Omaha Bank Wealth Management’s 6th Largest Position http://www.dailypolitical.com/?p=868626
# QUALCOMM Incorporated QCOM is Mutual of Omaha Bank Wealth Managements 6th Largest Position
# ['qualcomm', 'incorpor', 'qcom', 'mutual', 'omaha', 'bank', 'wealth', 'manag', '6th', 'largest', 'posit']
# ['qualcomm', 'incorporated', 'qcom', 'mutual', 'omaha', 'bank', 'wealth', 'managements', '6th', 'largest', 'position']
#
# Do or die: Robo-advice & Psychometry What drives wealth management winners in 2020?  https://www.finextra.com/blogposting/13494/do-or-die-robo-advice-amp-psychometry-what-drives-wealth-management-winners-in-2020 …
# Do or die Roboadvice  Psychometry What drives wealth management winners in 2020
# ['die', 'roboadvic', 'psychometri', 'drive', 'wealth', 'manag', 'winner', '2020']
# ['die', 'roboadvice', 'psychometry', 'drives', 'wealth', 'management', 'winners', '2020']
#
# CIBC (Toronto ON): "Retail and Business Banking, Wealth Management and Capital Markets. we provide a… http://bit.ly/2iUXo8t  #retail #jobs
# CIBC Toronto ON Retail and Business Banking Wealth Management and Capital Markets we provide a
# ['cibc', 'toronto', 'retail', 'busi', 'bank', 'wealth', 'manag', 'capit', 'market', 'provid']
# ['cibc', 'toronto', 'retail', 'business', 'banking', 'wealth', 'management', 'capital', 'markets', 'provide']
#
# Location:Alberta Internal Wholesaler, Wealth Management Products (Calgary region) http://dlvr.it/N13FQ7
# LocationAlberta Internal Wholesaler Wealth Management Products Calgary region
# ['locationalberta', 'intern', 'wholesal', 'wealth', 'manag', 'product', 'calgari', 'region']
# ['locationalberta', 'internal', 'wholesaler', 'wealth', 'management', 'products', 'calgary', 'region']
#
# 9 reasons why you won't retire rich, and how you can go about changing that http://buff.ly/2hUHLti  #financialplanning #wealthmanagement
# 9 reasons why you wont retire rich and how you can go about changing that
# ['9', 'reason', 'whi', 'wont', 'retir', 'rich', 'chang']
# ['9', 'reasons', 'wont', 'retire', 'rich', 'changing']
#
# Curated morning news, Katevatis Wealth Management Daily is published!  http://bit.ly/1PBQa3x  #worldjuniors #vancouver
# Curated morning news Katevatis Wealth Management Daily is published
# ['curat', 'morn', 'news', 'katevati', 'wealth', 'manag', 'daili', 'publish']
# ['curated', 'morning', 'news', 'katevatis', 'wealth', 'management', 'daily', 'published']
#
# Thompstone Wealth Management Ltd
#
# Welcome to Thompstone Wealth Management Ltd, Financial Planning Specialists,... http://fb.me/1r8PjVekn
# Thompstone Wealth Management Ltd
#
#  to Thompstone Wealth Management Ltd Financial Planning Specialists
# ['thompston', 'wealth', 'manag', 'thompston', 'wealth', 'manag', 'financi', 'plan', 'specialist']
# ['thompstone', 'wealth', 'management', 'thompstone', 'wealth', 'management', 'financial', 'planning', 'specialists']
#
# Amgen Inc. $AMGN is Merriman Wealth Management LLC’s 2nd Largest Position http://zpr.io/PqNbY
# Amgen Inc AMGN is Merriman Wealth Management LLCs 2nd Largest Position
# ['amgen', 'amgn', 'merriman', 'wealth', 'manag', 'llcs', '2nd', 'largest', 'posit']
# ['amgen', 'amgn', 'merriman', 'wealth', 'management', 'llcs', '2nd', 'largest', 'position']
#
# Ghodsi at 360 #Wealth Management Group expects rising #interest #rates will result in a more normal... http://www.cnbc.com/2016/12/27/is-the-party-over-for-dividend-stocks.html …
# Ghodsi at 360 Management Group expects rising will result in a more normal
# ['ghodsi', '360', 'manag', 'group', 'expect', 'rise', 'result', 'normal']
# ['ghodsi', '360', 'management', 'group', 'expects', 'rising', 'result', 'normal']
#
# Hot off the press! http://Munnypot.com  is a true disruptor when it comes to wealth management and financial advi…http://www.munnypot.com
# Hot off the press is a true disruptor when to wealth management and financial advi
# ['hot', 'press', 'true', 'disruptor', 'wealth', 'manag', 'financi', 'advi']
# ['hot', 'press', 'true', 'disruptor', 'wealth', 'management', 'financial', 'advi']
#
# AI in Banking: RoboAdvisor and Beyond:  http://bit.ly/2ijmKZm
# #roboadvisors #fintech #WealthManagement #BigData #AI
# AI in Banking RoboAdvisor and Beyond
#
# ['ai', 'bank', 'roboadvisor']
# ['ai', 'banking', 'roboadvisor']
#
# #منتديات_المطاريد #عام | Business Analyst Wealth Management | http://ift.tt/2hYSiUB
#   Business Analyst Wealth Management
# ['busi', 'analyst', 'wealth', 'manag']
# ['business', 'analyst', 'wealth', 'management']
#
# Robo-Advisors Global Market Segmentation and Major Players Analysis 2022  http://www.einnews.com/pr_news/359087258/robo-advisors-global-market-segmentation-and-major-players-analysis-2022 … #fintech #roboadvisor #wealthmanagement
# RoboAdvisors Global Market Segmentation and Major Players Analysis 2022
# ['roboadvisor', 'global', 'market', 'segment', 'major', 'player', 'analysi', '2022']
# ['roboadvisors', 'global', 'market', 'segmentation', 'major', 'players', 'analysis', '2022']
#
# Alpha Omega Wealth Management LLC Continues to Hold Stake in Exxon #wealth #makemoneyonline http://soco.space/GRWs2 .pic.twitter.com/9lvnArmQ2V
# Alpha Omega Wealth Management LLC Continues to Hold Stake in Exxon
# ['alpha', 'omega', 'wealth', 'manag', 'llc', 'continu', 'hold', 'stake', 'exxon']
# ['alpha', 'omega', 'wealth', 'management', 'llc', 'continues', 'hold', 'stake', 'exxon']
#
# Happy 2017! Resolve to combat #FOMO (Fear of Missing Out). http://bit.ly/2fQEP0y  #lifeinsurance #wealthmanagement pic.twitter.com/l3QrfI8qr9
# Happy 2017 Resolve Fear of Missing Out
# ['happi', '2017', 'resolv', 'fear', 'miss']
# ['happy', '2017', 'resolve', 'fear', 'missing']
#
# Don't assume outperformance is down to skill http://wi.st/2hYHGbO  #Videoblog #WealthManagement #ETFs #CapitalAtRisk
# Dont assume outperformance is down to skill
# ['dont', 'assum', 'outperform', 'skill']
# ['dont', 'assume', 'outperformance', 'skill']
#
# Applications of robotics are being recognized in Wealth management industry #WMTrends2017 http://ow.ly/XDdX306T4eA pic.twitter.com/Byc2Q9241b
# Applications of robotics are being recognized in Wealth management industry
# ['applic', 'robot', 'recogn', 'wealth', 'manag', 'industri']
# ['applications', 'robotics', 'recognized', 'wealth', 'management', 'industry']
#
# The Future of Wealth Management Will Hinge on Technology http://ow.ly/2pP4307Als4  @AndreaSchlapia #wealth #tech #future
# The Future of Wealth Management Will Hinge on Technology AndreaSchlapia
# ['futur', 'wealth', 'manag', 'hing', 'technolog', 'andreaschlapia']
# ['future', 'wealth', 'management', 'hinge', 'technology', 'andreaschlapia']
#
# Internal Wholesaler, Wealth Management Products (Vancouver region): Manulife (Calgary):… http://bit.ly/2hYzBk1  #finance #jobs #job
# Internal Wholesaler Wealth Management Products Vancouver region Manulife Calgary
# ['intern', 'wholesal', 'wealth', 'manag', 'product', 'vancouv', 'region', 'manulif', 'calgari']
# ['internal', 'wholesaler', 'wealth', 'management', 'products', 'vancouver', 'region', 'manulife', 'calgary']
#
# Internal Wholesaler, Wealth Management Products (Calgary region): Manulife (Calgary): "Manulife… http://bit.ly/2hYGfXy  #finance #jobs #job
# Internal Wholesaler Wealth Management Products Calgary region Manulife Calgary Manulife
# ['intern', 'wholesal', 'wealth', 'manag', 'product', 'calgari', 'region', 'manulif', 'calgari', 'manulif']
# ['internal', 'wholesaler', 'wealth', 'management', 'products', 'calgary', 'region', 'manulife', 'calgary', 'manulife']
#
# Location:Alberta Internal Wholesaler, Wealth Management Products (Vancouver region) http://dlvr.it/N111Vw
# LocationAlberta Internal Wholesaler Wealth Management Products Vancouver region
# ['locationalberta', 'intern', 'wholesal', 'wealth', 'manag', 'product', 'vancouv', 'region']
# ['locationalberta', 'internal', 'wholesaler', 'wealth', 'management', 'products', 'vancouver', 'region']
#
# Internal Wholesaler, Wealth Management Products (Vancouver region): Manulife (Calgary):… http://bit.ly/2hYPPth  #younger #workplaces
# Internal Wholesaler Wealth Management Products Vancouver region Manulife Calgary
# ['intern', 'wholesal', 'wealth', 'manag', 'product', 'vancouv', 'region', 'manulif', 'calgari']
# ['internal', 'wholesaler', 'wealth', 'management', 'products', 'vancouver', 'region', 'manulife', 'calgary']
#
# Internal Wholesaler, Wealth Management Products (Calgary region): Manulife (Calgary):… http://bit.ly/2hYxGfq  #younger #workplaces
# Internal Wholesaler Wealth Management Products Calgary region Manulife Calgary
# ['intern', 'wholesal', 'wealth', 'manag', 'product', 'calgari', 'region', 'manulif', 'calgari']
# ['internal', 'wholesaler', 'wealth', 'management', 'products', 'calgary', 'region', 'manulife', 'calgary']
#
# No one can time the market consistently http://wi.st/2h5m3BX  #Videoblog #ETFs #WealthManagement #EvidenceInvesting #CapitalAtRisk
# No one can time the market consistently
# ['time', 'market', 'consist']
# ['time', 'market', 'consistently']
#
# Drop 88% Price: £6.12. Hardcover: Implementing the Wealth Management Index: Tools to Build Your Practice and ... http://tinyurl.com/zj2upre
# Drop 88 Price 612 Hardcover Implementing the Wealth Management Index Tools to Build Your Practice and
# ['drop', '88', 'price', '612', 'hardcov', 'implement', 'wealth', 'manag', 'index', 'tool', 'build', 'practic']
# ['drop', '88', 'price', '612', 'hardcover', 'implementing', 'wealth', 'management', 'index', 'tools', 'build', 'practice']
#
# Internal Wholesaler, Wealth Management Products (Vancouver region): Manulife (Calgary AB):… http://bit.ly/2hYwQiJ  #calgary #jobs #job
# Internal Wholesaler Wealth Management Products Vancouver region Manulife Calgary AB
# ['intern', 'wholesal', 'wealth', 'manag', 'product', 'vancouv', 'region', 'manulif', 'calgari', 'ab']
# ['internal', 'wholesaler', 'wealth', 'management', 'products', 'vancouver', 'region', 'manulife', 'calgary', 'ab']
#
# Internal Wholesaler, Wealth Management Products (Calgary region): Manulife (Calgary AB):… http://bit.ly/2hYM4UC  #calgary #jobs #job
# Internal Wholesaler Wealth Management Products Calgary region Manulife Calgary AB
# ['intern', 'wholesal', 'wealth', 'manag', 'product', 'calgari', 'region', 'manulif', 'calgari', 'ab']
# ['internal', 'wholesaler', 'wealth', 'management', 'products', 'calgary', 'region', 'manulife', 'calgary', 'ab']
#
# Internal Wholesaler, Wealth Management Products (Vancouver region): Manulife (Calgary) "Manulife… http://bit.ly/2hYzBk1  #canada #jobs #job
# Internal Wholesaler Wealth Management Products Vancouver region Manulife Calgary Manulife
# ['intern', 'wholesal', 'wealth', 'manag', 'product', 'vancouv', 'region', 'manulif', 'calgari', 'manulif']
# ['internal', 'wholesaler', 'wealth', 'management', 'products', 'vancouver', 'region', 'manulife', 'calgary', 'manulife']
#
# Internal Wholesaler, Wealth Management Products (Calgary region): Manulife (Calgary) "Manulife… http://bit.ly/2hYGfXy  #canada #jobs #job
# Internal Wholesaler Wealth Management Products Calgary region Manulife Calgary Manulife
# ['intern', 'wholesal', 'wealth', 'manag', 'product', 'calgari', 'region', 'manulif', 'calgari', 'manulif']
# ['internal', 'wholesaler', 'wealth', 'management', 'products', 'calgary', 'region', 'manulife', 'calgary', 'manulife']
#
# Watch our short video on #GCC #WealthManagement...
# https://youtu.be/QqJiNYQiWKk
# Watch our short video on
#
# ['watch', 'short', 'video']
# ['watch', 'short', 'video']
#
# Happy New Year from all the team at Beacon Wealth-Management and Jeffrey Mills Solicitors. http://fb.me/2TzpUFXNU
# Happy New Year from all the team at Beacon WealthManagement and Jeffrey Mills Solicitors
# ['happi', 'new', 'year', 'team', 'beacon', 'wealthmanag', 'jeffrey', 'solicitor']
# ['happy', 'new', 'year', 'team', 'beacon', 'wealthmanagement', 'jeffrey', 'mills', 'solicitors']
#
# Wishing everyone a healthy and happy 2017!  From all of us at Tilton Wealth Management. pic.twitter.com/0RvtuR1z59
# Wishing everyone a healthy and happy 2017 From all of us at Tilton Wealth Management
# ['wish', 'everyon', 'healthi', 'happi', '2017', 'tilton', 'wealth', 'manag']
# ['wishing', 'healthy', 'happy', '2017', 'tilton', 'wealth', 'management']
#
# Happy New Year from all at Sheards Wealth Management! pic.twitter.com/CEPqOEbdv5
# Happy New Year from all at Sheards Wealth Management
# ['happi', 'new', 'year', 'sheard', 'wealth', 'manag']
# ['happy', 'new', 'year', 'sheards', 'wealth', 'management']
#
# Hey Kenny Blakey thanks for the follow! Find our #company page on #Facebook, Paragon International Wealth Management.
# Hey Kenny Blakey thanks for the follow Find our page on Paragon International Wealth Management
# ['hey', 'kenni', 'blakey', 'thank', 'follow', 'page', 'paragon', 'intern', 'wealth', 'manag']
# ['hey', 'kenny', 'blakey', 'thanks', 'follow', 'page', 'paragon', 'international', 'wealth', 'management']
#
# The biggest enemy of an investor is themselves! http://wi.st/2i8aBHt  #Videoblog #ETFs #WealthManagement #EvidenceInvesting #CapitalAtRisk
# The biggest enemy of an investor is themselves
# ['biggest', 'enemi', 'investor', 'themselv']
# ['biggest', 'enemy', 'investor']
#
# High growth doesn't mean higher stock returnshttps://wi.st/2i5kJ3C #Videoblog #WealthManagement #ETFs #CapitalAtRisk
# High growth doesnt mean higher stock returns
# ['high', 'growth', 'doesnt', 'mean', 'higher', 'stock', 'return']
# ['high', 'growth', 'doesnt', 'mean', 'higher', 'stock', 'returns']
#
# Happy New Year from Pinnacle Wealth Management! Hope 2017 is a great year! pic.twitter.com/fnD9K7YUHa
# Happy New Year from Pinnacle Wealth Management Hope 2017 is a great year
# ['happi', 'new', 'year', 'pinnacl', 'wealth', 'manag', 'hope', '2017', 'great', 'year']
# ['happy', 'new', 'year', 'pinnacle', 'wealth', 'management', 'hope', '2017', 'great', 'year']
#
# Happy New Year from us all at Hartey Wealth Management! pic.twitter.com/eJkEffQQNN
# Happy New Year from us all at Hartey Wealth Management
# ['happi', 'new', 'year', 'hartey', 'wealth', 'manag']
# ['happy', 'new', 'year', 'hartey', 'wealth', 'management']
#
# Happy New Years Day from All at Canaccord Genuity Wealth Management
# Happy New Years Day from All at Canaccord Genuity Wealth Management
# ['happi', 'new', 'year', 'day', 'canaccord', 'genuiti', 'wealth', 'manag']
# ['happy', 'new', 'years', 'day', 'canaccord', 'genuity', 'wealth', 'management']
#
# Wishing you all the best for a happy, healthy and prosperous 2017!
#
# The Lougheed Wealth Management Team pic.twitter.com/U2TFTtFKNY
# Wishing you all the best for a happy healthy and prosperous 2017
#
# The Lougheed Wealth Management Team
# ['wish', 'best', 'happi', 'healthi', 'prosper', '2017', 'loughe', 'wealth', 'manag', 'team']
# ['wishing', 'best', 'happy', 'healthy', 'prosperous', '2017', 'lougheed', 'wealth', 'management', 'team']
#
# Paraplanner (Wealth Management) - Exeter - Anonymous #JobsInExeter #ExeterJobs http://jobs.localworld.co.uk/job/504782166/paraplanner-wealth-management-/?TrackID=170 …
# Paraplanner Wealth Management  Exeter  Anonymous
# ['paraplann', 'wealth', 'manag', 'exet', 'anonym']
# ['paraplanner', 'wealth', 'management', 'exeter', 'anonymous']
#
# With ordinary talent and extraordinary perseverance, all things are attainable. - Thomas Foxwell Buxton #wealthmanagement #estateplanning
# With ordinary talent and extraordinary perseverance all things are attainable  Thomas Foxwell Buxton
# ['ordinari', 'talent', 'extraordinari', 'persever', 'thing', 'attain', 'thoma', 'foxwel', 'buxton']
# ['ordinary', 'talent', 'extraordinary', 'perseverance', 'things', 'attainable', 'thomas', 'foxwell', 'buxton']
#
# To see a “wealth management” advertisement makes me want to have wealth to manage.
# #mimesis
# To see a wealth management advertisement makes me want to have wealth to manage
#
# ['wealth', 'manag', 'advertis', 'want', 'wealth', 'manag']
# ['wealth', 'management', 'advertisement', 'makes', 'want', 'wealth', 'manage']
#
# I hope everyone's net worth exceeds a million plus this year.
#
# Yours truly,
#
# Vice President of Wealth Management at Goldman Sachs
# I hope everyones net worth exceeds a million plus this year
#
# Yours truly
#
# Vice President of Wealth Management at Goldman Sachs
# ['hope', 'everyon', 'net', 'worth', 'exceed', 'million', 'plus', 'year', 'truli', 'vice', 'presid', 'wealth', 'manag', 'goldman', 'sach']
# ['hope', 'everyones', 'net', 'worth', 'exceeds', 'million', 'plus', 'year', 'truly', 'vice', 'president', 'wealth', 'management', 'goldman', 'sachs']
#
# Stocks: Home Depot Inc. (HD) Position Held by the Alliance Wealth Management Group #HomeImprovement http://dld.bz/fqPR3
# Stocks Home Depot Inc HD Position Held by the Alliance Wealth Management Group
# ['stock', 'home', 'depot', 'hd', 'posit', 'held', 'allianc', 'wealth', 'manag', 'group']
# ['stocks', 'home', 'depot', 'hd', 'position', 'held', 'alliance', 'wealth', 'management', 'group']
#
# Don't suppress DS practitioners!
# http://bit.ly/2fknOLL
# #wealthmanagement
# #openyourmind
# #evolution
# #zen
# #yoga
# #wisdom
# #tsemtulku
# #kecharapic.twitter.com/3IIKX7lduK
# Dont suppress DS practitioners
#
#
#
#
#
#
#
#
#
# ['dont', 'suppress', 'ds', 'practition']
# ['dont', 'suppress', 'ds', 'practitioners']
#
# Don't suppress DS practitioners!
# http://bit.ly/2fknOLL
# #wealthmanagement
# #openyourmind
# #evolution
# #zen
# #yoga
# #wisdom
# #tsemtulku
# #kecharapic.twitter.com/lbWXPuz84o
# Dont suppress DS practitioners
#
#
#
#
#
#
#
#
#
# ['dont', 'suppress', 'ds', 'practition']
# ['dont', 'suppress', 'ds', 'practitioners']
#
# Don't suppress DS practitioners!
# http://bit.ly/2fknOLL
# #wealthmanagement
# #openyourmind
# #evolution
# #zen
# #yoga
# #wisdom
# #tsemtulku
# #kecharapic.twitter.com/FzbtJxJ5hl
# Dont suppress DS practitioners
#
#
#
#
#
#
#
#
#
# ['dont', 'suppress', 'ds', 'practition']
# ['dont', 'suppress', 'ds', 'practitioners']
#
# Raksha Wealth Management Services wishes you all a very Happy New Year 2017 pic.twitter.com/u4xhnsKBwu
# Raksha Wealth Management Services wishes you all a very Happy New Year 2017
# ['raksha', 'wealth', 'manag', 'servic', 'wish', 'veri', 'happi', 'new', 'year', '2017']
# ['raksha', 'wealth', 'management', 'services', 'wishes', 'happy', 'new', 'year', '2017']
#
# Latest News from Priority1 Wealth Management Group - http://eepurl.com/cvNLr5
# Latest News from Priority1 Wealth Management Group
# ['latest', 'news', 'prioriti', '1', 'wealth', 'manag', 'group']
# ['latest', 'news', 'priority', '1', 'wealth', 'management', 'group']
#
# Should you consider increasing exposure to Japan equities? Morgan Stanley Wealth Management offers suggestions
#  http://scl.bz/zz710rw
# Should you consider increasing exposure to Japan equities Morgan Stanley Wealth Management offers suggestions
#
# ['consid', 'increas', 'exposur', 'japan', 'equiti', 'morgan', 'stanley', 'wealth', 'manag', 'offer', 'suggest']
# ['consider', 'increasing', 'exposure', 'japan', 'equities', 'morgan', 'stanley', 'wealth', 'management', 'offers', 'suggestions']
#
# RT HBMTechnology: 64 robo advisors in Europe – five cracked the €100m euro mark http://bit.ly/2idkIxA  #fintech #wealthmanagement
# RT HBMTechnology 64 robo advisors in Europe five cracked the 100m euro mark
# ['rt', 'hbmtechnolog', '64', 'robo', 'advisor', 'europ', 'crack', '100m', 'euro', 'mark']
# ['rt', 'hbmtechnology', '64', 'robo', 'advisors', 'europe', 'cracked', '100m', 'euro', 'mark']
#
# Cyber terrorism: a defining issue of our time #wealthmanagement https://www.finextra.com/videoarticle/1431/cyber-terrorism-a-defining-issue-of-our-time?utm_medium=rss&amp;utm_source=finextrafeed …
# Cyber terrorism a defining issue of our time
# ['cyber', 'terror', 'defin', 'issu', 'time']
# ['cyber', 'terrorism', 'defining', 'issue', 'time']
#
# what's wrong with billionaires? Is it there job creation, wealth management, intelligence or use of laws that create wealth?
# whats wrong with billionaires Is it there job creation wealth management intelligence or use of laws that create wealth
# ['wrong', 'billionair', 'job', 'creation', 'wealth', 'manag', 'intellig', 'use', 'law', 'creat', 'wealth']
# ['whats', 'wrong', 'billionaires', 'job', 'creation', 'wealth', 'management', 'intelligence', 'use', 'laws', 'create', 'wealth']
#
# Stocks: Home Depot Inc. (HD) Position Held by the Alliance Wealth Management Group http://ift.tt/2ikxc66
# Stocks Home Depot Inc HD Position Held by the Alliance Wealth Management Group
# ['stock', 'home', 'depot', 'hd', 'posit', 'held', 'allianc', 'wealth', 'manag', 'group']
# ['stocks', 'home', 'depot', 'hd', 'position', 'held', 'alliance', 'wealth', 'management', 'group']
#
# The #HongKong Wealth Management 2017 Report #Citi #Standardchartered #DBS http://www.thedragonbanker.com/3/post/2016/12/the-hong-kong-wealth-management-2017-report.html …
# The Wealth Management 2017 Report
# ['wealth', 'manag', '2017', 'report']
# ['wealth', 'management', '2017', 'report']
#
# Altria Group $MO Shares Sold by Lyons Wealth Management LLC. http://ift.tt/2hEWsmW
# Altria Group MO Shares Sold by Lyons Wealth Management LLC
# ['altria', 'group', 'mo', 'share', 'sold', 'lyon', 'wealth', 'manag', 'llc']
# ['altria', 'group', 'mo', 'shares', 'sold', 'lyons', 'wealth', 'management', 'llc']
#
# Altria Group $MO Shares Sold by Lyons Wealth Management LLC. http://www.dailypolitical.com/?p=868426
# Altria Group MO Shares Sold by Lyons Wealth Management LLC
# ['altria', 'group', 'mo', 'share', 'sold', 'lyon', 'wealth', 'manag', 'llc']
# ['altria', 'group', 'mo', 'shares', 'sold', 'lyons', 'wealth', 'management', 'llc']
#
# Wishing you a safe and festive New Year's Eve!  From all of us at Tilton Wealth Management pic.twitter.com/HaBQaW60fr
# Wishing you a safe and festive New Years Eve From all of us at Tilton Wealth Management
# ['wish', 'safe', 'festiv', 'new', 'year', 'eve', 'tilton', 'wealth', 'manag']
# ['wishing', 'safe', 'festive', 'new', 'years', 'eve', 'tilton', 'wealth', 'management']
#
# Use a Balance Transfer Card for #CreditCard Consolidation http://buff.ly/2ijARSi  #PersonalFinance #Money #WealthManagement
# Use a Balance Transfer Card for Consolidation
# ['use', 'balanc', 'transfer', 'card', 'consolid']
# ['use', 'balance', 'transfer', 'card', 'consolidation']
#
# Point View's Dietze Offers Top Picks for 2017: Point View Wealth Management Founder, President, and Chief… http://m.tbnn.it/N0tDh3
# Point Views Dietze Offers Top Picks for 2017 Point View Wealth Management Founder President and Chief
# ['point', 'view', 'dietz', 'offer', 'pick', '2017', 'point', 'view', 'wealth', 'manag', 'founder', 'presid', 'chief']
# ['point', 'views', 'dietze', 'offers', 'picks', '2017', 'point', 'view', 'wealth', 'management', 'founder', 'president', 'chief']
#
# Alpha Omega Wealth Management LLC Continues to Hold Stake in Exxon Mobil Corporation $XOM http://ift.tt/2iQNYHc
# Alpha Omega Wealth Management LLC Continues to Hold Stake in Exxon Mobil Corporation XOM
# ['alpha', 'omega', 'wealth', 'manag', 'llc', 'continu', 'hold', 'stake', 'exxon', 'mobil', 'corpor', 'xom']
# ['alpha', 'omega', 'wealth', 'management', 'llc', 'continues', 'hold', 'stake', 'exxon', 'mobil', 'corporation', 'xom']
#
# Alpha Omega Wealth Management LLC Continues to Hold Stake in Exxon Mobil Corporation $XOM http://www.dailypolitical.com/?p=868392
# Alpha Omega Wealth Management LLC Continues to Hold Stake in Exxon Mobil Corporation XOM
# ['alpha', 'omega', 'wealth', 'manag', 'llc', 'continu', 'hold', 'stake', 'exxon', 'mobil', 'corpor', 'xom']
# ['alpha', 'omega', 'wealth', 'management', 'llc', 'continues', 'hold', 'stake', 'exxon', 'mobil', 'corporation', 'xom']

# %% [markdown]
# ### Aspect-terms Extraction

# %%
texts=[' '.join(i) for i in nstem]

# %%
import spacy
nlp = spacy.load("en_core_web_sm")

# %%
temp=nlp(texts[0])
temp
# Out:
# high growth doesnt mean higher stock return

# %%
type(temp[0])
# Out:
# spacy.tokens.token.Token

# %%
for i in temp:
    print(i.tag_,i.shape_)
# Out:
# JJ xxxx
# NN xxxx
# VBZ xxxx
# RB xx
# VB xxxx
# JJR xxxx
# NN xxxx
# NN xxxx

# %%
def word_extraction(texts):
    extracted_words = []
    for i in texts:
        doc = nlp(i)
        for token in doc:
            if token.tag_=='NN' and token.shape_ != 'x' and token.shape_ != 'xx' and token.shape_ != 'xxx':
                extracted_words.append(token.lemma_)
    return extracted_words
        
extract_words=word_extraction(texts)

# %%
model = gensim.models.KeyedVectors.load_word2vec_format('./pretrained/GoogleNews-vectors-negative300.bin', binary=True)

# %%
'''
def word2vec(words):
    # removal of words which not present in the word2vec model vocabulary. (wrongly spelled)
    filtered_terms = []
    for i in range(len(words)):
        correct_words = [token for token in words[i] if token in model.vocab]
        if len(correct_words) > 0 :
            filtered_terms.extend(correct_words)
    #converting words into vector
    vector_of_terms = []
    filtered_terms=list(set(filtered_terms))
    for i in range(len(filtered_terms)):
        vector_of_terms.append(model.get_vector(filtered_terms[i]))
    return vector_of_terms,filtered_terms
'''
def word2vec(words):
    # removal of words which not present in the word2vec model vocabulary. (wrongly spelled)
    filtered_terms = [i for i in words if i in model.vocab]
    #converting words into vector
    vector_of_terms = []
    filtered_terms=list(set(filtered_terms))
    for i in range(len(filtered_terms)):
        vector_of_terms.append(model.get_vector(filtered_terms[i]))
    return vector_of_terms,filtered_terms

# %%
aspect=['price','service','selfservice','product','digital','robot','robo']

# %%
def topic_words(aspect):
    vec=word2vec(extract_words)
    aspect_vec=np.array([model.get_vector(i) for i in aspect])
    result=[]
    for i in range(len(aspect)):
        temp=1-vec[0]@aspect_vec[i]/np.linalg.norm(aspect_vec[i])/np.linalg.norm(vec[0],axis=1)
        word=[vec[1][i] for i in np.argsort(temp)[:100]]
        result.append(word)
    return result

# %%
candidate=topic_words(aspect)

# %%
print(candidate)
# Out:
# [['price', 'premium', 'stock', 'cost', 'market', 'discount', 'sell', 'tariff', 'buyer', 'sale', 'seller', 'demand', 'markup', 'rate', 'rent', 'cent', 'dividend', 'wage', 'share', 'investor', 'benchmark', 'dollar', 'premia', 'level', 'profit', 'import', 'offer', 'trade', 'costco', 'worth', 'commod', 'broker', 'threshold', 'liter', 'minimum', 'auction', 'coupon', 'rental', 'supplier', 'payment', 'marketwatch', 'target', 'payout', 'aapl', 'output', 'index', 'cash', 'yield', 'takeup', 'preorder', 'tuition', 'trader', 'sector', 'fetch', 'date', 'fare', 'size', 'dealer', 'cusip', 'outlook', 'cashflow', 'fuel', 'increment', 'forecast', 'goog', 'ration', 'petroleum', 'highend', 'peso', 'ratio', 'deal', 'penney', 'premarket', 'hike', 'percent', 'longrun', 'hsbc', 'option', 'ownership', 'standard', 'lowcost', 'portfolio', 'current', 'q3', 'pump', 'debt', 'distributor', 'stake', 'maker', 'refund', 'ripoff', 'bread', 'margin', 'budget', 'afford', 'invest', 'number', 'analyst', 'multitrillion', 'trend'], ['servic', 'network', 'access', 'serv', 'portal', 'care', 'mail', 'provi', 'broadband', 'transit', 'staff', 'traffic', 'work', 'turnkey', 'prayer', 'engin', 'payment', 'function', 'phone', 'support', 'telemarket', 'program', 'product', 'charter', 'rental', 'mission', 'internet', 'user', 'branch', 'takeup', 'expeditor', 'address', 'unit', 'site', 'station', 'travel', 'taxi', 'comfort', 'platform', 'sector', 'honor', 'fare', 'client', 'model', 'connect', 'partnership', 'discount', 'gateway', 'membership', 'meal', 'forum', 'lowcost', 'search', 'trust', 'drive', 'content', 'base', 'line', 'locat', 'institution', 'flight', 'peopl', 'center', 'managementand', 'relationship', 'contractor', 'journey', 'endeavor', 'comput', 'cord', 'domain', 'beta', 'help', 'speech', 'public', 'toll', 'onlin', 'secur', 'supplier', 'offer', 'pioneer', 'experienc', 'feedback', 'pilot', 'breakfast', 'channel', 'process', 'roll', 'area', 'cost', 'rockford', 'resend', 'debt', 'premium', 'today', 'agreement', 'administr', 'cashless', 'email', 'news'], ['chatbot', 'onlin', 'technol', 'technolog', 'checkout', 'multichannel', 'multifactor', 'portal', 'costco', 'cern', 'cashless', 'internet', 'appli', 'user', 'turnkey', 'backend', 'merck', 'manual', 'comput', 'servic', 'managementand', 'debit', 'download', 'dashboard', 'appl', 'transact', 'ensur', 'audio', 'click', 'secur', 'access', 'print', 'ebook', 'digi', 'custo', 'insur', 'custom', 'spreadsheet', 'payment', 'config', 'stor', 'easi', 'broadcom', 'fintech', 'expeditor', 'automat', 'applic', 'techn', 'data', 'exelon', 'filter', 'orion', 'symantec', 'locat', 'revenu', 'informat', 'fedex', 'fingerprint', 'coupon', 'veri', 'machin', 'requir', 'highend', 'email', 'specif', 'content', 'tailor', 'walmart', 'explor', 'saver', 'select', 'lowcost', 'cynthia', 'standard', 'rental', 'merchant', 'tool', 'percept', 'gmail', 'photobucket', 'mail', 'websit', 'untap', 'arca', 'effortless', 'catalog', 'updat', 'payer', 'experienc', 'chat', 'featur', 'mangement', 'indus', 'product', 'cater', 'manag', 'avail', 'function', 'broadband', 'video'], ['product', 'brand', 'portfolio', 'user', 'market', 'line', 'technolog', 'platform', 'content', 'design', 'ensur', 'premium', 'catalog', 'supplier', 'segment', 'distributor', 'exelon', 'beta', 'managementand', 'turnkey', 'launch', 'fintech', 'client', 'tool', 'merck', 'competitor', 'ebook', 'backend', 'item', 'growth', 'flagship', 'startup', 'onlin', 'disruptor', 'technol', 'q3', 'exhibitor', 'data', 'channel', 'asset', 'liquid', 'concept', 'broaden', 'model', 'trademark', 'techn', 'store', 'sofi', 'process', 'custom', 'core', 'research', 'manufactur', 'placement', 'engin', 'filter', 'markup', 'domain', 'investor', 'breed', 'buyer', 'webinar', 'flavor', 'site', 'version', 'expand', 'import', 'ecosystem', 'fruit', 'tester', 'brew', 'logo', 'lineup', 'demo', 'fedex', 'highend', 'dealer', 'informat', 'code', 'coupon', 'redesign', 'type', 'skin', 'unit', 'supplement', 'costco', 'seller', 'semiconductor',  ...

# %%
s=str(candidate)
s=re.sub(r'\', \'',' ',s)
s=re.sub(r'\'\], \[\'',' \n ',s)

# %%
print(s)
# Out:
# [['price premium stock cost market discount sell tariff buyer sale seller demand markup rate rent cent dividend wage share investor benchmark dollar premia level profit import offer trade costco worth commod broker threshold liter minimum auction coupon rental supplier payment marketwatch target payout aapl output index cash yield takeup preorder tuition trader sector fetch date fare size dealer cusip outlook cashflow fuel increment forecast goog ration petroleum highend peso ratio deal penney premarket hike percent longrun hsbc option ownership standard lowcost portfolio current q3 pump debt distributor stake maker refund ripoff bread margin budget afford invest number analyst multitrillion trend
#  servic network access serv portal care mail provi broadband transit staff traffic work turnkey prayer engin payment function phone support telemarket program product charter rental mission internet user branch takeup expeditor address unit site station travel taxi comfort platform sector honor fare client model connect partnership discount gateway membership meal forum lowcost search trust drive content base line locat institution flight peopl center managementand relationship contractor journey endeavor comput cord domain beta help speech public toll onlin secur supplier offer pioneer experienc feedback pilot breakfast channel process roll area cost rockford resend debt premium today agreement administr cashless email news
#  chatbot onlin technol technolog checkout multichannel multifactor portal costco cern cashless internet appli user turnkey backend merck manual comput servic managementand debit download dashboard appl transact ensur audio click secur access print ebook digi custo insur custom spreadsheet payment config stor easi broadcom fintech expeditor automat applic techn data exelon filter orion symantec locat revenu informat fedex fingerprint coupon veri machin requir highend email specif content tailor walmart explor saver select lowcost cynthia standard rental merchant tool percept gmail photobucket mail websit untap arca effortless catalog updat payer experienc chat featur mangement indus product cater manag avail function broadband video
#  product brand portfolio user market line technolog platform content design ensur premium catalog supplier segment distributor exelon beta managementand turnkey launch fintech client tool merck competitor ebook backend item growth flagship startup onlin disruptor technol q3 exhibitor data channel asset liquid concept broaden model trademark techn store sofi process custom core research manufactur placement engin filter markup domain investor breed buyer webinar flavor site version expand import ecosystem fruit tester brew logo lineup demo fedex highend dealer informat code coupon redesign type skin unit supplement costco seller semiconductor booth percept project risk revenu portal price program megatrend vector crop quarter
#  multichannel digi audio print video broadband music format internet content vinyl copyright download studio technol camera media onlin technolog ebook tech engin catalog takeup semiconductor comput turnkey broadcom network fingerprint medium advent highend channel color homebuy photobucket movi cashless coupon embed cyber edit photo microchip laser pioneer q3 adult user symantec document portal hybrid mass stream brand access custom ident design platform revolution film creation sound untap theater compress demo generalist vector managementand radio text data motion gender rental revenu fintech ecosystem explor screen dementia featur multifactor bullion adulthood percept placement space techn playlist adapt matrix checkout experienc premium handhold
#  robot robo cube chatbot stryker microchip penguin tech rocket monster orbit camera laser giant demo cage drone technol brain space destruct cone keyboard panda armor coaster snake planet human object disruptor mascot comput descript cartoon hybrid video truck invent float venturi screenshot rope tractor evil tester ghost instrument medic screen unit portal appli mission sleuth design dude barker super apollo pizza angel thermo train cyber scientist tool dame tunnel realm machin tower trivia bike digi unlock metal electron ship room earth teaser improv teamwork startup manual weapon ident dashboard craft outsmart classroom bomb compass mindless soldier automat trow rubber technolog
#  robo robot monster telemarket comput chatbot crank destruct hybrid derek sound machin stryker teaser demo digi dude hack barker ripoff phone typo drone apollo fresno shit tech trick invent disruptor penguin roger cube witless giant tweet freakout echo armor frazier automat descript ghost cynthia laser spin crap babi joke mindless discov baxter custom bollock choos rocket bitch asian suck lgbt microchip cage highend super doom specif mayb cheryl dexter appli video snake piss cyber keyboard technolog changer mess honolulu experienc cartoon whippin cetera sleuth femal aapl evil veri moder roll junk classic rooster retweet hashtag talon columbus watson halt planet']]
