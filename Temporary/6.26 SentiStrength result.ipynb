# %%
import os
import time

import pandas as pd
import numpy as np
import json
import matplotlib.pyplot as plt
import re
import matplotlib

from nltk.stem.snowball import SnowballStemmer
import nltk
import gensim
import spacy

import matplotlib.cm as cm

stemmer = SnowballStemmer("english")
nlp = spacy.load("en_core_web_sm")

# %%
from tool import *
# unique(x)
# find_kol(data,rank)
# unique_time(data)
# exforeign(data)
# duplicate(data)
# remove_link(data)
# remove_sign(data)
# total_clean(indata)
# toword(data,stem=False,stop=True)
# get_words(url), pos, neg, opinion
# debug2(sentence)
# month(start,end)
# search(data,keywords)
# LDA(data, topics, words,otherwords)
# NMF(data,topics,words,otherwords)

# %%
otherwords={'hi','wealthfront','betterment','robo','roboadvisor','roboadvisors',
            'wealthfronts','happy','im','vs','thanks','like','love','yet','yeah','via','want','one','a','an','advisor',
            'advisors','dont','didnt','financial','investment','wealth','finance'}

otherwords=otherwords.union(set(gensim.parsing.preprocessing.STOPWORDS))

# %%
m=month('2017-06','2020-05')
root_path=os.getcwd()
category=os.listdir(root_path+'\\SentiStrength\\final')
category
# Out:
# ['Bank Brokerage', 'Discount Brokerage', 'Full Brokerage', 'Robo Advisor']

# %%
def read_data(path):
    structure=list(os.walk(path))
    summary=[]
    for i in structure:
        if not i[1]:
            temp=[]
            for j in i[2]:
                #print(i[0]+'\\'+j)
                #temp.append([(x['text'],x['positive'],x['negative']) for x in anothertemp])
                if j=='TDAmeritrade2017-07.json': 
                    temp.append([])
                if j=='Wealthfront2017-08.json':
                    temp.append([])
                temp.append([{'text':x['text'],'positive':x['positive'],'negative':x['negative']} for x in json.load(open(i[0]+'\\'+j))[:-1]])
            summary.append(temp)
    #return summary
    def lsum(list_):
        result=[]
        num=len(list_[0])
        for i in range(num):
            temp=[]
            for j in list_:
                temp+=j[i]
            result.append(temp)
        return result
    return lsum(summary)

# %%
#list(os.walk(root_path+'\\SentiStrength\\final\\Bank Brokerage'))

# %%
metadata=[]
for i in category:
    metadata.append([])
    metadata[-1]=read_data(root_path+'\\SentiStrength\\final\\'+i)

# %%
for i in metadata:
    print(len(i))
# Out:
# 36
# 36
# 36
# 36

# %%
msdata=[]
temp=os.listdir(root_path+'\\MS_weekly')
for i in temp:
    msdata.append(total_clean(json.load(open(root_path+'\\MS_weekly\\'+i)))[:-1])

# %%
for i in msdata:
    print(len(i))
# Out:
# 4573
# 4964
# 4673
# 4889
# 4176
# 5006
# 5374
# 5126
# 3959
# 3996
# 3604
# 5129
# 4839
# 4095
# 3973
# 5671
# 4345
# 3860
# 3627
# 3467
# 3541
# 4300
# 3987
# 5316
# 3796
# 3263
# 3160
# 3563
# 3453
# 3429
# 3078
# 3414
# 3825
# 4729
# 4456
# 4504

# %%
def subanalyze(data,keywords): # data hierarchy: months*(text,score)*piece
    pospolarity=[]
    negpolarity=[]
    freq=[]
    for k in data:
        pos=0
        neg=0
        count=0
        for i in k:
            for j in keywords:
                if j in i['text'].lower():
                    pos+=i['positive']
                    neg+=i['negative']
                    count+=1
                    break
        pospolarity.append(pos/max(1,count))
        negpolarity.append(neg/max(1,count))
        freq.append(count)
    return pospolarity,negpolarity,freq

def double(data,keyword_list):
    app=subanalyze(data,keyword_list)
    matplotlib.rcParams['figure.dpi'] = 100
    fig, ax1 = plt.subplots()
    ax1.plot(np.array(m),app[0],color='C1')
    ax1.set_xticks(np.arange(36))
    ax1.set_xticklabels([i if x%3==0 else '' for x,i in enumerate(m)],rotation=45)
    ax1.set_ylabel('Positive')
    for t in ax1.xaxis.get_ticklines():
        t.set_visible(False)
    for t in ax1.xaxis.get_ticklines()[::2][::3]:
        t.set_visible(True)
    ax2 = ax1.twinx()
    for t in ax2.xaxis.get_ticklines():
        t.set_visible(False)
    for t in ax2.xaxis.get_ticklines()[::2][::3]:
        t.set_visible(True)
    ax2.set_xticks(np.arange(36))
    ax2.set_xticklabels([i if x%3==0 else '' for x,i in enumerate(m)],rotation=45)
    ax2.plot(m,app[1],color='C2')
    ax2.set_ylabel('Negative')
    ax1.set_title('Keywords: '+', '.join(keyword_list[:3]))
    plt.show()
    
def trend(data,hint,keyword_list): # hint=0 for pos, 1 for neg
    app=subanalyze(data,keyword_list)
    matplotlib.rcParams['figure.dpi'] = 100
    fig, ax1 = plt.subplots()
    ax1.plot(np.array(m),app[hint],color='C'+str(hint+1))
    ax1.set_xticks(np.arange(36))
    ax1.set_xticklabels([i if x%3==0 else '' for x,i in enumerate(m)],rotation=45)
    ax1.set_ylabel('Sentiment Polarity')
    for t in ax1.xaxis.get_ticklines():
        t.set_visible(False)
    for t in ax1.xaxis.get_ticklines()[::2][::3]:
        t.set_visible(True)
    ax2 = ax1.twinx()
    for t in ax2.xaxis.get_ticklines():
        t.set_visible(False)
    for t in ax2.xaxis.get_ticklines()[::2][::3]:
        t.set_visible(True)
    ax2.set_xticks(np.arange(36))
    ax2.set_xticklabels([i if x%3==0 else '' for x,i in enumerate(m)],rotation=45)
    ax2.bar(m,app[2],alpha=0.3)
    ax2.set_ylabel('Sentiment Frequency')
    ax1.set_title('Keywords: '+', '.join(keyword_list[:3]))
    plt.show()
    
def all_trend(data,hint,keyword_list):
    app=[subanalyze(i,keyword_list) for i in data]
    matplotlib.rcParams['figure.dpi'] = 200
    fig, ax = plt.subplots(2,2,sharex=True,sharey=True,figsize=(12,8))
    for i in range(2):
        for j in range(2):
            temp=2*i+j
            
            ax[i][j].plot(np.array(m),app[temp][hint],color='C'+str(hint+1))
            ax[i][j].set_xticks(np.arange(36))
            ax[i][j].set_xticklabels([i if x%3==0 else '' for x,i in enumerate(m)],rotation=45)
            if not j:
                ax[i][j].set_ylabel('Sentiment Polarity')
            for t in ax[i][j].xaxis.get_ticklines():
                t.set_visible(False)
            for t in ax[i][j].xaxis.get_ticklines()[::2][::3]:
                t.set_visible(True)
            ax2 = ax[i][j].twinx()
            for t in ax2.xaxis.get_ticklines():
                t.set_visible(False)
            for t in ax2.xaxis.get_ticklines()[::2][::3]:
                t.set_visible(True)
            ax2.set_xticks(np.arange(36))
            ax2.set_xticklabels([i if x%3==0 else '' for x,i in enumerate(m)],rotation=45)
            ax2.bar(m,app[temp][2],alpha=0.3)
            if j:
                ax2.set_ylabel('Sentiment Frequency')
            ax[i][j].set_title(category[temp])
    plt.suptitle('Keywords: '+', '.join(keyword_list[:3]))
    plt.show()

def show(entity,month,keyword):
    a,b=0,0
    result=[]
    for i in metadata[entity][month]:
        s=0
        for j in keyword:
            if j in i['text'].lower():
                s=1
        if s:
            #print(i,data[entity][month][1][x])
            result.append(i)
    return sorted(result,key=lambda x : x['text'])

def classify(monthdata):
    pos=[]
    neg=[]
    for i in monthdata:
        poscnt=0
        negcnt=0
        for k in i:
            if k['positive']>=-1.5*k['negative']:
                poscnt+=1
            elif -k['negative']>=1.5*k['positive']:
                negcnt+=1
        pos.append(poscnt/len(i))
        neg.append(negcnt/len(i))
    return pos,neg

# %% [markdown]
# ## MS

# %%
m=month('2017-06','2020-05')
m.index('2019-05')
# Out:
# 23

# %%
trend(msdata,0,[''])

# %%
trend(msdata,1,[''])

# %%
double(msdata,['']) # 1,4,5, 11(morgan stanley garden, justin rose), 23, -3

# %%
temp=classify(msdata)
plt.plot(temp[0],color='C1')
plt.plot(temp[1],color='C2')

# %% [markdown]
# ### Overall 1,11

# %%
NMF(msdata[1],10,7,{})
# Out:
# ['"frankfurt" + "next" + "bank" + "via" + "goldman" + "morgan" + "stanley"',
#  '"stanley" + "morgan" + "bitcoin" + "zero" + "virtually" + "shrinking" + "acceptance"',
#  '"best" + "make" + "team" + "say" + "bank" + "via" + "morganstanley"',
#  '"research" + "form" + "generation" + "renewables" + "power" + "new" + "cheapest"',
#  '"scam" + "stop" + "hoax" + "country" + "global" + "change" + "climate"',
#  '"billion" + "exclusive" + "source" + "italian" + "court" + "claim" + "hear"',
#  '"cointelegraph" + "cryptocurrency" + "eye" + "vehicle" + "former" + "investment" + "ceo"',
#  '"great" + "move" + "go" + "god" + "president" + "thank" + "trump"',
#  '"morgan" + "pt" + "reiterated" + "price" + "overweight" + "rating" + "target"',
#  '"real" + "impact" + "like" + "dont" + "money" + "good" + "get"']

# %%
NMF(msdata[11],10,7,{})
# Out:
# ['"bank" + "stock" + "via" + "market" + "say" + "stanley" + "morgan"',
#  '"therhs" + "morganstanley" + "best" + "chrisbeardshaw" + "show" + "nspcc" + "garden"',
#  '"good" + "jr" + "deserved" + "chris" + "played" + "done" + "well"',
#  '"donating" + "book" + "every" + "booktrustusa" + "made" + "eagle" + "morganstanley"',
#  '"jacket" + "justinrose" + "golf" + "win" + "congrats" + "justin" + "great"',
#  '"cash" + "competitor" + "fb" + "snap" + "lead" + "bank" + "ipo"',
#  '"cut" + "raised" + "apple" + "tesla" + "tsla" + "price" + "target"',
#  '"amazing" + "justin" + "team" + "many" + "deserved" + "chris" + "congratulation"',
#  '"career" + "musk" + "earnings" + "analyst" + "unusual" + "call" + "year"',
#  '"valuable" + "worth" + "disney" + "company" + "would" + "youtube" + "much"']

# %%
unique([(i['positive'],i['negative']) for i in msdata[1]])
# Out:
# [((1, -1), 1091, 43.82),
#  ((1, -2), 477, 19.16),
#  ((2, -1), 333, 13.37),
#  ((1, -3), 189, 7.59),
#  ((2, -2), 110, 4.42),
#  ((3, -1), 105, 4.22),
#  ((1, -4), 60, 2.41),
#  ((2, -3), 40, 1.61),
#  ((3, -2), 29, 1.16),
#  ((2, -4), 18, 0.72),
#  ((3, -3), 12, 0.48),
#  ((4, -1), 8, 0.32),
#  ((4, -2), 5, 0.2),
#  ((3, -4), 5, 0.2),
#  ((5, -3), 2, 0.08),
#  ((5, -2), 2, 0.08),
#  ((5, -4), 1, 0.04),
#  ((4, -3), 1, 0.04),
#  ((4, -4), 1, 0.04),
#  ((1, -5), 1, 0.04)]

# %%
unique([(i['positive'],i['negative']) for i in msdata[11]])
# Out:
# [((1, -1), 1041, 36.2),
#  ((3, -1), 455, 15.82),
#  ((1, -2), 442, 15.37),
#  ((2, -1), 438, 15.23),
#  ((2, -2), 150, 5.22),
#  ((1, -3), 113, 3.93),
#  ((3, -2), 55, 1.91),
#  ((2, -3), 48, 1.67),
#  ((4, -1), 40, 1.39),
#  ((1, -4), 29, 1.01),
#  ((3, -3), 21, 0.73),
#  ((2, -4), 21, 0.73),
#  ((3, -4), 10, 0.35),
#  ((4, -2), 6, 0.21),
#  ((4, -3), 3, 0.1),
#  ((5, -2), 2, 0.07),
#  ((4, -5), 1, 0.03),
#  ((4, -4), 1, 0.03)]

# %%
LDA([i for i in msdata[11] if i['positive']==3 and i['negative']==-1],10,7,{})
# Out:
# ['0.025*"great" + 0.018*"good" + 0.015*"morgan" + 0.015*"stanley" + 0.015*"luck" + 0.010*"justin" + 0.008*"hope"',
#  '0.013*"morganstanley" + 0.011*"morgan" + 0.011*"stanley" + 0.011*"last" + 0.010*"good" + 0.008*"well" + 0.008*"work"',
#  '0.045*"great" + 0.023*"justinrose" + 0.022*"morganstanley" + 0.013*"thanks" + 0.010*"see" + 0.007*"stanley" + 0.007*"morgan"',
#  '0.018*"morganstanley" + 0.013*"congrats" + 0.010*"multicultural" + 0.010*"morganstanleys" + 0.010*"innovation" + 0.010*"justinrose" + 0.009*"morgan"',
#  '0.022*"morgan" + 0.022*"stanley" + 0.021*"beautiful" + 0.019*"morganstanley" + 0.018*"great" + 0.018*"time" + 0.015*"garden"',
#  '0.040*"congratulation" + 0.022*"well" + 0.018*"chris" + 0.015*"morganstanley" + 0.013*"huge" + 0.012*"many" + 0.012*"deserved"',
#  '0.024*"golf" + 0.024*"justin" + 0.024*"great" + 0.022*"fantastic" + 0.019*"win" + 0.018*"congrats" + 0.018*"awesome"',
#  '0.017*"amazing" + 0.015*"need" + 0.013*"stanley" + 0.013*"morgan" + 0.012*"morganstanley" + 0.011*"performance" + 0.009*"thank"',
#  '0.020*"morgan" + 0.020*"stanley" + 0.014*"morganstanley" + 0.013*"chris" + 0.013*"garden" + 0.013*"great" + 0.012*"congratulation"',
#  '0.061*"garden" + 0.037*"nspcc" + 0.036*"morganstanley" + 0.035*"show" + 0.033*"chrisbeardshaw" + 0.031*"best" + 0.024*"congratulation"']

# %% [markdown]
# ### Overall 4,5

# %%
unique([(i['positive'],i['negative']) for i in msdata[4]])
# Out:
# [((1, -1), 1157, 47.79),
#  ((1, -2), 393, 16.23),
#  ((2, -1), 312, 12.89),
#  ((1, -3), 134, 5.53),
#  ((3, -1), 126, 5.2),
#  ((2, -2), 113, 4.67),
#  ((2, -3), 48, 1.98),
#  ((3, -2), 35, 1.45),
#  ((1, -4), 32, 1.32),
#  ((2, -4), 22, 0.91),
#  ((4, -1), 16, 0.66),
#  ((3, -3), 13, 0.54),
#  ((3, -4), 12, 0.5),
#  ((1, -5), 3, 0.12),
#  ((4, -2), 2, 0.08),
#  ((5, -2), 1, 0.04),
#  ((5, -1), 1, 0.04),
#  ((5, -4), 1, 0.04)]

# %%
unique([(i['positive'],i['negative']) for i in msdata[5]])
# Out:
# [((1, -1), 1027, 41.44),
#  ((1, -2), 558, 22.52),
#  ((2, -1), 266, 10.73),
#  ((1, -3), 162, 6.54),
#  ((2, -2), 135, 5.45),
#  ((3, -1), 114, 4.6),
#  ((2, -3), 55, 2.22),
#  ((3, -2), 41, 1.65),
#  ((1, -4), 41, 1.65),
#  ((2, -4), 25, 1.01),
#  ((3, -3), 19, 0.77),
#  ((4, -1), 16, 0.65),
#  ((3, -4), 10, 0.4),
#  ((4, -2), 5, 0.2),
#  ((1, -5), 2, 0.08),
#  ((4, -3), 1, 0.04),
#  ((2, -5), 1, 0.04)]

# %%
LDA([i for i in msdata[4] if i['positive']==1 and i['negative']==-2],10,7,{'morgan','stanley','morganstanley'})
# Out:
# ['0.021*"bank" + 0.012*"u" + 0.009*"overweight" + 0.008*"hq" + 0.006*"around" + 0.006*"equalweight" + 0.006*"think"',
#  '0.009*"way" + 0.008*"tax" + 0.008*"market" + 0.008*"done" + 0.006*"one" + 0.006*"man" + 0.006*"job"',
#  '0.009*"wrong" + 0.009*"rate" + 0.007*"could" + 0.007*"many" + 0.007*"fed" + 0.005*"imf" + 0.005*"world"',
#  '0.012*"people" + 0.008*"stanley" + 0.006*"world" + 0.006*"problem" + 0.006*"power" + 0.006*"client" + 0.006*"experience"',
#  '0.018*"recruiting" + 0.011*"pact" + 0.010*"fake" + 0.010*"brokerage" + 0.009*"industry" + 0.009*"quits" + 0.008*"stock"',
#  '0.021*"climate" + 0.019*"change" + 0.010*"one" + 0.008*"billion" + 0.008*"market" + 0.008*"dont" + 0.006*"share"',
#  '0.009*"india" + 0.007*"u" + 0.006*"bank" + 0.006*"know" + 0.006*"weight" + 0.006*"m" + 0.005*"trump"',
#  '0.020*"overweight" + 0.017*"r" + 0.014*"say" + 0.010*"share" + 0.009*"target" + 0.008*"broker" + 0.007*"get"',
#  '0.013*"broker" + 0.012*"exit" + 0.010*"recruiting" + 0.008*"via" + 0.008*"protocol" + 0.006*"money" + 0.006*"business"',
#  '0.015*"price" + 0.015*"raise" + 0.012*"overweight" + 0.012*"target" + 0.012*"tesla" + 0.010*"stock" + 0.008*"time"']

# %%
LDA([i for i in msdata[5] if i['positive']==1 and i['negative']==-2],10,7,{'morgan','stanley','morganstanley'})
# Out:
# ['0.012*"goldman" + 0.010*"say" + 0.009*"sachs" + 0.009*"amazon" + 0.007*"tax" + 0.007*"case" + 0.007*"risk"',
#  '0.012*"cut" + 0.011*"could" + 0.011*"boom" + 0.011*"bust" + 0.011*"tax" + 0.010*"trump" + 0.010*"bank"',
#  '0.008*"price" + 0.007*"wage" + 0.007*"tell" + 0.007*"banker" + 0.007*"oil" + 0.006*"tax" + 0.006*"need"',
#  '0.018*"tax" + 0.011*"car" + 0.009*"u" + 0.007*"new" + 0.005*"one" + 0.005*"could" + 0.005*"get"',
#  '0.020*"overweight" + 0.008*"inflation" + 0.008*"rating" + 0.008*"stanley" + 0.007*"target" + 0.007*"u" + 0.007*"buy"',
#  '0.016*"car" + 0.012*"electric" + 0.011*"want" + 0.009*"get" + 0.009*"charge" + 0.009*"inflation" + 0.009*"tax"',
#  '0.032*"protocol" + 0.030*"broker" + 0.025*"exit" + 0.018*"dangerous" + 0.017*"corbyn" + 0.017*"brexit" + 0.015*"hard"',
#  '0.011*"government" + 0.011*"may" + 0.011*"collapse" + 0.010*"drop" + 0.008*"election" + 0.008*"ill" + 0.007*"market"',
#  '0.008*"inflation" + 0.008*"low" + 0.008*"condition" + 0.005*"put" + 0.005*"financial" + 0.005*"looking" + 0.005*"think"',
#  '0.010*"market" + 0.009*"doubt" + 0.009*"snap" + 0.007*"battery" + 0.007*"see" + 0.007*"lead" + 0.007*"sell"']

# %%
text(search([i for i in msdata[5] if i['positive']==1 and i['negative']==-2],['election']))
# Out:
# [' just told its investors that another general election towards the end of was likely once Mays Govt realised it could not secure the Brexit deal it wants the Conservative party began to fall apart opening the door to Labour taking power',
#  'I voted Dem for years from Bill to Hillary in general election that is What a fool I was Never again Where were the Dems when Goldman was getting free reign from the Commodities Futures Trading Commission',
#  'MORGAN STANLEY Mays government will collapse in triggering a fresh general election ',
#  'MORGAN STANLEY Mays government will collapse in triggering a fresh general election via BIUKFinance',
#  'MORGAN STANLEY Mays government will collapse in triggering a fresh general election via BIUKFinance January',
#  'MORGAN STANLEY Theresa Mays government will collapse in triggering a fresh general election ',
#  'Morgan Stanley has told investors that another general election towards the end of is likely once Theresa Mays government realises it cannot secure the Brexit deal it wants and the Conservative party began to fall apart',
#  'Morgan Stanley issued a report in which they claimed May will survive Xmas but early next year May gov will collapse and a general election will be called',
#  'Theresa Mays UK government will collapse in and trigger fresh election predicts Morgan Stanley ']

# %%
for i in msdata[5]:
    if i['positive']==1 and i['negative']==-2:
        print(i['text'],'\n')
# Out:
# Well actually full employment is more of a statistical equation result and not that every single person has a job Stagnant wages are our fault We voted for fools by not voting
#
# Takes less patience to charge than to gas up since you plug and go at work shopping at home sleeping No flammable liquids no odor no dangerous fumes no tail pipe emissions no carbon monoxide risks
#
# BD Advisor Valuations To Compress As Morgan Stanley Withdrawal Unravels The Broker Protocol other Weekend Reading for Financial Planners Nov
#
#  I hear a rumor that Morgan Stanley will offer investment banking and brokerage services in China within a two year time frame
#
# Inflation as measured may be low but the cost of living is skyrocketing Maybe were not measuring the right things
#
# Barrons Health and Wealth Roundtable Four top advisors offer strategies for avoiding common pitfalls when planning for your postcareer years MorganStanley RBC HighTowerAdvsor
#
# UnNamed Sources alleged Steyer groped a Morgan Stanley coworker in
#
# What work are you taking about Walmart or Dunking MacDonald Shout the hell up
#
# Not under trumps new laws or lack of
#
# NOT So Surprising For those of us Who Called out MorganStanley WAY Back in SNAP Debut in Underwriting a Short Sell Fraud overseen by CNBC FortuneTech techreview
#
# exactly mr jefferson take the time to recycle batteries yeah it is expensive as shit yeah it is toxic get ur own name and tweet me
#
#  ways Morgan Stanleys protocol exit will backfire by Elzweig
#
#  ways Morgan Stanleys protocol exit will backfire
#
# Dont tweet us that half baked self serving BS Americans are sick tired on being screwed then having to bail them out by big financial institutions
#
# Not true lead is a serious commodity Go buy a battery
#
# LACDD this week has gone crazy with its new name and on the stock market I see it going to A share Its about Was two years ago China few months ago invested million in them
#
# The guarantee is selfinsured on the balance sheet of Pru they could use derivatives from Morgan Stanley too The risk should be taken into consideration in Prus capital adequacy more stringent after GFC formulas Last resort is FSCS at compensation insured product
#
# Another stupid tweetJesh Where do you fools come from Mars
#
# The bloated balance sheet keeping Yields rates low is evidently financing excess capacity which is deflationary The solution is
#
# Um no I get tired of all the talking heads I base my opinions on and when trying to get a solar photovoltaic system for my home At this point it wasnt worth it at all
#
# About as much as youre stuck thinking stupid Im I have done just a bit of stock bond and mutual fund trading in my life I still use Morningstar Think about YOURSELF making only minimum wage Tell me where you free up enough money to invest
#
# and then everyone will realize their stupidity electricity costs more and pollutes more than petrol
#
# Watching that Fox News shit again Shane
#
# If and only if the markets and Trump doesnt collapse Markets are outsold Trump is marketing his own collapse js
#
# News flash Theres a Nazi in the White House with the intelligence of a garden slug
#
# But the deficit was declining Which is the actual goal Which in turn reduces debt Eco
#
# Why are we adding Trillions to the Budget for Tax Breaks Without getting anything for it At Least with infrastructure spending we get something
#
# IMMINENT Sun FlareEMP bomb WILL KILL of USA Billion would prevent it Instead we r spending BILLION on a wall RETWEET LIVE
#
# Nuance Communications Inc NUAN Raised to Overweight at Morgan Stanley
#
# Trading tip from Morgan Stanley Western Areas WSA shares to weaken next days following strong rally since June
#
# Morgan Stanley Bankers Brother Stole M Through Two Fraudulent ICOs
#
# sell weed
#
# What does Morgan Stanley leaving the Recruiting Protocol mean for your business brokerdefender Explains
#
# Thx but YOUR working class investors NEED YOUR PUBLIC stand AGAINST GOP propose budget changes to Ks similar retirement plans
#
# A problem
#
# Well this new compensation plan was almost certainly rolled out TO comply with the fiduciary rule Less conflicted than the old one
#
# Morgan Stanley MS is somewhat overlooked but its also broadly climbing Soft target s FPE s Cheap petenajarian ps hello
#
# GOP are sellout scumbags DNC just sellouts to other millionaires corps BOTH suck GOP just more obvious abt it
#
# Did You Know is being accused of mismanaging its employees funds between and Learn more
#
# By then Ill be in the one right in front of you doing with a blinker stuck on
#
# While of Americans try to figure out how to drive their large tax bills
#
# So in essence the is the black population This is unacceptable Its crazy to say full employment when Black unemployment is double digits
#
# US oil services firm Weatherford hires Morgan Stanley to sell units sources claradenina
#
# US oil services firm Weatherford hires Morgan Stanley to sell units sources
#
# Does that mean youll be joining me on Saturday at PM Also I said we have about T annually of deficit spending policy space Well only need abt B of it to do
#
# What pricing has been the biggest contributor to inflation trends Fuel kicks it everything And has remained stable since fracking begun
#
# Betcha you are wrong
#
# Yes I got tired of being told Do more with less Increase your productivity for the same wages
#
# Thats not really truewages for the middle class are stagnant
#
# SURPRISINGLY LOW I LIVED THROUGH THE INFLATION OF THE LATE s s That was TOUGH
#
# if oil companies would let them they could build electric car with power to clime large hill or go up mountain NOW they have trouble going even on very slight uphill road IF THEY WANTED TO they could build one with power THEY JUST WANT YOUR MONEY FOR SOMETHING BUILT CHEAP
#
# Rent here in Denver goes up abt yr Say what u want about inflation
#
# Edward Jones Noses Ahead of Morgan Stanley to Boast Biggest Brokerage Force
#
# Edward Jones Noses Ahead of Morgan Stanley to Boast Biggest Brokerage Force via jedhorowitz
#
# Full unemployment is a misnomer with the low workforce participation rate Many makes are not looking for employment
#
#  how are they gonna be charged
#
# SNAP as predicted back at every quarter will reveal the weakness in snap and its undeserved valuation premium we see downside from here and sold on the spike today Downgraded to SELL by most of its IPO banks including lead bank Morgan Stanley this week target
#
# Saudi budget Flynas picks Morgan Stanley for IPO sources Reuters
#
# China makes historic move to open market for financial firms business alfredliuhk evelynpi jeffkearns chancat jpmorgan Chase MorganStanley UBS Citi GoldmanSachs HSBC CEIBS irisirispang INGnews ANZAU Jkylebass GeorgeSoros
#
# Morgan Stanley loses senior fixed income quant as hiring heats up at the end of the year
#
# SNAP s disappointing Q speaks to growing challenges for the companys monetization potential Morgan Stanley a lead IPO bank downgrades to Underweight with price target
#
# This should be another indicator to all that we are a demandconsumption driven economy Prices for goods services realestate will rise when middleclass and working class wages rise GOP Tax cuts have zero effect on wages and will not grow the
#
# EV growth bullish for overall demand but per Morgan Stanley beware false claims that nickel sulphate will be in short supply Producing NiSO isnt particularly challengingcostly After all BHP can produce ktpa NiSO by at Nickel West with mere M investment
#
# JMPSZ China will give global financial companies unprecedented access to the worlds secondlargest economy JPMorgan Chase Co and Morgan Stanley saying in statements that theyre committed to China
#
# Morgan Stanley is too low on NVDA but they have their reasons MS Nvidia earnings
#
#  latest retailrelated shr to drag this wk Supplier hit by bearish MorganStanley note citing Down KO
#
# Wait you want inflation
#
# Point is food packaging is Shrinking It has been for yrs ie A lb can of ground coffee WAS the common lg size This is where the food inflation is Shrinking products
#
# Dollar set for biggest weekly drop in weeks on tax concerns Delay likely to keep US investment spending lowerMorgan Stanley Markets in narrow ranges euro volatility lowest since
#
# And repeals tax breaks for electric cars
#
# This should be much higher considering the population will be roughly billion people
#
# No advisor will want to join MorganStanley now that a No Exit sign is posted over the entryway says Elzweig
#
# Servicing company might have driven Tax reform at Morgan Stanley European Conference on November
#
# Because as bankers they only make if people borrow But rental prices are soaring while pay remains stagnant
#
# Why would you want higher inflation
#
# Morgan Stanley now sees international benchmark fetching a barrel in Q of the year up from an earlier estimate of US crude is poised to average for the quarter up from its prior call
#
# Morgan Stanley has raised its forecast for prices through saying the world is hungry for more US at a time when its uncertain American drillers can deliver it
#
# SenSanders Wage increases are stagnant even when in theory low unemployment in a Free Market should increase salariesThe problem is we dont have a Free Market but a Manipulated Market controlled by a limited number of players who control huge numbers of Financial Instruments
#
# Morgan Stanley issued a report in which they claimed May will survive Xmas but early next year May gov will collapse and a general election will be called
#
#  is still quite expensive and inefficient Otherwise the Sunbelt and Tropics would already be on that bandwagon Here in we still use and primarily Solar wind and geothermal do not provide enough
#
# Full employment mean you dont count the last of unemployed people and completely ignore the millions who have given up on getting a job As for inflation none of those jobs that exist pay enough for anyone to buy anything You really are quite stupid frankly
#
# Doubt it Will they be flying electric vehicles too
#
# Ill believe it when I see it
#
# MOVESMorgan Stanleys head of sports entertainment division to leave
#
# Is this bad Economics
#
# BruceWorley private msg sorry looking for Traing Vice President at Morgan Stanley
#
# Head of Morgan Stanleys Global Sports and Entertainment Division Has Left theFirm
#
# Morgan Stanley nixes protocol pact blocking brokers exits via nypost
#
# Teslacould rocket to new highs then collapse says Morgan Stanley in report TSLA
#
# I shared my thoughts on Morgan Stanleys exit from the Broker Protocol with dvjamieson FAmagazine
#
# CEO mattsonnenpfi discusses Morgan Stanleys exit from Broker Protocol with FAmagazine
#
# BUCKLE UP Tesla is going to face extreme volatility in Morgan Stanley warns
#
# Fake inflation numbers and fake unemployment numbers
#
# Cannot Invest In You Because Of Your Tweet No Solutions Just A Problem
#
# Morgan Stanley fires its first post protocol weapons Many more to follow Bad for advisors and public customers
#
# TheRealDavidYe Met this fool at the UCLAUSC game who was a stockbroker for Morgan Stanley and now works for Amazon Only years old Why cant we do that
#
# Yes oil has better uses than burning it for transportation It wont go away but it will be used for something better than burning it The oil market will shrink once it is replaced by EV transportation
#
# Miner problem Oil has dozens of uses other than fuel Plastic rubber lubricants medicine sealants clothing storage containers gaskets serving containers medical supplies furniture school supplies aircraft fuel food packages and a whole lot more items So think about that
#
# Tesla shares could top in the next year only to see that price slashed in half later on Morgan Stanley analysts say
#
# And as expected its gameon in a post era Morgan Stanley obtains Temporary Restraining Order TRO against departing broker who tried to contact former clients to join him at the new firm Morgan Stanley claims client list is THEIR data not advisors
#
# Morgan Stanley Ties Hands of Broker Who Jumped After Protocol ExitSources via advisorhubinc
#
# And the green freaks will then complain about the dirty batteries and well have to go back to gasoline
#
# Its just an estimate As long as nobody is counting the longterm discouraged theres no way to know
#
# An economic site I follow called ShadowStats claims the official unemployment numbers started excluding the longterm discouraged unemployed in They put the actual total unemployment in the US at
#
# BUCKLE UP Tesla is going to face extreme volatility in Morgan Stanley warns TSLA
#
#  BUCKLE UP Tesla is going to face extreme volatility in Morgan Stanley warns TSLA
#
# Tesla Could Rocket To New Highs Then Collapse Morgan Stanley
#
# By there will be more storage on the grid that can handle interruptions and incoming electrcity from reweables while driving prices down Wind already cheaper than new power plants
#
# There wont be a low power time once a billion cars with an average of batteries per car start charging That means the grid will b full or close to full capacity Nothing can run around the clock not break It will take trillions to update the grid power plants
#
# Or they can be charged at night during low demand
#
# HP Lowes Analog Devices and Palo Alto Earnings Morgan Stanley Chime via YouTube
#
# Morgan Stanley says tax bill is bad for the economy
#
# MorganStanley are absolutely spot on Throwing in expensive tax cuts to a healthy economy could cause a serious boom and bust to equities too
#
# Wells Fargo Wave of Mutilation JPMorgan Chase Debaser Citigroup Where Is My Mind Morgan Stanley Bone Machine Goldman Sachs Gigantic
#
# MORGAN STANLEY Mays government will collapse in triggering a fresh general election via BIUKFinance
#
# Ryan is the biggest fake ever Even Morgan Stanley is against it
#
# Is MorganStanley starting a movement of firms abandoning the Protocol for Broker Recruiting
#
# Short answer Ill be living in Bettendorf now working at Morgan Stanley I plan on doing a lot with kids through campsworkoutsspeaking
#
#  MCHP Morgan Stanley lowered their rating from Overweight to EqualWeight
#
# Broker Protocol Administrator Questioned as Morgan Stanley Exits
#
# YouUS News on need for tax cuts Tax cuts fueled the economic booms of the roaring s bust See Morgan Stanley on cuts
#
# And in toto Morgan Stanley is saying this is not a good idea
#
# Morgan Stanley thinks tax reform could derail the stock market rally Do you agree
#
# Morgan Stanley to Pay B to Settle Financial CrisisEra Charges In case you forgot Now they give Tax advice
#
# Racist
#
# Not true
#
# This is racist
#
# Morgan Stanley loses million team to Baird
#
# MorganStanley decision will be particularly disruptive for teams already in transition HDelux talks with
#
# Morgan Stanley warns that Trump tax cuts could create a boom then a bust
#
# Morgan Stanley Trump tax cuts could create boom then a bust CNNMoney InfoRealEstate Harold ArnoldRealtor
#
# Morgan Stanleys Exit from Broker Protocol is Stern Warning to BrokerDealers Competition
#
# Morgan Stanley Trump tax cuts could create boom then a bust that was always our destiny even before Trump but this may supercharge the bubble
#
# Lawyers say this move is going to give them a headache in court Protocol Admin Delayed Sharing Morgan Stanley Exit
#
# DowDuPonts PT raised by Morgan Stanley to overweight rating DWDP
#
# Did Morgan Stanley just kill the broker protocol agreement
#
# Scoop from late last night Broker Protocol Administrator Delayed Public Notice of Morgan Stanleys Exit
#
# Broker Protocol Administrator Delayed Public Notice of Morgan Stanleys Exit
#
# Morgan Stanley Trump tax cuts could create boom then a bust CNNMoney
#
#  news via CNNMoney Morgan Stanley Trump tax cuts could create boom then a bust
#
# Morgan Stanley Trump tax cuts could create boom then a bust
#
# Broker Protocol Administrator Delayed Public Notice of Morgan Stanleys Exit wealthmgmt
#
# economic news via CNNMoney Morgan Stanley Trump tax cuts could create boom then a bust
#
#  Morgan Stanley Trump tax cuts could create boom then a bust
#
# Morgan Stanley Trump tax cuts could create boom then a bust
#
# That will be the first one in years then They are closing more than they are opening The rest are being converted to cheaper natural gas
#
# India Brazil Indonesia S Africa moved off the fragile Morgan Stanleys list of unstable emerging economies
#
# Natural gas is so cheap we are exporting it for the first time Coal is harder to transport and crush than nat gas pipe lines Sorry Coal
#
# They are also building more renewables than anybody They start and stop those coal plans all the time Nobody wants expensive coal for elct
#
# The rise of coal exports and home use without restrictions will increase production Sorry coal is here to stay
#
# The trend for coal as an electrical source will continue to drop due to low natural gas prices and ease of use Market forces not regulation
#
# Ill have to take your word for it I wont be around to dispute
#
# But no tax credit
#
# They could be powered by monkey dust instead Difficult to predict
#
# Choosing the right license to your project is so critical Hard to change it and an odd license may deter contributions Nick Williams MorganStanley
#
# MorganStanley recruiting is effectively over after leaving Broker Protocol says Elzweig recruiter
#
# The fastest way to wealth is entrepreneurship and tax avoidance The formula is there just depends if ppl take advantage of it
#
# MorganStanley PT for IONS is just voting present as is MorningstarInc FV of but they added key commentary we stress majority of Ionis pipeline is not competing with ALNY candidates caution against overly punitive stance on Ionis RNAbased platform
#
# Morgan Stanley Oil Markets The Return of Geopolitical Risk
#
# Ill be that year Hopefully Ill make it
#
# YES And thats why the Tax Plan is so obscene
#
# Wages are stagnant for the average American and subliving wage for too many
#
# Maybe because Wall Street is being manipulated by the to use as an indicator of the US economy which it has Very Little to do with When will people realize that Wall Street is just a number of investors NOT American economy Those investments dont put food on the table
#
# Computer Science and Eng Maths students solving technology problems with MorganStanley this afternoon CSSBristol
#
# Yes and all their batteries will discharge after miles
#
# Coal is too expensivewont come back wo gov handouts Natural gas is cheaper dropped electric prices for yrs
#
#  Acknowledges US Dominance Says Will Struggle to Meet World Demand
#
# Except trump admin wants to get rid of tax incentives to purchase electric
#
# Pollute the landfills
#
# Doubt it
#
# The charging stations will cost too much We cannot accommodate How will the batteries be disposed of
#
# MND Mondi upgraded to Overweight from Equal weight at Morgan Stanley Price target R Can explain the strength today
#
# This is why most engineers are liberal Conservatives lack the brainpower to dolve problems
#
# Ok cranky old man
#
# Morgan Stanley has raised its forecast for oil prices through saying the world is hungry for more US shale crude at a time when its uncertain American drillers can deliver it
#
# ill bet you thought lehman bros would still be around
#
# Not if the tax credit for them is gone
#
# And it will be hot as hell
#
# Wrong Coal cars said
#
# Stock Call Lupin Morgan Stanley Cuts To Equalweight From Overweight Cuts Target To From
#
# Ill be getting my electric heart rechargedkidneys too
#
# I believe that too Get the price down and the miles per charge up
#
# Cant believe these arent everywhere in the US They are in Germany
#
# Speculation onlywe doubt it
#
# And some will be moving ISIS BOMBS
#
# MORGAN STANLEY Mays government will collapse in triggering a fresh general election via BIUKFinance January
#
# Morgan Stanley Brokers Jump Early Under Protocol Pressure
#
# Bitcoin and the Blockchain Will Stomp Out Wall Street Fraud QA with Caitlin Long a former Morgan Stanley ma
#
# Morgan Stanley Brokers Jump to Regionals Under Protocol Pressure
#
# MorganStanley suggest will collapse next year over KeirStarmer eloisetodd ElunedMorgan BIUK
#
# MORGAN STANLEY Mays government will collapse in triggering a fresh general election
#
# US Steel upgraded at Cowen Morgan Stanley maintains at Overweight
#
# Morgan Stanley expects May government to collapse in
#
#  climbs from to and recommends overweight He says hes studying possible stock sales
#
# Sorry Morgan Stanley Even when I see your ads on twitter I think about Morgan Freeman not you
#
# Nuance Communications upgraded to overweight from equal weight at Morgan Stanley
#
# My latest Morgan Stanleys broker protocol exit How did we get here newsfromIN
#
# CLVS NOW MS chimes in DJ Clovis Maintained at Overweight by Morgan Stanley DJ Clovis PT Cut to From BFD
#
# Ahead of Broker Protocol exit M Morgan Stanley team jumps to Baird
#
# Nuance Communications as Morgan Stanley boosts to Overweight
#
# This wouldnt be the same Morgan Stanley that claimed a vote to leave would cause equities to collapse by over
#
# Learn how MorganStanley protects your online and mobile account information and transactions against fraud
#
# Morgan Stanley Bankers Brother Stole M Through Two Fraudulent ICOs via FintechBot
#
# Finra Morgan Stanley must pay Schwab million over broker recruiting violation
#
# Con man you mean its important to JP Chases and Morgan Stanleys bottom line
#
# Bro the article JUST said it got weaker not stronger
#
# Theresa Mays UK government will collapse in and trigger fresh election predicts Morgan Stanley
#
# Im disabled and so are my finances
#
# Whats Morgan Stanleys rationale for exiting the Broker Protocol Join BDNEWSGUY rhordt for First Look Video
#
# In the Newsroom video rhordt BDNEWSGUY discuss Morgan Stanleys rationale for exiting the broker protocol
#
# disruption of your social media department would be waking them up
#
# Why stay with a wirehouseGo independent Questions Abound After Morgan Stanley Leaves Broker Protocol
#
# Headed for the exits Morgan Stanley loses brokers with over B
#
# So does MorganStanleys strategic plan include creating disruption just so you can create longterm investments from it
#
# If this tax bill goes through we arent investing in shit
#
# Gone in a New York minute Morgan Stanley loses teams managing over billion in assets by AndrewWelsch
#
# It might be MorganStanley alone that decides they cant compete without these restrictions HDelux
#
# Gone in a New York minute Morgan Stanley loses teams B in AUM by AndrewWelsch
#
#  teams with B in AUM quit Morgan Stanley
#
# Morgan Stanley advisers feel burned by broker protocol exit via newsfromIN
#
# Morgan Stanley advisers feel burned by broker protocol exit
#
# MorganStanley Bankers Brother Stole M Through Two Fraudulent
#
# If you have been invited to the room you belong in the room If you are in the room then you have a seat at the table If you have a seat at the table then you have a responsibility to speak Carla A Harris Vice Chairman Morgan Stanley MorganStanley
#
# Morgan Stanleys broker protocol exit How did we get here
#
# MORGAN STANLEY Theresa Mays government will collapse in triggering a fresh general election
#
# Morgan Stanley Bankers Brother Stole M Through Two Fraudulent ICOs via themerklenews
#
# Its cuz we live in a suppressive society against white people
#
# New GenovaBurns LE Blog Post Abandons Industry Pact
#
# NEW LE Blog Morgan Stanley Abandons Broker Industry Recruiting Pact by topherk
#
# Hence Morgan Stanleys withdrawal from the Broker Protocol The asset slippage is becoming meaningful
#
# Morgan Stanley Bankers Brother Stole M Through Two Fraudulent ICOs The Merkle Cryptocredit
#
# no one wants to be a blithering bumbling blathering bamboozling baboon
#
# You have to include on this list will see an explosion in pRTLS adoption that will change how the world works
#
# Correct What is the problem with Fed deficits
#
# Take away tax rebates and watch sales decline
#
# Boardman is coal burning
#
# Morgan Stanley This next big technology trend could start the fourth industrial revolution
#
# Unfortunately housing has gone way up Making impoverished even poorer Hence homelessness is rising Average per American
#
# I disagree but either way its why minimum wage needs to be higher and tied to inflation
#
# My years of IT experience to the contrary
#
# The fact that inflation is so low is a symptom of underlying weakness in the economy An economy that is growing broadly in a healthy manner would have higher inflation
#
# Inflation is low for two reasons We are not at full employment That is government BS that is arrived at by cooking the data what jobs people have are largely low paying and insecure thus seriously constraining spending
#
# and how much electricity to charge them
#
# You need to go buy groceries Inflation is HERE
#
# valuewalk One Of The Biggest Unicorns Could Be In Trouble Morgan Stanley
#
# got cheap Chinese labor exported everyones job you dont count the people that are not on unemployment insurance farce
#
# Its that all or nothing approach that has people put off about alternative energy sources And just how do you think bikes are made
#
# One Of The Biggest Unicorns Could Be In Trouble Morgan Stanley
#
# As Morgan Stanley exits the Broker Protocol Alan Foxman reminds advisors to check their employment contracts
#
# EU will want its pound of flesh to make sure others do not follow the route of UK J Morgan Stanley already in concrete discussion of Frankfurt move Vast majority of financial transactions now completed by internet and electronic mode and London will rue the day we leave EU
#
# SoWorld Bank IMFMoodyMorgan Stanley are wrong and your boss ArvindKejriwal is right Mike hatao AUR topi pahno ashupage
#
# Puppet Masters warns the is likely to weaken for the next six years
#
# Morgan Stanley bailed out to the tune of bn after the crash I dont think we should set much store at there predictions about a government
#
# Morgan Stanley dominating the block business with deals over USFD and TRCO tonight
#
# Another Firm Follows UBS and Morgan Stanley Out of the Broker Protocol Are you among these firms and has it affected you
#
# Well considering Morgan Stanley are known for tax evasion I would of thought thats a statement of the blding obvious or what from themyou Digbylj
#
# Morgan Stanley warns Jeremy Corbyn is more economically dangerous than hard Brexit despite helping cause the recession themselves
#
# The cause we know too much debt lots of the trigger and timing we know not yet was to months early from to but moneyprinting makes it more difficult
#
# Had a blast teaming up with MorganStanley yesterday to give an intro to to a room full of investors at the DL HQ Heres a of Ragavans talk on Want to learn more about our story Lets chat drop us a line at
#
# Oh is quantum computing another buzz word for illegal algorithms that hedge funds use to artificially drive stock prices
#
# CBI Institute of Fiscal Studies TPA Morgan Stanley OBR Resolution have raised serious issues in economic policies
#
# Morgan Stanley warns Corbyn is more economically dangerous than hard Brexit despite helping cause the recession themselves mattzarb
#
# Morgan Stanley predicts will be tricky one for global economies says sell US corporate bonds by MorganStanley Investor will have to be careful next year as stalling economies with rising inflation Nov
#
# What struck Morgan Stanley the most following Q Piraeus Bank results Bullish comments about NPE reduction and nearterm progress
#
# MorganStanley recent analysis of potential Labour Government is a bit rich coming from an institution that needed a billion bailout No red faces no sense of irony I suppose
#
# Whats wrong with low inflation
#
# Not looking good for all the prepping and EMP training scenarios
#
# DOOM See Jons tweet re above
#
# Not the same Morgan Stanley that needed to be bailed out by the FED for b Bit hypocritical if it is
#
# Gas will be cheap for me
#
# So lets mess it up with tax giveaway to billionaires
#
# Has anyone noticed that lately there is virtually negative correlation between TSLA share price and the price of bitcoin From this I infer that the amount of stupid money is finite
#
# Morgan Stanley Predictions for India Brazil Energy Stocks and Volatility INDA EWZ XLE OIH TS VXX UVXY
#
# Despite helping to crash the global economy in an orgy of fraud Morgan Stanley warns Corbyn is more economically dangerous than hard Brexit hed turn socialism for the few into socialism for the many Thats the idea yes
#
# Morgan Stanley warns Corbyn is more economically dangerous than hard Brexit despite helping cause the recession themselves mattzarb
#
# Corbyn is more DANGEROUS to UK than any Brexit Morgan Stanley issues warning on leader
#
# Lets clear out the old sectors Starting with the criminal banking industry
#
# Morgan Stanley warns Corbyn is more economically dangerous than hard Brexit despite helping cause the recession themselves
#
# And robotic siege on jobs Get technical people
#
# Michael Rosen I wonder if the Morgan Stanley giving dire warnings about a Labour Govt today is the same
#
# Morgan Stanley predicts will be tricky for global economies says sell US corporate bonds
#
# Morgan Stanley Upgrades Allergen AGN to Overweight
#
# As Banking Loses Its Influence in London Morgan Stanley Also States
#
# That is a lot of battery waste to dispose of
#
# UPDATE Morgan Stanley Upgrades Allergen AGN to Overweight
#
# Even bank Morgan Stanley who advises global investors say J Corbyn crippling taxesmass renationalise would reduce our finances Post Brexit who wants a Marxist Corbyn wreaking crew controlling it
#
# Is this the same Morgan Stanley that was partly responsible for the financial crash was bailed out by the Fed to the tune of billion the most of any bank and have only paid back billion Thought so
#
# Wait till your tax breaks go down the tubes
#
# Morgan Stanley Kept NYSECRM As a Overweight They Now Have a Price Target Of
#
# Get involved in the KelloggMorgan Stanley Sustainable Investing Challenge
#
# So what is the problem or problems
#
# Reaffirmed NYSECRM Overweight Rating Maintained by Morgan Stanley
#
# I never said oil doesnt have its uses I said that transportation isnt a good one
#
# How often does that need to be replaced Keep in mind I never said that oil isnt useful for lubricant I said that is a better use than burning it for transportation
#
# they must not go to grocery store srinking size for same price is inflation
#
# Hence Morgan Stanleys exit from the Broker Proticol The big firms are finally feeling the change in their industry
#
# Got a source for that Because I highly doubt that much is used
#
# If you mean employment at Walmart or other shit jobs then yes Right to work GOP laws have created working poor
#
# Is here a way to drive across the country in an electric car without any extra effort Until that happens electric cars are nowhere near ready Takes too long to charge the battery as well
#
# Morgan Stanley Reaffirms Overweight Rating for Inc CRM
#
# ASIAN SEMI DOWNGRADE MORGAN STANLEY dngrades Sammy TSMC ASE ASM Pac WDC on thesis NAND pricing softening on smphone demand peaking news to anyone Gimmicky to do it over Thxgiving wkend not sure NAND weakness is contrarian Stay ve SPE Might need more popcorn
#
#  Morgan Stanley Reaffirms Overweight Rating for Inc CRM
#
# Youve mixed up the apples oranges a bit Reducing the Fedpublic deficit causes us private sector folks to be in deficitdebt Public vs private
#
# Despite record stock prices we have huge income inequality problem
#
# Ready for the recession
#
# Not gonna happen with the Tax Increase on those who spend
#
# So lets get this straight Government puts Charlie Sherm in jail for laundering then NY Benjamin Lawsky wrights the regulation Quites as NY Regulator becomes the go to guy for bitcoin license Only the Insiders ie Morgan Stanley get the license They Stole Bitcon
#
# Basically the only way to have so much money circulating in the economy without causing inflation is through debt and other financial instruments In particular student loans and mortgages comprise a HUGE amount of our total debt
#
# Not if the oil and gas industry can sabotage it
#
# Morgan Stanley sees Tesla shares rising to as production issues subside then plunging to in a decline of percent from the stocks current price of as more electric car competition comes to the market
#
# Morgan Stanley is a criminal organization that made money off of crashing the economy putting millions out out their jobs and homes Their executives should be in prison
#
# How about going for solar instead You know so poor people can afford to travel
#
# QE put a floor under the market years emergency moneyprinting asset distortions doesnt cause genuine free market capitalism
#
# There are many factors causing inflation Look back to the Carter Administration When foreign countries stop buying our debt look out
#
# Invenergys proposed power plant has been delayed once again Lets keep the pressure up and stop this thing once and for all MorganStanley
#
# Corporate tax cuts should stimulate inflation which will benefit investors at the expense of consumers
#
# If course the proposed tax cut will eliminate the tax credit for them Think that might effect sales
#
# Not if the Trump tax bill passes
#
# Xerox Document Company Morgan Stanley Anthem Blue Cross and Blue Shield NY Chamber of Commerce
#
# Equipped with a coal burner back up engine
#
# Morgan Stanley denied widespread market chatter that the bank is planning a new nonagency mortgage conduit via albyoon Read on Debtwire
#
# Germany have attempted to use wind when its season solar as stated when the sun shine to harness maximum use
#
# Birth dearth deflation
#
# And wages arent rising like they should
#
# Looking for another bailout
#
# Actually Uber is a pioneer in planning drone air taxis
#
# But new flying electric cars are already being tested that one day would be as cheap as cars are today can cause the next population shift
#
# Morgan Stanley raises some alarm bells on shale noting that world starting to rely on it more just as we start seeing limitations on it
#
# I sincerely DOUBT that a Billion will be on the Road Unless Batteries Double their current efficiency Price drops DRAMATICALLY
#
# TNF Americas Meeting Collateral Management panel led expertly by Thilo Derenbach Clearstream ably assisted by John Graham BNPParibas Gaurav Joshi PwCLLP Craig Jones Barclays and Michael Kaicher MorganStanley Challenges and developments
#
# You are delusional
#
#  in the United Stares But those coal burners are really something
#
# I doubt that get real
#
# World bank is wrong Morgan stanley is wrong IMF is wrong on demonitisation Only Sickulars r right on demonitisation
#
# By Rejecting the Broker Protocol Morgan Stanley is Building a Wall
#
# Why should anyone get a tax break for buying a car
#
#  Blog from November Criminal collapse of Citibank and Morgan Stanley imminent
#
# CSSMS If u guys were real financial advisoers wouldnt you be somewhere other than Morgan Stanley MSs perverse incentives drive
#
# Someone tell realDonaldTrump coal is obsolete then he needs to tell that to the coal miners
#
# I doubt this
#
# Morgan Stanley raised its forecast for oil prices saying US shale crude may not be able to meet growing demand
#
# This confirms my poor opinion of Morgan Stanley
#
# Yes and sadly Ill be off the earth by then
#
# Wind is THE MOST unreliable source of energy
#
# The Priceline Groups overweight rating reiterated at Morgan Stanley PT PCLN
#
# HYBRID Gasoline engine and Electric the gasoline engine charges the batteries of the electric engine The Porsche Spyder
#
# Las Vegas Sands upgraded to Overweight on Macau bullishness at Morgan Stanley LVS MGM WYNN
#
# LVS Las Vegas Sands upgraded to Overweight from Equal Weight at Morgan Stanley with a price target of
#
# Hell No
#
# And how many guns will there be by
#
# US tax reform to lift PC insurance earnings Morgan Stanley MorganStanley
#
# If pay rates and COLAs were attached to inflation rates it wouldnt be so bad for so many but were paid of Americans from yr ago
#
# One has to wonder what energy source will be used ro generate all that electricity to charge those billion vehicles
#
# US electricity generation by source is generated by coal So an increase in electric cars will increase demand for coal
#
# Online pressure Morgan Stanley recently warned that sales will outright decline during the holiday quarter
#
# No one in their right mind wants inflation only deflation The cost of living is way too high in many places and needs to be lowered ASAP
#
# OBVIOUSLY YOU DONT DO ANY SHOPPING AT Home Depot OR Lowes
#
# Better fire up some more coal plants to recharge all those bad boys
#
# No batteries last forever darn it
#
# Wages also have been stagnant
#
# And the landfills will be full of batteries leaking into the ground water
#
# Brent Crude trading above Morgan Stanley on OIL Raise forecast to by mid Prefer Reliance Ind GAIL petronet LNG IOC
#
# Sorry but your other comments tell me you have no idea what nothing really means
#
# What You want higher inflation
#
# Doubtful
#
# There is the unpopular concept of cutting back on cell phones TV programming other unnecessary stuff You gotta want it
#
# Oh no My company makes exhaust systems
#
# Oh I see So thats why the GOP wants to pass tax reform
#
# Investors need decisionuseful information from companies What does it mean According to MorganStanley Issues risks and opportunities analysis Uniform metrics and reliable data Alignment between quarterly annual
#
# Reported for spam
#
#  suck
#
# Why one analyst argues Morgan Stanley is a better investment than Goldman Sachs
#
# Ruth Porat is a Britishborn American financial executive who currently serves as CFO of Alphabet Inc as well as its subsidiary Google She was also CFO and executive vice president of Morgan Stanley and sits on Forbes top most powerful women
#
# such a HUGE mistake
#
# Morgan Stanley on Cement We remain constructive Prefer Ultratech Dalmia Bharat In north India the sand mining ban may hurt nearterm demand the shift to coal may lead to some cost rises We see this as transient mediumterm outlook is intact
#
# Morgan Stanley on PSU banks EW on BOB UW on BOI Canara Prefer SBI PNB After recent rally SoE banks are trading closer to adjusted book Incrementally riskreward is unfavorable return to doubledigit RoE will take years
#
# Where will we put all the spent lithium batteries Whats the plan to further pollute groundwater
#
# Because we little people the consumers have no more money to spend All the money is sucked up by the rich American Revolution needed
#
# Hello trump Is that Obamas fault too
#
# So there is no reason for this tax cut for the rich then No vote
#
# JeffFlake BobCorker SenJohnMcCain All economists Forbes and Morgan Stanley say this tax bill is bad for US Its not just the liberals Do the right think You dont need to vote yes ccusmcdoordie
#
# Dream on Nobody wants those expensive and limited range cars
#
# Marlins ownership seeking at least M in new capital MorganStanleys private wealth division advising Jeter adviser Greg Fleming is ex MS wealthasset management chief I see JonHeyman has teaser doc
#
# The planets going anyway Time to face that And if u have descendants so be it Actually Guttfields robots will probably be in charge by then They may not care being feelingless and all
#
# Morgan Stanley Australia Housing Lead Indicator at lowest level ever goes back to
#
# Based on this answer I cant tell whether JackEtienne is just bullish on OWL or if he actually thought MorganStanleys ATVI report wasnt filled with crazy assumptions
#
# But you arent sure what those effects are Given the option a lifeless desert is a better place to mine than anywhere else Learn more here
#
# The Fed Gov just approved a b military spending spending bill Where are the increased taxes I believe is proposing LESS taxes
#
# A kinetic point is why and who pays There are earth resources used Need to know how much and how we are as tax payers subsidize this movement Science isnt validated if it isnt defined by cause and effect results before anticipated outcome
#
# Ok genius hows this plan Have solar panels on house roof charge electric car overnight Havent noticed any increase in electric bills havent had to put gas in car since I bought it mos ago Youre using the same argument ppl used for replacing horses
#
# Morgan Stanley says latest Rockwell rebuff likely marks the end of Emerson pursuit ROK EMR
#
# SELL SNAP The stock has been downgraded by most main brokers including JP Morgan Morgan Stanley and UBS
#
# SELL SNAP it has a SELL rating by most the brokers including Morgan Stanley UBS JP Morgan
#
# Its bifurcated especially this month Commodities with deflation services with inflation Better than ten months of deflation we had during
#
#  of Americans had money stolen from them by you guys
#
# Morgan Stanley AMD Cryptocurrency Chip Market to Drop By
#
# Note the STEADY climb since so WHY arent US Corporations creating jobs AND helping pull an indebted America out of our hole How many BILLIONS is enough when the working poor middle class subsidize a wage under
#
# Thats bc gas prices are high creeping higherwages are low
#
# MorganStanley research finds that major initiativesdigitizing its predominantly cashbased economy and reforming its tax systemhave the potential to make one of the worlds fastestgrowing large economies Forbes
#
# Schwab execs sound off on Bitcoin HSAs and Morgan Stanley exit from broker protocol
#
# Donny and team are working on raising that inflation rate Just give them a minute
#
# Cookie chain Tiffs Treats locks in mln PE Hub This funding makes me hungry
#
# Schwab Exec Predicts Morgan Stanley Protocol Exit Will Backfire
#
# Morgan Stanleys pct stake in Deutsche Bank unrelated to Cerberus buying pct sources tell us MS stake held by multiple investors using the US bank as their broker
#
# Susan OFlynn MorganStanley speaking about how female hiring has been a major strategy for several yearsevery single division is held accountable
#
# The EEOC lawsuit vs Morgan Stanley would have had more impact but was filed on Sept It settled in
#
# DKS up on an upgrade to overweight by Morgan Stanley Probably a
#
# I get a statement from Morgan Stanley telling me whats happening with my That preacher dont tell them shit
#
#  Chip Market to Drop By
#
# No where near makes up for how much revenue we didnt get because of the tax cuts in the first place Which we are repeating currently We are going to go through another boombust cycle and hit another recession
#
# It means theyre trying to crush net neutrality so startups have to struggle more
#
# Well so the indicators say but many Americans see that wages SS benefits arent keeping up with inflation
#
# Wages are too low Top tax rate on the rich is too low Too much money is spent on the military
#
# The Procter Gamble Company PG Presents at Morgan Stanley Global Consumer Retail Conference Brokers Conference Transcript
#
# Not proportionally in the US as Trump has taken away tax incentives for US car manufacturers to produce electric cars
#
# By megabanks will have been replaced either by socialism or by a physical analogue to the current DC dumpster fire
#
# Dont say never it is actually the dems who dont have money for such things They accuse the right of what the left does ad is always the case
#
# Morgan Stanley Capital International has surprisingly removed Corporation from its Emerging Markets Index which foreign investors track to take investment decisions with fund size estimated at trillion
#
# Will More Firms Leave Broker ProtocolAfter Morgan Stanleys exit the recruiting scene could shift in a variety of ways says one industry watcher
#
# Hertz Global HTZ Increased Conviction That Structural Changes Are Needed Morgan Stanley
#
#  From liberal propaganda too
#
# Indias stable growth makes investing easier regardless of domestic and global concern MorganStanleys SwaKel tells nirajshah
#
#  world wide markets stockholders never knew Norton SEC criminal did he saw the k and never told you chemical had no money but had to answer to the street
#
# MorganStanley If I do what you tell me to do and then you tell me that I cannot do it who is at fault here
#
# Last weeks broker data shows Hartleys net seller m Morgan Stanley net buyer m Hartleys distributing to Morgans No prob with that
#
# Fake story Fake news Fake reporter
#
# My question is if Car companies can do it without massive kickbacks from the federal govt Can we just all admit that Tesla is giant bc of the incredible consumer incentives to make it affordable
#
# Or now bear with me this is some radical thinking we could power are vehicles with something clean that already exists Something most cars already run on the others can be converted Ah just being dum i guess time to go drink some fuel get drunk
#
# Hon Dburman moderating Shooting the BullWhat Regulators Need to Know to Understand wallstreet NARUC NYSDPS MorganStanley jpmorgan SPGMarketIntel
#
# Katy Zhao MorganStanley on CFABoston we use CDP for footprints benchmark to peer group and look to switch out high polluter for low polluter
#
# You need to go out into the various states Louisiana businesses closing Mississippi no jobs to name a few Ppl are struggling financially Where are the jobs
#
# Katy Zhao VP Portfolio Manager MorganStanley on CFABoston never want investor clients to quiz us on ratings from eg MSCIInc or Sustainalytics so our method argues for building it ourself
#
# Next on CFABoston stage Building Personalized Sustainable Investing Portfolios for High Net Worth Clients by Katy Zhao Vice President Portfolio Manager Financial Advisor MorganStanley and alumna of NYUStern
#
# And how much energy will it take to keep these things charged
#
# FinMKTG No selfrespecting advisor will want to join MorganStanley now that a No Exit sign is posted over the entryway says Elzweig
#
# Then lets get Morgan Stanley and Bank of America to pay back their loans to the taxpayers theyre wrong doers
#
# If businesses are doing so well why do they need a tax cut Well they dont they just need to increase the pay to a living wage min wage now
#
# Everywhere I travel in the US I see a boom as measured by the lack of open seats on airplanes soldout hotels and crowded restaurants not to mention the almostoutofcontrol construction activityin every city These are exactly the kinds of things that lead to inflation
#
# BAML and Morgan Stanley swaps drop bn on VM change
#
# The NALSC has finally kicked off Currently US Financing Considerations with John Hoffman Credit Suisse Kalli Dircks and Chris Rigoli Morgan Stanley and Jim Cirenza DNB Markets
#
# The only proven case Ive seen is the case of the Tories breaking the rules in Thanet South when they were up against one Nigel FarageRemain were bankrolled by Goldman Sachs Morgan Stanley and Citibank
#
# Encryption is done is NOT MD of Tech Info Risk MorganStanley this morning
#
# Yes Claiming that EV batteries are going to landfill is just ignorant and a google search away from fact All EV batteries in US are recycled or reused
#
# Andy inflation is rising It will increase cause Trump is destablize Mid East Oil is rising equal inflation go up You have been sold down the river by GOP establishment
#
# Morgan Stanley might win an award for making a dumbest statement of
#
# I avoided stairs at Morgan Stanley in the late s because stairs were where traders followed you so they could look up you skirt
#
# As Morgan Stanley exits the Broker Protocol Alan Foxman reminds advisors to check their employment contracts
#
# Morgan Stanley raised concerns about growth Firms report said the frequency of bookings slowed
#
# If they were less expensive many more would be purchased
#
# Sorry Morgan but electric cars arent ready for prime time And to get to billion would require more than million electric car salesyear Battery technology is still far too stilted to get there with a car which could drive more than milescharge
#
# Youre right the Repturds are deplorable
#
# Wait Just wait I expect rampant inflation due to the Trump effect
#
# CWIR today announced it has retained PondelWilkinson as its investor relations and strategic public relations firm Clients include MetroGoldwynMayer Morgan Stanley Procter Gamble Amgen and KPMG
#
# What is the plan for all of the hazardous waste created in their manufacturing process and needed for their operation
#
# Whoah Morgan Stanley just announced it acquired stake in Deutsche Bank Unclear in whose name
#
# BILL GIVEN TO IN SUBSTIDIES FROM GOV WOULDNT BE NICE TO HAVE BUSINESS TAKE HOME BILLIONS ASK GOV TO CARRY THE REST OF WAGES
#
# a Those banks also had the money to donate to McCain too in So they asked for trillions of tax money but used millions to get them into office to make sure they got it Numbers for both are from
#
# pay your way out of crime standard procedure for GoldmanSachs MorganStanley jpmorgan
#
# MorganStanley to seize control of China business after foreign rule Uturn
#
#  People claim that the banks needed the money thats a lie Americans needed the money and giving it to us instead would have also solved the problem Instead the banks CEOs got giant bonuses with our money Many of those banks had millions to give to Obama in the
#
# In talking to folks at MorganStanley and the founders they have backed they do more walking than talking on inequality Rare MS
#
# Morgan Stanley home of Adam Jonas again a big netseller of TSLA in Q TR Price seems to be stabilizing once owned MM
#
# Ill stick with my truck powered by unleaded fuel
#
# Inflation is not inherently good
#
# This AM on SquawkCNBC CEO Founder LisaSkeeteTatum discussed involvement w MorganStanley Innovation Lab and how Landit is increasing of women in the workplace Watch here
#
# California only has coal burning facility
#
# As predicted back at every quarter will reveal the weakness in SNAP and its undeserved valuation premium we see downside from here and sold on the spike today Downgraded to SELL by most of its IPO banks including lead bank Morgan Stanley last week with target
#
# Morgan Stanley is disappointed by Airbnb declining growth and brand awareness
#
# Over just years the Obama administration Doubled the national debt We have a huge spending problem and the govt needs to stay the hell out of healthcare
#
# Not at the pace of electric vehicle purchases today Not to mention the investment needed to have charging stations in the same numbers as todays gas stations A huge challenge in such a relatively short period of time
#
# Morgan Stanley MD Says Tax Reform Is Far From a Done Deal
#
# And that is bad
#
# How Morgan Stanley outdid Goldman in an old commodities rivalry
#
# How Morgan Stanley Outdid Goldman in Old Commodities Rivalry read the story TheTerminal JavierBlas jfarchy
#
# With the Nissan Leaf I wonder how many ppl have to tell their boss oops cant come to work bc I forgot to charge my car or having to take an Uber home bc they forgot to charge work
#
# A new Transitions in Employment blog post is up and Im discussing more effects of Morgan Stanleys exit from the Protocol for Read more
#
# Where will all the wasted battery go
#
# todays version of trickledown economics try again
#
# Implying that Obama will have been the cause of the next recession
#
# Not any more than its cost If the govt spent more on everything else that would increase GDP directly and be cheaper than the GOP plan to raise taxes on the middle class
#
#  They think IMF Chief Is Sanghi World Bank Chief Is Bhakt Morgan Stanley Is Paid Troll Rating Doesnt Matter And allow them loot the nation and keep feeding all poor with some yojanas which they will also use to loot and always keep them Poor
#
# Morgan Stanley warn about excessive JPY short positions
#
# But if the tax bill passes you wont get a tax credit for buying one in the US Trump wants cars that run on coal
#
# Today November AM ET KMI Kinder Morgan Is Maintained at Overweight by Morgan Stanley
#
# How Morgan Stanley outdid Goldman in old commodities rivalry
#
# MorganStanley This morning theres conflicting price targets for AMAT Is it or Considering AMAT was at youd think but report came after
#
# Jackson Senior Fellow Stephen Roach former chairman of Morgan Stanley Asia weighs in on the proposed tax reform plan on CNBC
#
# Wine women a spectacular view What could go wrong Nothing A hearty thx to Alix Magner Morgan Stanley Lani Basa Business Womens Circle for a spectacular evening Tues at the Guthrie Theater Together we can do so much more Lets keep it going
#
# Corbyn more dangerous for markets than hard Brexit warns Morgan Stanley via telegraph
#
# Corbyn more dangerous for markets than hard Brexit warns Morgan Stanley
#
# Thats because under Tories Morgan Stanley bank can avoid paying taxes and rip off ordinary people
#
# I think youre confusing JP Morgan and Morgan Stanley
#
# Corbyn more dangerous for markets than hard Brexit warns Morgan Stanley lbc
#
# Corbyn more dangerous for markets than hard Brexit warns Morgan Stanley via telebusiness
#
# It never endsthe tories are thieves Put them in prison with hms
#
# Corbyn more dangerous for markets than hard Brexit warns Morgan Stanley Telegraph
#
# Corbyn more dangerous for markets than Brexit say Morgan Stanley Are they right
#
# imagine trying to spin this as a bad thing MorganStanley
#
# The US Investment banks are going public these days it seems Corbyn more dangerous for markets than hard Brexit warns Morgan Stanley via telegraph
#
# Or to put it another way Corbyn more dangerous for Morgan Stanley than hard Brexit
#
#  just told its investors that another general election towards the end of was likely once Mays Govt realised it could not secure the Brexit deal it wants the Conservative party began to fall apart opening the door to Labour taking power
#
# Samsung Electronics shares drop after Morgan Stanley cuts view Seoul SAMSUNG Electronics Co Ltds shares fell more than per cent to a onemonth low on Monday after Morgan Stanley cut its recommendation on the South Korean gia
#
# What was Morgan Stanleys bailout for systematically derailing the global economy billion
#
# This country would improve overnight if everyone read and understood this article These banks and their leaders are the enemies of democracy and the population at large They exist to rob us This is Morgan Stanley spelling that out Couldnt be clearer
#
# That will be our old chums Morgan Stanley wholl relocate to Frankfurt regardless Benedict old chap
#
# Why the hell should an American investment bank have absolutely anything to say about British politics Back off Morgan Stanley you cant vote yet
#
# Morgan Stanley has told investors that another general election towards the end of is likely once Theresa Mays government realises it cannot secure the Brexit deal it wants and the Conservative party began to fall apart
#
# UBS to pull out of pact on broker recruiting joining Morgan Stanley via LisaBeilfuss
#
# Morgan Stanley is full of it They are also wrong UK is leaving the EU at the moment that can damage Morgan Stanley more they can imagine and given their short slightness they dont see it
#
# A flat tax is detrimental to low income earners and barely touches the
#
# I dont think Labour should take lectures from Morgan Stanley or telegraph tax exiles do you
#
# And if it keeps going the way it is the miners will be charging you more to move your money around the world than Morgan Stanley will once they get their blockchain up and running Bitcoin needs to evolve and fast
#
# Corbyn more dangerous for markets than hard Brexit warns Morgan Stanley Guessing theyre not one of johnmcdonnellMP s mysterious fund managers afneil
#
#  Chip Stocks Fall As Morgan Stanley Expects Memory Prices To Drop
#
# Morgan Stanley upgradea VALE a Overweight Buena
#
# UBS joins Morgan Stanley ditching broker recruiting agreement via BarronsOnline
#
# UBS to exit broker pact weeks after Morgan Stanley defected
#
# Springer Nature asks JP Morgan Morgan Stanley to organize IPO say sources Reuters
#
# Chip Stocks Fall As Morgan Stanley Expects Memory Prices To Drop
#
#  Corbyn more dangerous for markets than hard Brexit warns Morgan Stanley
#
# Know of lots unemployeed
#
# Id highly doubt that
#
# I inferred nothing In my last post I elaborated on the rhetoric used by economists to conceal their intent from regular people who think full means all available used
#
# With financial conditions at record easy conditions Morgan Stanley asks Is policy tightening excessive Va zerohedge
#
# zerohedge With financial conditions at record easy conditions Morgan Stanley asks Is policy tightening excessive
#
# With financial conditions at record easy conditions Morgan Stanley asks Is policy tightening excessive
#
# US gov counts person with jobs as people with job each hence the deceptive employment numbers In months a case of eggs has gone from to Trumps big mouth ran up sugar from a lb bag to a current No inflation Take a math class MorganStanley
#
# Morgan Stanley expects the Australian dollar to weaken to US cents
#
# initiated today Citi With Buy Goldman Neutral Mizuho Buy UBS Buy Barclays equalweight JPMorgan overweight PT equalweight at Morgan Stanley
#
# I voted Dem for years from Bill to Hillary in general election that is What a fool I was Never again Where were the Dems when Goldman was getting free reign from the Commodities Futures Trading Commission
#
# ICYMI How Morgan Stanley Outdid Goldman Sachs in Old Commodities Rivalry with jfarchy and dakincampbell
#
# Are you complaining
#
#  Slides As Morgan Stanley Says Sell On Amazon Risk CAH Also AMZN PDCO HSIC CVS ABC WBA TMO
#
# My cell phone battery sucks after a year cant wait to get one in my car
#
# We need fiscal prudence disclosure of risks and divestment to protect your customers from these stranded assets TDCanada scotiabank RBCCanada BMO cibc nationalbank HSBC WellsFargo MorganStanley jpmorgan BankofTokyo mizuhobanking
#
# RPCs RiskReward Has Turned Unfavorable According To Morgan Stanley get quality content from
#
# Currently investigating Gini Index or coefficient A gauge of economic inequality measuring income distribution Sample of how its used Morgan Stanley report
#
# Cardinal Health slides as Morgan Stanley says sell on Amazon risk CAH AMZN PDCO HSIC CVS WBA MCK ABC TMO
#
# Morgan Stanley brokers litigate eachother but remove the right of their clients to do the same via nypost
#
# Cardinal Health McKesson decline after declared by Morgan Stanley as most at risk in case of Amazon entry
#
# Cardinal Health McKesson decline after declared by Morgan Stanley as most at risk in case of Amazon entry
#
# Corporations and Businesses are using to pay CEOs stockholders and buy back their stock The American people KNOW that you and they are screwing the middle class and poor every day
#
# Morgan Stanley cautious on ANF with PT accelerating structural headwinds high inventory levels gross margin guide down
#
# Pricing models rolled out recently by Morgan Stanley and JPMorgan Chase Co charge thousands of dollars an hour
#
# JACOBIN Sen Gillibrands donors Morgan Stanley Goldman Sachs JP Morgan Chase Blackstone Group all rank consistently high on her top twentyUBS Deutsche Bank Citigroup also donatedGoldman Sachs gave more money to Gillibrand than any other congressperson in
#
# Amazon disruption of healthcare a foregone conclusion says Morgan Stanley AMZN CVS WBA CAH MCK ABC TMO HSIC PDCO
#
# zerohedge Too Early to Call All Clear on Equities Morgan Stanleys Wilson What thats crash didnt clear out the weak hands
#
# Too Early to Call All Clear on Equities Morgan Stanleys Wilson What thats crash didnt clear out the weak hands
#
# RT NickGiva Trading idea of the century buy TSLA shares through brokers with BUY rating MorganStanley short equal amount through IB Va zerohedge
#
# Cardinal Health cut to sell PT on outsized Amazon risk at Morgan Stanley CAH
#
# Except youre constantly bleeding borrow costs Not a synthetic put More buying call options on a lawsuit
#
# zerohedge RT NickGiva Trading idea of the century buy TSLA shares through brokers with BUY rating MorganStanley short equal amount through IB and when it all turns out to be a fraud join the class action against MS Resultfree synthetic put
#
# Morgan Stanleys buy rating reiterated at J P Morgan Chase Co MS
#
# Since when ever did we have full employlment Who writes this fantastical nonsense
#
# Something that goes up percent in a year its by definition speculative comments Morgan Stanley Chairman and CEO James Gorman So anybody who thinks theyre buying something that its a stable investment is deluding themselves
#
# Morgan Stanley The OPEC meeting Nov remains the key sector catalyst into yearend The market expectation is for an extension through created by comments early this fall but there is increased risk that OPEC delays the extension decision USO
#
# Morgan StanleyDo not expect break up of German coalition talks to turn into long term EUR negative factor StreetSignsCNBC
#
# Bharat Forge gets half its truck parts sales from crankshafts Which means over percent its revenue could be at risk Morgan Stanley said

# %% [markdown]
# ### Overall 23,-3

# %%
unique([(i['positive'],i['negative']) for i in msdata[22]])
# Out:
# [((1, -1), 852, 37.11),
#  ((1, -2), 389, 16.94),
#  ((2, -1), 330, 14.37),
#  ((2, -2), 185, 8.06),
#  ((3, -1), 184, 8.01),
#  ((1, -3), 108, 4.7),
#  ((2, -3), 88, 3.83),
#  ((3, -2), 58, 2.53),
#  ((1, -4), 34, 1.48),
#  ((4, -1), 21, 0.91),
#  ((2, -4), 17, 0.74),
#  ((3, -3), 12, 0.52),
#  ((3, -4), 10, 0.44),
#  ((4, -2), 5, 0.22),
#  ((4, -3), 1, 0.04),
#  ((5, -1), 1, 0.04),
#  ((3, -5), 1, 0.04)]

# %%
unique([(i['positive'],i['negative']) for i in msdata[23]])
# Out:
# [((1, -1), 959, 33.36),
#  ((1, -2), 492, 17.11),
#  ((2, -1), 390, 13.57),
#  ((1, -3), 267, 9.29),
#  ((3, -1), 224, 7.79),
#  ((2, -2), 188, 6.54),
#  ((2, -3), 97, 3.37),
#  ((3, -2), 84, 2.92),
#  ((1, -4), 56, 1.95),
#  ((4, -1), 29, 1.01),
#  ((3, -3), 27, 0.94),
#  ((2, -4), 25, 0.87),
#  ((3, -4), 17, 0.59),
#  ((4, -2), 9, 0.31),
#  ((4, -3), 4, 0.14),
#  ((1, -5), 3, 0.1),
#  ((5, -1), 2, 0.07),
#  ((4, -4), 1, 0.03),
#  ((5, -2), 1, 0.03)]

# %%
LDA([i for i in msdata[23] if i['positive']==1 and i['negative']==-3],10,7,{'morgan','stanley','morganstanley'})
# Out:
# ['0.010*"say" + 0.010*"tsla" + 0.008*"target" + 0.008*"stock" + 0.008*"m" + 0.007*"price" + 0.006*"trump"',
#  '0.037*"war" + 0.034*"recession" + 0.033*"trade" + 0.025*"world" + 0.024*"push" + 0.019*"fullblown" + 0.016*"toward"',
#  '0.008*"trade" + 0.008*"uschina" + 0.006*"stock" + 0.006*"loss" + 0.006*"buy" + 0.006*"volume" + 0.006*"top"',
#  '0.010*"fired" + 0.009*"say" + 0.007*"tariff" + 0.007*"michael" + 0.007*"wu" + 0.007*"adviser" + 0.007*"new"',
#  '0.022*"tesla" + 0.011*"analyst" + 0.010*"useless" + 0.010*"forecast" + 0.010*"wild" + 0.008*"time" + 0.008*"company"',
#  '0.017*"uber" + 0.013*"ipo" + 0.011*"look" + 0.011*"lyft" + 0.009*"money" + 0.009*"underwriter" + 0.007*"client"',
#  '0.020*"say" + 0.017*"easy" + 0.015*"hurting" + 0.015*"tesla" + 0.015*"thats" + 0.011*"brand" + 0.010*"saying"',
#  '0.011*"tesla" + 0.009*"june" + 0.007*"tsla" + 0.007*"analyst" + 0.007*"money" + 0.007*"bank" + 0.007*"around"',
#  '0.012*"tesla" + 0.011*"b" + 0.011*"market" + 0.008*"trade" + 0.008*"war" + 0.008*"bank" + 0.006*"recession"',
#  '0.010*"could" + 0.008*"win" + 0.008*"corporate" + 0.008*"get" + 0.006*"rate" + 0.006*"cash" + 0.006*"senator"']

# %%
text(search([i for i in msdata[23] if i['positive']==1 and i['negative']==-3],['tesla']))
# Out:
# [' How Wild Useless Are Tesla Analyst Forecasts Morgan Stanley Edition ',
#  'Adam Jonas of Morgan Stanley in his note We note that a Tesla share price of would put Teslas equity market valuation approximately at parity with SpaceX',
#  'Didnt we hear the same thing about the and AAPL a few years ago aztecs OJRenick MattRayTalk Morgan Stanley says its too easy to own a Tesla now and thats hurting the brand MS TSLA',
#  'Elon Musk owns B TSLA stock Larry Ellison owns B George Soros B Mark Cuban B vs MS clown analyst Adam Jonas who sold his soul to the devil taking orders from MorganStanley Morgan Stanley We see who has the power TESLA does ',
#  'Eroded Mindnumbing Miserable Musks weak track record of delivering on his promises Elon Musk Loads Up Tesla Stock But Carmaker Worst Enemy is Tesla Itself Morgan Stanley',
#  'From Morgan Stanley says its too easy to own a Tesla now and thats hurting the brand via rEconomics ',
#  'Hmmm Was that a Teslabranded mouse in the background',
#  'How Wild Useless Are Tesla Analyst Forecasts Morgan Stanley Edition ',
#  'How Wild Useless Are Tesla Analyst Forecasts Morgan Stanley Edition TSLA TSLAQ ',
#  'How Wild Useless Are Tesla Analyst Forecasts Morgan Stanley Edition via cleantechnica',
#  'How Wild Useless Are Tesla Analyst Forecasts Morgan StanleyEdition ',
#  'Imagine if GM had my engine mpg Buick They would OWN the car and truck market Bankrupt Tesla I could then partner and own the roadable airplane trillionyear market according to Morgan Stanley Read my tweets if you want to know the future EVs suck',
#  'In case you missed it Morgan Stanley had NO positives on Tesla in the call yesterday TSLA',
#  'It says more about Morgan Stanley than about Tesla imho',
#  'Its a cop out to lay this all on central banks Its excusing lazy analysis by analysts money managers Look at actual analysts notes on Tesla It is the fault of no central bank that Morgan Stanley valued TSLA Mobility which does not exist at B tech bubble redone',
#  'Morgan Stanley Warns Tesla Is Facing Bankruptcy ',
#  'Morgan Stanley piles pressure on Tesla with worst case call ',
#  'Morgan Stanley says its too easy to own a Tesla now and thats hurting brand CNBC ',
#  'Morgan Stanley says its too easy to own a Tesla now and thats hurting the brand ',
#  'Morgan Stanley says its too easy to own a Tesla now and thats hurting the brand by thesheetztweetz via cnbctech',
#  'Morgan Stanley says its too easy to own a Tesla now and thats hurting thebrand ',
#  'MorganStanley Bear Adam Jonas might be simply wants to UNLOAD GM shares into Retail investors and Accumulate TESLA shares Crooked WS ',
#  'RT AnsonMcCade Tesla Shifts From Growth To DistressedCredit Story Morgan Stanley Says via ansonmccade ',
#  'RT cybersecfeeds RT AnsonMcCade Tesla Shifts From Growth To DistressedCredit Story Morgan Stanley Says via ansonmccade ',
#  'Re Tesla hurting their brand by selling cheap cars I see their point',
#  'So Morgan Stanley are Banking and consulting in Moscow Does Putin like Tesla and SpaceX ',
#  'THE BURSTING OF THE TESLA STOCK BUBBLE Bloomberg Morgan Stanley threw the biggest blow declaring that in a worstcase scenario Teslas shares could sink to a shocking A Wedbush analyst TSLA TSLAQ',
#  'Tesla Shifts From Growth To DistressedCredit Story Morgan Stanley Says ',
#  'Tesla Shifts From Growth To DistressedCredit Story Morgan Stanley Says via ansonmccade ',
#  'Tesla TSLA Deal Highlights Its Desperate Need For Cash Morgan Stanley via StreetInsider',
#  'Tesla is shifting from a company many believed had vast longterm growth potential to a distressedcredit and restructuring story says Morgan Stanley ',
#  'Tesla stock stumbled early on Tuesday after Morgan Stanley slashed its bear case to a share down from over fears of increased debt ',
#  'Teslas increasing production rate and active resale market may be hurting the brands appeal and diminish demand for its cars Morgan Stanley said on Friday in a counterintuitive note to clients Counterintuitive is the new stupid EVNewsDaily ValueAnalyst',
#  'Teslas woes make it a restructuring story a Morgan Stanley analyst said a private call with investors via technology',
#  'This is same Morgan Stanley who say too many tesla cars on roads hurting tesla brand']

# %% [markdown]
# ### Over -3

# %%
unique([(i['positive'],i['negative']) for i in msdata[-2]])
# Out:
# [((1, -1), 971, 39.01),
#  ((1, -2), 437, 17.56),
#  ((2, -1), 304, 12.21),
#  ((2, -2), 180, 7.23),
#  ((1, -3), 163, 6.55),
#  ((3, -1), 136, 5.46),
#  ((2, -3), 95, 3.82),
#  ((1, -4), 57, 2.29),
#  ((3, -2), 49, 1.97),
#  ((2, -4), 27, 1.08),
#  ((3, -3), 22, 0.88),
#  ((3, -4), 18, 0.72),
#  ((4, -1), 12, 0.48),
#  ((4, -2), 7, 0.28),
#  ((1, -5), 4, 0.16),
#  ((4, -3), 3, 0.12),
#  ((2, -5), 2, 0.08),
#  ((3, -5), 1, 0.04),
#  ((4, -4), 1, 0.04)]

# %%
unique([(i['positive'],i['negative']) for i in msdata[-3]])
# Out:
# [((1, -1), 892, 34.9),
#  ((1, -2), 556, 21.75),
#  ((2, -1), 355, 13.89),
#  ((1, -3), 173, 6.77),
#  ((2, -2), 166, 6.49),
#  ((3, -1), 113, 4.42),
#  ((2, -3), 92, 3.6),
#  ((3, -2), 62, 2.43),
#  ((1, -4), 52, 2.03),
#  ((2, -4), 29, 1.13),
#  ((3, -3), 24, 0.94),
#  ((3, -4), 17, 0.67),
#  ((4, -2), 7, 0.27),
#  ((4, -1), 7, 0.27),
#  ((4, -3), 5, 0.2),
#  ((1, -5), 5, 0.2),
#  ((2, -5), 1, 0.04)]

# %%
LDA([i for i in msdata[-3] if i['positive']==1 and i['negative']==-2],10,7,{'morgan','stanley','morganstanley'})
# Out:
# ['0.017*"u" + 0.014*"coronavirus" + 0.009*"week" + 0.009*"next" + 0.009*"could" + 0.007*"look" + 0.007*"last"',
#  '0.014*"overweight" + 0.012*"price" + 0.011*"target" + 0.010*"case" + 0.010*"market" + 0.009*"recession" + 0.009*"galactic"',
#  '0.010*"price" + 0.008*"target" + 0.008*"share" + 0.007*"overweight" + 0.007*"sachs" + 0.006*"analyst" + 0.006*"group"',
#  '0.011*"risk" + 0.009*"u" + 0.008*"economy" + 0.008*"drop" + 0.006*"bn" + 0.006*"believe" + 0.005*"q"',
#  '0.054*"bank" + 0.023*"goldman" + 0.019*"sachs" + 0.017*"chase" + 0.015*"america" + 0.014*"well" + 0.014*"say"',
#  '0.008*"million" + 0.008*"jobless" + 0.008*"claim" + 0.008*"oil" + 0.008*"recession" + 0.007*"forecast" + 0.006*"market"',
#  '0.046*"recession" + 0.045*"global" + 0.025*"goldman" + 0.025*"declare" + 0.018*"case" + 0.014*"base" + 0.014*"sachs"',
#  '0.029*"pt" + 0.013*"maintains" + 0.009*"overweight" + 0.008*"time" + 0.007*"low" + 0.007*"raised" + 0.006*"m"',
#  '0.013*"global" + 0.011*"u" + 0.009*"lindy" + 0.008*"million" + 0.008*"one" + 0.008*"billion" + 0.007*"ahya"',
#  '0.016*"stock" + 0.013*"q" + 0.012*"gdp" + 0.011*"decline" + 0.007*"tesla" + 0.007*"overweight" + 0.006*"say"']

# %%
text(search([i for i in msdata[-3] if i['positive']==1 and i['negative']==-2],['oil']))
# Out:
# ['ETEnergyworld Oil price fall a net negative for global economy Morgan Stanley ',
#  'Is today the day I get to take a shot every time some wet wipe from Morgan Stanley says gardenvariety recession Spoiler alert theres no gardenvariety recession Theres always a cause',
#  'Morgan Stanley Base Case Global Recession Now DJIA F SP F Nasdaq F DXY GOLD F OIL F USDJPY Important Final SM MoveHHEODEOW ',
#  'Morgan Stanley Slashes Brent Oil Forecast To ',
#  'Morgan Stanley further cut its oil price forecast now expecting Brent crude to average a barrel during the second quarter from a barrel earlier ',
#  'Oil gas stocks rally after crude oil prices hit year low Morgan Stanley bullish on HPCL BPCL moneycontrolcom ',
#  'Putting it all together we believe the cumulative decline in oil prices since the beginning of the year if sustained is enough to reduce real GDP growth by about to bp MorganStanley',
#  'Ruchir Sharma Chief Global Strategist of Morgan Stanley on CNBC reallocate equity assets to markets that are oil importers have low dependence on globalization and a strong domestic market',
#  'The prices were hitting lower for long time its an excuse today to pump up The price for consumers will not be reduced Oil gas stocks rally after crude oil prices hit year low Morgan Stanley bullish on HPCL BPCL ',
#  'The spring forecast is still not out The is still using fall forecast which had oil at barrel Morgan Stanley is listing Brent futures at barrel ANS crude is around barrel When sprint forecasts comes out revenue projections will likely drop by million',
#  'Will Citigroup Bank of America and Morgan Stanley refuse to finance oil and gas projects in the Arctic Surely one of them will be willing to wreck the planet ']

# %% [markdown]
# ### Extreme

# %%
def extreme(data):
    result=[]
    for i in data:
        if i['positive']>=4 or i['negative']<=-4:
            result.append(i)
    return result

# %%
extreme_data=[extreme(i) for i in msdata]

# %% [markdown]
# 2017-06: 876191205893312512,innovation lab,870693133792694272,926549853622099968 <br>
# 2017-06 <br>
# 2017-06 <br>
# 2017-06 <br>

# %%
text(extreme_data[1])
# Out:
# [' MS stock price struggling close to the highest as crowd sentiment has been weakening Good results tom increasingly ',
#  ' yrs of constant war all over the MiddleEast thousands of dead people StopLying What is lying doing for you',
#  'Actually he saved America billions on globalist redistribution of wealth scam U people r disgrace to USA pushing propaganda to brainwash',
#  'And it killed off everything even huge beasts will again',
#  'And we were already headed for the Depression and unemployment due to Democratic actions prior to Republicans taking the wheel',
#  'Apparently Morgan Stanley is sexist they think females are incompetent idiots',
#  'Awards for Excellence Morgan Stanley reclaims the investment banking throne via Euromoney ',
#  'Awe yes The struggle was fuckin real But this time I dont think we will see depression we will see corruption THE GREAT FALL OF USA',
#  'Aww MS was looking forward to those kickbacks Sorry youll have to find other more creative ways to rape our economy now',
#  'Bartscott cant wait for Pittsburgh the world cant wait for an apology from the rape apologists at PSU',
#  'Bullish and wrong and clients are angry bearish and wrong and they fire you Barton Biggs Morgan Stanley',
#  'CA NY IL are broke and in horrible shape from taking care of the illegals instead of American Citizens',
#  'Can you imagine what horror it would be should Globalist Dems have their way We all will be living in a rd world like communityone is all',
#  'Closing Bell Happy Hour Stocks rise DJIA MorganStanley surge MS Nasdaq SP hit record highs VIDEO ',
#  'Considering climate change and many EPA regulations are a huge hoax invented for people like Gore to line his pockets I am not that worried',
#  'Divest',
#  'Election is over',
#  'Ever actually gone to a store The employees hate each other',
#  'Ewwh how disgusting ',
#  'Excellent Congratulations',
#  'Excellent observation Susan Its nonsense like this tripe MS is pushing that should keep any investor the HLL away from Morgan Stanley',
#  'Expanding women and girls access to the Internet Thats what women being tortured and abused need The frigging Internet Give me a break',
#  'Fear has no place in your success equation Carla Harris Morgan Stanley ',
#  'Former MorganStanley CEO Eyes Investment Vehicle ',
#  'FrightMongering Morons Global warming started yrs ago at the end of the LAST Ice AgeCyclical changes happenUsing fear for ',
#  'Good get is out of the UM all together They are going to be running the one world order for the globalist',
#  'Gorman hits Blankfein where it really hurts Morgan Stanley overtakes Goldman in market value ',
#  'Got to go to to prove a point Homeboy dont know squat LBJ would have been a better ref He act Increased and killed Dem',
#  'Ha Ha Pelosi Waters Both are crazy as outhouse rats',
#  'Hes pathological if lips R moving hes lying',
#  'Horrible ad Why are you wasting ad money twitter TwitterAdsHelp AdsAPI TwitterMktg TwitterSupport TwitterBusiness',
#  'I agree to a great extent but not re Planet Earth We are ALL in this together what one nation lets fail fails for us also All connect',
#  'I dont Democrats R caring loving Republicans R mean disgusting Dems tend right thing repubs do wrong thing ON purpose ',
#  'I finally got an interview with Morgan Stanley and Im totally pissing my pants ',
#  'I know ppl pWcJP morgan Morgan Stanley All hate itI think its more the amount of hours they workthe workload not rly the job itself',
#  'I read the accordtook our jobsour tax dollarschina India do not have to comply and rapes our nation',
#  'I think theyre not portraying hate messages Except maybe the disgusting tweet Ugh',
#  'ICYMI These soft skills are THE secret sauce to promotions Morgan Stanley banker explains whartonknows ',
#  'IF YOUR SO WORRIED ABOUT CLIMATE CHANGE HOW ABOUT YOU STOP POISONING OUR FOOD BY SPRAYING IT WITH VUG SPRAY POTUS VP',
#  'Id be worried about being paid downergroup Adani financials are now BB Morgan Stanley downgrade too ',
#  'Im not worried the blood sucking are leaving the UK for Europe about time we kicked the out anyway goodnews',
#  'In your dreams This is bad for the UK and for the EU No matter if Brexit is hard French wish or soft Spanish',
#  'IndeedPassive investing boom is creating a frightening risk for markets Morgan Stanley says ',
#  'Investors are climbing the last wall of worry but Morgan Stanley offers reasons to be optimistic ',
#  'Is a me feel bad about the millions of dollars she made trading Bank debt swaps for Morgan Stanley',
#  'Is the situation exacerbated by the likelihood that his memory of the past is completely romanticized macho bullshit Yeah Id say so',
#  'Is the truth Obummer lover',
#  'It may not be Dems vs Reps or any other divisionsits the wealthy getting wealthier the middle class shrinking etc communism',
#  'It was an excellent move will save US Trillions of Dollars lost jobs While China is allowed to pollute for another years unabated',
#  'Look at All the democratic run into the ground cities like San Fran Chicago Detroit Baltimore violence bankrupt Chicago strictest gun laws',
#  'Loved that Morgan Stanley have an internal project for brokers called Next Best Action ',
#  'Maybe they were celebrating an increased chance of their grandchildren living to a ripe old age instead of dying horribly of malaria etc',
#  'Millions of good job Like',
#  'Morgan Stanley NYSEMS Comments on iPhone Release and Jeep Spinoff ',
#  'Morgan Stanley The Debt Ceiling Worries Us Most Zero Hedge ',
#  'Morgan Stanley is a transaction with Wachovia LLC Financial Services Inc and vacant vehicles',
#  'Morgan Stanley is moving jobs from London to Frankfurt and Dublin after Brexit sources say ',
#  'Morgan Stanley passive investing boom is creating a frightening risk for markets LukeWGraham',
#  'Much more serious than debates Talking about murders World wide Pedo ring putting US risk',
#  'My retirement advisor with Morgan Stanley was the first person to wish me a happy birthday this year Being in your s is sure a thrill',
#  'No thats not why trump got elected he got elected bc he cheated lied used foreign nation win also paid off members of elect collge',
#  'Nope wont happen What chokes is the Leftist liberal Democrats wanting globalism here in America Look at EU Even Britain wants out',
#  'Obama Legacy Trillion Debt and ISIS',
#  'Oh Thats not good I dont likeapprove of that lifestyle but gays are human beings deserve to be treated as such Only God can judge',
#  'Passive investing boom is creating a frightening risk for markets Morgan Stanley says ',
#  'Passive investment may be cheap for investors but it is frightening Morgan Stanley strategist ',
#  'Piece is horrible Blind to trump attacks on EPA his push for more fossil fuel exploitation attacks on fuel efficiencyMorganStanley',
#  'Sad to see MorganStanley bowing to the gods of liberal dogma Prob makes the firm sick to read this must b penance for taking bailout',
#  'Sigh sigh wolf growl ha',
#  'Since youre an entity bent on profit and you look at the world in only measurable analytics you cant measure human influence ',
#  'Socal alone theres a million plus illegals voting ',
#  'Sounds good Now get my money out of fossil fuels and into renewables',
#  'TRAITOR he hates this country with a passion so obvious but he loves Russia and Putin',
#  'Terrible depreciation in the companies moving business and jobs to Europe easyJet and Morgan Stanley as examplesloss of passporting ',
#  'Than Morgan Stanley people are strange and dumb people The will regret this after the world takes Bitcoin in their middle ',
#  'Thank God for POTUS Trump pulling us out of such a terrible deal of pure NONSENSEWe should care our earthbut this was a bum deal U S',
#  'That Naspers ADR gap closed pretty aggressively Thanks Morgan Stanley',
#  'The real impact is that the egomaniacal moron is going to get us all killed Cant we fire him',
#  'The republicans a party of class dignity HA You are bullies name callers You cant discuss the issues without doing it sad bunch',
#  'The same people who loaded up on student loans and now cry foul will they do the same with a mortgage High odds',
#  'They told us back in that they would secure the border Neither side wants it But our President does',
#  'Think was World depression after WWI US housing crisis domino effect from the usual speculation drought in prairies poverty in Europe',
#  'This is bs Someone is sad no carbon dioxide credits Article at least admits trump was right about accord being political nonsense',
#  'This story should read the real impact on how Morgan Stanley will lose money after USA pulled out of that ridiculous corrupt agreement',
#  'Thrilled to announce that MorganStanley has invested in iCapital and will leverage our going forward ',
#  'Thrilled to be on such an amazing team Morgan Stanley digital chief AI to help advisers not cyborg bots ',
#  'Typical lack of understanding of the why the depression happenedgold standard money supply raising taxes to lack of Fed intervention',
#  'Unemployed Lol No where to go He was a kind man who loves his family Not sure what that is trump feels ',
#  'We did Wow So all the rioting fighting blood shed hate race lies and more lies A president who tweets his ass off btr than all',
#  'We look like selfish fools to rest of the world',
#  'Whatever I was agreeing that we have corruption so get off me and spew your anger elsewhere',
#  'Whether its NATO UN Climate Change even when they hate us they want our Dollars Gentleman who started Weather Report will tell u HOAX',
#  'Who is it that shuts down free speech with violence and riots Whos the party of hate Do ewe listen to the leftist media Hollywood',
#  'With this dip shit in office World war Death I dont see us progressing w this evil man in our White House ',
#  'Yeah but the biggest of all surprises would be to get rid of the nonfederal reserve Nothing federal abt them they make paper useless',
#  'Yeah it would be terrible if we made the world better and prevented a disaster because wed never prove the disaster was gonna happen',
#  'Yet the facts are still gop control three houses of gov Followed shortly by Great Depression massive unemployment and stock market Crash',
#  'You are pre judge mental and probably just plain mental OK if you are nobody will call you a fruitcake just know you are hate filled',
#  'You would be incorrect to judge anyones heart at least biblically speaking Clearly you are just a troll but try and be intelligent Sad',
#  'gop Reagan was a horrible ',
#  'i protest im w her Fresh memes daily ',
#  'it will improve US economy No more BS on climate change',
#  'oh is that the trained hate class your referring me to Write that down for your ancestors',
#  'sjupiter he only speaks in large font and horribly photoshopped propaganda']

# %% [markdown]
# **Data property**: hard to extract useful information

# %% [markdown]
# ## Service model

# %%
all_trend(metadata,0,[''])

# %%
all_trend(metadata,1,[''])

# %%
LDA(metadata[3][1],10,7,{'wealthfront','robo','advisor','like','roboadvisor','roboadvisors','advisor'})
# Out:
# ['0.012*"betterment" + 0.010*"u" + 0.010*"raise" + 0.010*"rise" + 0.009*"good" + 0.009*"million" + 0.008*"open"',
#  '0.019*"personal" + 0.017*"capital" + 0.016*"review" + 0.016*"money" + 0.013*"fund" + 0.012*"one" + 0.011*"via"',
#  '0.017*"digital" + 0.011*"via" + 0.010*"capital" + 0.009*"v" + 0.009*"advice" + 0.009*"financial" + 0.009*"first"',
#  '0.030*"advisor" + 0.014*"advisory" + 0.014*"via" + 0.011*"advice" + 0.011*"betterment" + 0.010*"build" + 0.008*"investing"',
#  '0.015*"advisor" + 0.015*"rt" + 0.014*"future" + 0.014*"sector" + 0.012*"ready" + 0.009*"use" + 0.008*"management"',
#  '0.020*"personalcapital" + 0.020*"capital" + 0.020*"personal" + 0.019*"robinhoodapp" + 0.014*"investment" + 0.013*"betterment" + 0.012*"via"',
#  '0.029*"advisor" + 0.026*"human" + 0.020*"personal" + 0.017*"capital" + 0.015*"via" + 0.012*"financial" + 0.010*"investing"',
#  '0.014*"personal" + 0.014*"capital" + 0.010*"market" + 0.009*"bank" + 0.008*"personalcapital" + 0.007*"review" + 0.007*"fidor"',
#  '0.016*"financial" + 0.014*"via" + 0.010*"think" + 0.009*"good" + 0.008*"read" + 0.007*"fee" + 0.006*"capital"',
#  '0.029*"investing" + 0.014*"transform" + 0.014*"roboanalysts" + 0.012*"responsible" + 0.012*"socially" + 0.010*"question" + 0.010*"ask"']

# %%
temp=[i for i in metadata[3][1] if i['positive']>=2]

# %%
other={'wealthfront','robo','advisor','like','roboadvisor','roboadvisors','advisor','u','robinhoodapp',
       'personalcapital','personal','capital','u','robinhood','v','betterment'}
LDA(temp,10,7,other)
# Out:
# ['0.021*"support" + 0.017*"ever" + 0.017*"integration" + 0.017*"u" + 0.017*"know" + 0.017*"brokersroboadvisors" + 0.017*"think"',
#  '0.014*"good" + 0.011*"fund" + 0.011*"want" + 0.011*"value" + 0.011*"cant" + 0.011*"stop" + 0.011*"rise"',
#  '0.026*"best" + 0.015*"thanks" + 0.011*"good" + 0.008*"finance" + 0.008*"look" + 0.008*"new" + 0.008*"see"',
#  '0.019*"please" + 0.019*"best" + 0.019*"v" + 0.019*"mint" + 0.015*"support" + 0.015*"add" + 0.015*"work"',
#  '0.016*"account" + 0.010*"v" + 0.010*"advisor" + 0.010*"much" + 0.010*"support" + 0.010*"im" + 0.007*"plan"',
#  '0.020*"good" + 0.017*"advisor" + 0.014*"financial" + 0.010*"great" + 0.010*"account" + 0.010*"interesting" + 0.010*"plus"',
#  '0.019*"support" + 0.013*"advisor" + 0.010*"good" + 0.010*"u" + 0.010*"much" + 0.007*"year" + 0.007*"advice"',
#  '0.021*"advisor" + 0.018*"would" + 0.014*"good" + 0.014*"money" + 0.011*"via" + 0.011*"fee" + 0.011*"account"',
#  '0.023*"please" + 0.017*"love" + 0.010*"look" + 0.010*"think" + 0.010*"get" + 0.010*"one" + 0.010*"customer"',
#  '0.032*"review" + 0.022*"safe" + 0.022*"simple" + 0.019*"wealthsimple" + 0.013*"via" + 0.013*"excel" + 0.013*"bonus"']

# %%
LDA([i for i in metadata[3][11] if i['positive']>=2],10,7,other)
# Out:
# ['0.013*"advisor" + 0.010*"great" + 0.010*"good" + 0.009*"also" + 0.009*"best" + 0.009*"one" + 0.009*"investor"',
#  '0.010*"people" + 0.010*"would" + 0.009*"help" + 0.008*"advisor" + 0.008*"dont" + 0.006*"thanks" + 0.006*"investing"',
#  '0.012*"advisor" + 0.009*"great" + 0.009*"best" + 0.008*"human" + 0.008*"fund" + 0.008*"money" + 0.008*"want"',
#  '0.011*"one" + 0.009*"digital" + 0.008*"new" + 0.008*"able" + 0.008*"well" + 0.007*"pretty" + 0.006*"dashboard"',
#  '0.009*"get" + 0.008*"see" + 0.008*"account" + 0.007*"support" + 0.006*"really" + 0.006*"cost" + 0.006*"security"',
#  '0.016*"advisor" + 0.009*"money" + 0.009*"via" + 0.007*"spend" + 0.007*"account" + 0.007*"best" + 0.006*"financial"',
#  '0.009*"use" + 0.008*"investment" + 0.007*"fee" + 0.007*"month" + 0.006*"money" + 0.006*"fund" + 0.006*"finance"',
#  '0.014*"client" + 0.008*"advisor" + 0.008*"fee" + 0.007*"support" + 0.007*"financial" + 0.005*"run" + 0.005*"technology"',
#  '0.008*"need" + 0.008*"investing" + 0.006*"best" + 0.006*"change" + 0.006*"security" + 0.006*"invest" + 0.005*"always"',
#  '0.014*"fee" + 0.007*"work" + 0.007*"cost" + 0.007*"love" + 0.007*"happy" + 0.006*"great" + 0.006*"advisor"']

# %% [markdown]
# **Difficulty of topic modelling**<br>
# <li>Merged data may not have a unified topic</li>
# <li>Unmeaningful output; from output (words) to original meaning</li>
# <li>Time consuming(number of topics)</li>
#
# **Future method**: associate them with events from news search<br>

# %%
service=['customer service','user experience','customer experience','online experience','client service','client support',
         'customer support','client experience']
all_trend(metadata,0,service)

# %%
all_trend(metadata,1,service)

# %%
#all_trend(metadata,1,service)

# %% [markdown]
# ### LDA

# %%
NMF(search(metadata[1][12],service),10,10,{})
# Out:
# ['"investment" + "man" + "online" + "call" + "year" + "etrade" + "irate" + "suit" + "time" + "called"',
#  '"stay" + "question" + "cant" + "away" + "feel" + "really" + "company" + "get" + "wanted" + "account"',
#  '"information" + "call" + "time" + "center" + "phone" + "looking" + "support" + "help" + "robinhoodapp" + "number"',
#  '"answer" + "responsible" + "asking" + "idzik" + "associate" + "paul" + "twice" + "joke" + "different" + "etrade"',
#  '"future" + "im" + "free" + "guy" + "chat" + "week" + "call" + "rep" + "best" + "charlesschwab"',
#  '"didnt" + "send" + "problem" + "pay" + "good" + "thank" + "etrade" + "lot" + "got" + "great"',
#  '"response" + "havent" + "support" + "different" + "tdameritrade" + "worst" + "nothing" + "trade" + "issue" + "yesterday"',
#  '"free" + "long" + "respond" + "bullshit" + "take" + "cant" + "email" + "phone" + "askrobinhood" + "robinhood"',
#  '"worst" + "offer" + "away" + "tdameritrade" + "used" + "price" + "long" + "fidelity" + "never" + "make"',
#  '"contact" + "tdameritrade" + "use" + "experience" + "link" + "used" + "pm" + "ameritrade" + "td" + "client"']

# %%
NMF(search(metadata[1][13],service),10,10,{})
# Out:
# ['"phone" + "time" + "pleased" + "support" + "rep" + "get" + "chat" + "tdameritrade" + "ive" + "im"',
#  '"recently" + "response" + "chat" + "fee" + "platform" + "use" + "awesome" + "theyre" + "etrade" + "great"',
#  '"create" + "call" + "shape" + "data" + "center" + "ameritrade" + "experience" + "client" + "advisor" + "td"',
#  '"via" + "transfer" + "let" + "option" + "awesome" + "hr" + "sending" + "much" + "support" + "robinhoodapp"',
#  '"hey" + "brokerage" + "people" + "tdameritrade" + "last" + "love" + "randomly" + "night" + "wrote" + "guy"',
#  '"calling" + "account" + "client" + "looking" + "like" + "specialist" + "hiring" + "check" + "charles" + "schwab"',
#  '"thats" + "live" + "robinhood" + "business" + "excellent" + "broker" + "complaint" + "go" + "site" + "better"',
#  '"looking" + "helpful" + "brokerage" + "hey" + "taking" + "made" + "worse" + "make" + "day" + "trade"',
#  '"way" + "also" + "country" + "house" + "update" + "use" + "charlesschwab" + "resolve" + "week" + "sent"',
#  '"yet" + "cash" + "waiting" + "call" + "client" + "ridiculous" + "tdameritrade" + "called" + "outside" + "app"']

# %%
double(metadata[1],service)

# %%
for i in range(36): # good: charles schwab; bad: td, robinhood
    print(text(extreme(search(metadata[1][i],service))))
    print()
# Out:
# ['CharlesSchwab has excellent customer service', 'Its a shame that jonnajarian and petenajarian sold Trade Monster to etrade The customer service is now horrendous', 'SunTrust HORRIBLE customer service Changing everything to Charles Schwab after yrs banking w SunTrust after this', 'no worries i finally got a good customer service guy in denver thats gonna double check on me', 'tyhall Stocktwits I like Interactive brokers Cheap but excellent execution Customer service could be better though']
#
# ['CharlesSchwab I hate your hold entertainment but your overthephone customer service is wonderful cc Tracy in Indianapolis ', 'TERRIBLE CUSTOMER SERVICE at scamhood too', 'Their customer support is honestly terrible too Super slow and unresponsive', 'etrade HORRIBLE EXPERIENCE TODAY WITH THE PLATFORM NO CUSTOMER SERVICE AND STILL HAVING PROBLEMS  MINUTES INTO SESSION', 'etrade ur customer service is appalling Ur leaving msgs wout enuf info NOT HELPFUL Why', 'horrible customer service', 'tyhall Stocktwits I like Interactive brokers Cheap but excellent execution Customer service could be better though']
#
# ['Horrible customer service IBKR Interactive Brokers My other brokers R much more helpful courteous ', 'I would gladly pay RobinhoodApp month for better customer service its pretty atrocious the delay times in response for a product', 'RobinhoodApp  your app but your customer support is truly awful Ive contacted many times and every time same automated answer', 'RobinhoodApp you are horrible Your customer service is the worst You tried to steal k frommy bank account then charged me  Thieves', 'RobinhoodApp your customer service is horrible Called about a placed bid and got hung up on Still waiting for someone to answer WTF', 'Thank you ETRADE The problem is all resolved and your customer service was extremely helpful']
#
# ['CharlesSchwab has consistently provided me excellent customer service just wanted to put that out in the universe ', 'So far the only ones I have been in business with that are very great in customer service are Chase and Charles Schwab', 'USDCAD EURUSD NZDUSD AUDUSD USDJPY TDAmeritrade customer service is worst Arrogant people arrogant customer service culture', 'etrade  days in a row Come on called customer support and no help Your system works on your end but not the customers Very upset ']
#
# ['Horrible experience with charlesschwabcom Worst customer service ever', 'I hate ur slow response time for customers Let me get in their Ill build a customer support team thatll increase clientele RobinhoodApp', 'Received magnificent customer service today from TDAmeritrade ', 'RobinhoodApp Robinhood customer service is the worst in the financial services industry It is beyond terrible vladtenev CNano', 'RobinhoodApp Your customer service is the worst in the industry It is beyond terrible', 'Super excited about the  days of free trading from TDAmeritrade best customer service ever', 'TDAmeritrade you are sucks your application doesnt work your thinkorswim cannot load charts and L and your customer service is horrible', 'TDBankUS TDAmeritrade terrible customer service and disappointing on a retail account for jordansfurn late fee nickel and diming', 'thomaspeterffy horrible customer service still k shares are not shown after transfer process confirmation from Robinhood pls help']
#
# ['CharlesSchwab I opened an account with you last week and plan to close it as soon as I can get my money out Your customer service is abhorrent', 'I am dreading the merger if I loss the site and customer service I am familiar with Have used Merrill lynch and Edward Jones in the past Settled at Ameritrade years ago and have never hade a compliant Love it', 'It would be a huge mistake to voluntarily switch from TD to Schwab In technology customer support RIA support fixed income and trade execution TD Ameritrade is  times better than Schwab Schwab is awful', 'Its a good step forward that RobinhoodApp is adding DRIP Dividend Reinvestment Plan and fractional shares but what really needs fixing is your customer service Not having a human to call is really frustrating and the core reason why I moved to CharlesSchwab', 'Its a good step forward that RobinhoodApp is adding DRIP Dividend Reinvestment Plan and fractional shares but what really needs fixing is your customer service Not having a human to call is really frustrating and the core reason why I moved to CharlesSchwab', 'RIAs are NOT split over Schwabs proposed predatory takeover of TD Ameritrade TD was  times superior in customer service support technology and trading than Schwab If there was ever a deal that should be rejected for antitrust violations its this awful Schwab deal', 'RobinhoodApp Customer service is Terrible', 'Schwab is the absolute worst financial institution in the nation Totally customer unfriendly with antique technology and horrible customer support', 'Shittiest customer service award goes to who ever I talked to at etrade today You used to be a classy platform who would go out of their way for custoners What happened ', 'TD Ameritrade customer support sucks They have been wrong on several occasions just this year when I have called Schwab may not be any better but TD Ameritrade is terrible', 'TDAmeritrade I love you all I have no regrets leaving allyfinancial to join the TD Think or Swim team The most robust trading platform along with excellent customer service Today I made a mistake by selling apart of my position that I wanted to add too', 'TDAmeritrade why is your client service terrible When asked for commission rates I was told you cant match other company rates even though I have large account with you No wonder you are going down the hill', 'This is terrible customer service if you ask me ']
#
# ['After watching the absolute and utter incompetence of TD Ameritrade employees firsthand today I now understand why the Cubs are in free fall mode Piss poor Customer service is dead and TD Ameritrade killed it', 'Anyone else discouraged by how terrible Fidelity Investments customer service is these days ', 'Are you looking for an with stellar customer service Look no further than our  Annual Review Best in Class finishers TDAmeritrade MerrillEdge Ally fidelity and CharlesSchwab Read our full review here ', 'I have tried several different platforms this is by far the worst with terrible connectivity issues desktop never syncs with mobile clumsy interface and unknowledgeable or otherwise unwilling to help customer service Yet fees are charged I recommend any other platform', 'If you are not banking with TDBankUS or trading with TDAmeritrade TDANetwork you are missing out of EXECUTIVE FIRST CLASS customer service NO dont work for them no spouse works for them I am just an EXTREMELY happy customer They work for ME I DO NOT work for them ', 'RobinhoodApp I am extremely displeased with your customer service This is absurd', 'RobinhoodApp Robinghood i come to find out is a terrible platform for trading Wont allow me to withdrawal my funds No customer support Have sent emails with no response Very disappointed', 'TDAmeritrade What happened this morning at Market Open Awful execution and glitchy Is this something to expect in the future It is imperative this does not happen again Customer service wait times are out of control right now', 'The ammount of lagging and order execution delay its been unreal lately And customer service is not helpful other than saying everything is OK on their end The platform needs to be fixed we in Canada still pay high commissions Is not free', 'Yeap this is multiple days in a row Customer service used to be so good now horrible sad', 'dude thats my goal right there but not on robinhood they have horrible customer service switch to TD ameritrade they have  service and no more fees on options stock purchases congrats on the great returns on tesla also uber', 'dude thats my goal right there but not on robinhood they have horrible customer service switch to TD ameritrade they have  service and no more fees on options stock purchases congrats on the great returns on tesla also uber', 'etrade opening an account with etrade was a terrible idea I had my money on closing day Thursday and lost it all on Friday customer service says thats the risk I take in trading WOW']
#
and cleared it all up Hats off Faith', 'AskRobinhood terrible customer service and holding peoples money for no reason Im calling the SEC everyone just call Its so simple and they will call u back within  hours Restricted accounts for week Robinhood your garbage and Im leaving', 'AskRobinhood terrible customer service and holding peoples money for no reason Im calling the SEC like just call them Its so simple and they will call u back within  hours Restricted accounts for week Robinhood your garbage and Im leaving', 'CharlesSchwab On hold almost  minutes waiting to speak to a human Awful customer serviceyou should be waiving fees as this service is awful POOR POOR POOR', 'ClassRobinhood So this happened to me ACB shares gone except forI didnt sell any of my shares Neither did I make any money for the shares that are missing I had more then one On Robinhood an because they have terrible customer service I cant get the help i needed', 'I called customer service They treated me like I was a liar The told me that they would open a case but that very probably they cannot honor me the losses incured from the TOS issue Terrible experience Thinking to move my over  to another broker TDAmeritrade', 'I have a trade related issue Robinhood refuses to fix it The horrible Robinhood customer service continues The rep is Chloe Useless ', 'I have joined the Etrade app Extremely great customer service Thanks tim for the recommendations of Etrade', 'I joined Etrade Havent deposited any money yet Still learning how to trade properly fromTim Sykes You cant trust a brokerage company that doesnt have a phone number For customer service Been with Robinhood  years I hated all three years', 'I may be ready to move on from etrade after almost  years Ive never needed their customer service before so just now realizing its pretty terrible ', 'I might need to take my money out of yall and go to E Trade The customer service is terrible and yall app is down Like wth', 'Robinhood customer service is horrendous', 'Robinhood is terrible Im sorry but its just a terrible service Horrible customer serviceHello etrade', 'RobinhoodApp If you care at all about customer service please let me know how youd like to get my business back I truly believe in not just your business but also your mission and values however that oversight I mentioned earlier was extremely irritating', 'RobinhoodApp is terrible IMO I have been trying to close my account for  weeks Customer service is awful I moved to CharlesSchwab late last year and my experience has been nothing short of exceptional Id recommend looking at more reputable brokers', 'RobinhoodApp shout out to this company while you cant reach them by phone there is no need to they have the most excellent customer service and follow through that I have seen and worked with in a very long time my account was turned upside down they worked it out Faith restor', 'TDAmeritrade Your customer service is extremely frustrating and subpar I was waiting more than  mins to get an assistance then I hung up because none of your agent got connected and had no more time Your messenger based service is also ridiculous No one could help me either', 'TDAmeritrade thinkorswim customer s ...

# %%
plt.plot(classify(metadata[0])[0],'d',color='C1',label='bank pos')
plt.plot(classify(metadata[0])[1],'d',color='C2',label='bank neg')
plt.plot(classify(metadata[1])[0],color='C1',label='discount pos')
plt.plot(classify(metadata[1])[1],color='C2',label='discount neg')
plt.legend()
plt.show()

# %%
online=['digital service','digital platform','online service','mobile app','online account','self service','selfservice',
        'online experience']
all_trend(metadata,0,online)

# %%
online=['digital service','digital platform','online service','mobile app','online account','self service','selfservice',
        'online experience']
all_trend(metadata,1,online)

# %%
search(metadata[1][13],online)
# Out:
# [{'text': 'Really pissed off at CharlesSchwab iOS mobile app Improve your app plz Super slowwwwwww',
#   'positive': 3,
#   'negative': -4},
#  {'text': 'CharlesSchwab mobile app being down is a big problem right now',
#   'positive': 1,
#   'negative': -2},
#  {'text': 'CharlesSchwab your mobile app is seriously unhappy right now',
#   'positive': 1,
#   'negative': -3},
#  {'text': 'etrade no existing orders of mine are showing up this morning on the mobile app for the second day in a row This is absurd',
#   'positive': 1,
#   'negative': -2},
#  {'text': 'MATRADEs seminar today to highlight as a vehicle to access Japan is a big hit It shows SMEs growing interest to adopt digital platform to grow their export business JoProBlog ',
#   'positive': 2,
#   'negative': -1},
#  {'text': 'etrade streaming quotes not working this morning On mobile app for iOS All well yesterday do this daily Relaunched app multiple times no luck Still see vol from yesterday vs pre mkt',
#   'positive': 3,
#   'negative': -1},
#  {'text': 'have you checked out etrade lately they would give you power pro for free for your PC and their mobile app is actually excellent for options but thats besides the point robinhood charges a lot more on their spreads when you buysell was my point',
#   'positive': 4,
#   'negative': -2},
#  {'text': 'etrade STOP RESTRICTING MY ACCOUNT EVERY TIME I OPEN THE MOBILE APP Fix your app Missed like  good trades I had planned',
#   'positive': 2,
#   'negative': -2},
#  {'text': 'My other alternative would be Etrade they offer same commission fees execution quality so Ive read Goal is to eventually grow my account to K and open an account with Interactive Brokers Do you only trade via mobile app',
#   'positive': 1,
#   'negative': -2},
#  {'text': 'My other alternative would be Etrade they offer same commission fees execution quality so Ive read Goal is to eventually grow my account to K and open an account with Interactive Brokers Do you only trade via mobile app',
#   'positive': 1,
#   'negative': -2},
#  {'text': 'RobinhoodApp AskRobinhood can you plz make the cost equity invested available for the mobile app so tedious to have to addsubtract gains also fix the all time charts already ',
#   'positive': 1,
#   'negative': -3},
#  {'text': 'RobinhoodApp ive been able to reproduce a pretty serious security flaw several times on the mobile app How do i get in touch',
#   'positive': 3,
#   'negative': -2},
#  {'text': 'RobinhoodApp why do I have to verify my bank account separately on the website and on the mobile app This is insanity especially given how long it takes for each separate process to finish',
#   'positive': 1,
#   'negative': -1},
#  {'text': ' fee share dealing mobile app launching in the UK ',
#   'positive': 1,
#   'negative': -1},
#  {'text': 'As more and more financial transactions take place online its important to have the best mobile apps and tools to make financial management easier CEO iWrixen recommends mint and RobinhoodApp for individual wealth building on Forbes ',
#   'positive': 2,
#   'negative': -1},
#  {'text': 'TDAmeritrade how can I change mobile app login to use fingerprint instead of typing in password samsung android',
#   'positive': 1,
#   'negative': -1},
#  {'text': 'TDAmeritrade annoyed with mobile app having to keep login in for real time quotes',
#   'positive': 1,
#   'negative': -3},
#  {'text': 'TDAmeritrade Your trade quotes are not even correct On the mobile app',
#   'positive': 1,
#   'negative': -1},
#  {'text': 'Ok TDAmeritrade mobile app thisd be nothing short of a heart attack What happened here All accounts are showing  positions and  balance ',
#   'positive': 1,
#   'negative': -3},
#  {'text': 'Oh I see I have the TDAmeritrade mobile app but its really just for emergencies Very rarely my neighborhood gets power outages that last a few seconds Never occurred during a trade but you never know Other than that Ive never traded on a mobile app',
#   'positive': 1,
#   'negative': -2},
#  {'text': 'Im using td ameritrade mobile app', 'positive': 1, 'negative': -1},
#  {'text': 'TDAmeritrade mobile app is down Cant login from browser as well Called client services and waiting over  mins now ridiculous',
#   'positive': 1,
#   'negative': -3},
#  {'text': 'TDAmeritrade you had to go and destroy the mobile app Now no one can log into it If it aint broken dont fix it',
#   'positive': 1,
#   'negative': -3},
#  {'text': 'TDAmeritrade mobile apps not working this morning Log in failed try again later',
#   'positive': 1,
#   'negative': -3},
#  {'text': 'One of the worst mobile app Going to file complaints in FINRA regarding the same and will share my experience on social media and CNN and other major channels',
#   'positive': 1,
#   'negative': -3},
#  {'text': 'What fix I lost my k because of bug in your mobile app',
#   'positive': 1,
#   'negative': -2},
#  {'text': 'I am yet to get any response from you guys I lost my  k because of bug in your mobile app Now i am going to take the help of social media and share my bad experience with tdameritrade I will share my experience with media as well As there is no help from your side other than',
#   'positive': 1,
#   'negative': -2}]

# %%
search(metadata[1][14],online)
# Out:
# [{'text': 'WaltBettinger hello sir big fan of the CharlesSchwab platformsthey arbitrarily removed a feature called IDEA HUB from the mobile app and no one seems to knows why or if they are bringing it backi would love to see it in the app againyour help is greatly appreciate it',
#   'positive': 3,
#   'negative': -1},
#  {'text': 'JonathanCraig hi Jonathan i am a CharlesSchwab customer big fan of the street smart edge platform someone decided to remove the IDEA HUB from the mobile appany chance of bringing it back',
#   'positive': 2,
#   'negative': -1},
#  {'text': 'Can someone at CharlesSchwab fix a problem with my mobile app All discussions I had today went nowhere',
#   'positive': 1,
#   'negative': -2},
#  {'text': 'One of my most used apps is CharlesSchwab Great job team The digital products web mobile app are great manifestations of the quality your customer service It shows how much competitive user research you did for these latest features',
#   'positive': 3,
#   'negative': -1},
#  {'text': 'Etrade mobile app gives great charts',
#   'positive': 3,
#   'negative': -1},
#  {'text': 'WebullGlobal I got to say you outdone yourselves on your mobile app I downloaded on ios and droid and I got to say wow You put RobinhoodApp etrade and TDAmeritrade and others to shame am yet to try to trade on your platform',
#   'positive': 3,
#   'negative': -3},
#  {'text': 'etrade you would not be using AI on your mobile app to trade against my buy and sell orders would you Odd how prices moved against me',
#   'positive': 1,
#   'negative': -2},
#  {'text': 'Ill never forget the day I bought for the first time I was sitting out on my back deck frustrated as all hell Why it had just taken so long and been so difficult to buy this thing Mobile apps like RobinhoodApp are helping to simplify the process',
#   'positive': 2,
#   'negative': -3},
#  {'text': 'WebullGlobal I got to say you outdone yourselves on your mobile app I downloaded on ios and droid and I got to say wow You put RobinhoodApp etrade and TDAmeritrade and others to shame am yet to try to trade on your platform',
#   'positive': 3,
#   'negative': -3},
#  {'text': 'Ive never used webull but I do trade via robinhood sometimes and having Think or Swim as a platform and mobile app to utilize the charting plus other available tools including depth L Options Chains and more has been amazing',
#   'positive': 3,
#   'negative': -1},
#  {'text': 'WebullGlobal I got to say you outdone yourselves on your mobile app I downloaded on ios and droid and I got to say wow You put RobinhoodApp etrade and TDAmeritrade and others to shame am yet to try to trade on your platform',
#   'positive': 3,
#   'negative': -3},
#  {'text': 'scottforflorida flgovscott SUPPORTED tdameritrade STEALING my FL REAL PROPERTY over  my car assets illegally hacking online accounts violating wife children out of state foxnews cnbc potus corporate crime against ',
#   'positive': 2,
#   'negative': -4},
#  {'text': 'i have Merrill EDGE user friendly and nice set of tools but cant trade VXX i have Fidelity and while i like their execution speed not a fan of their mobile app landing page also just opened a Schwab which i like the best may transfer more funds into SWB',
#   'positive': 2,
#   'negative': -1},
#  {'text': 'We have made all of our money on our smartphones from TDAmeritrade mobile app Think Or Swim',
#   'positive': 2,
#   'negative': -1},
#  {'text': 'Digital  is the services ecosystem powering our mobile apps Digital  extends that ecosystem to every nextgen interface that we are seeing across the planet Great interview with TDAmeritrade VijaySTDA via marthaheller',
#   'positive': 3,
#   'negative': -1}]

# %%
search(metadata[1][-5],online)
# Out:
# [{'text': 'CharlesSchwab whats up with the log in trouble on the mobile app',
#   'positive': 2,
#   'negative': -2},
#  {'text': 'Hi I like Charles Schwab and SSE Mobile app sucks desktop version solid Only issues when buy go to sell move your sell around too fast it just locks up and a couple times I watch my profits go cause I cant do anything Fix is edit the sell dont move and cancel too much',
#   'positive': 2,
#   'negative': -2},
#  {'text': 'etrade whats up with mobile app Has not been updated bid ask or profit loss all morning but will execute trades',
#   'positive': 2,
#   'negative': -3},
#  {'text': 'I like the interface a bit better yeah but to be fair I havent really used Robinhood at all because my capital is already spread between webull ally and etrade I only opened robinhood acct for the free stonks I love webull desktop platform but the mobile app could be better',
#   'positive': 3,
#   'negative': -1},
#  {'text': 'etrade I had  in shares in  I had not checked my online account for  years relying on statements for updates I went to cash in my shares and was told you have eschewed cancelled them You never emailed telephoned or wrote to me How can this be legal',
#   'positive': 1,
#   'negative': -2},
#  {'text': 'etrade Your mobile app and website are showing  entirely different prices on things Are you trying to manipulate the markets a little things going on here ',
#   'positive': 1,
#   'negative': -2},
#  {'text': 'I closed mine  yrs ago and switched to Interactive Brokers for options trading IBs platform is infinitely better than commsec they only charge contract They even email you a few days before your options are due to expire Can even trade them with ease on the mobile app',
#   'positive': 1,
#   'negative': -2},
#  {'text': 'Interactive Brokers Love their mobile app Does options as well',
#   'positive': 3,
#   'negative': -2},
#  {'text': 'interactive brokers allows too best mobile app for trading imo',
#   'positive': 2,
#   'negative': -2},
#  {'text': 'Yes I have an account Interactive Brokers is pretty good It has many sophisticated features I like it But its mobile app can use some improvement',
#   'positive': 3,
#   'negative': -2},
#  {'text': 'One of my portfolio companies is on today Meet getcompound Congrats on launching the mobile app ',
#   'positive': 1,
#   'negative': -2},
#  {'text': 'Just discovered an awesome feature Popular Collections on RobinhoodApp desktop was always using the mobile app Can buysellwait based on trends than asking around ',
#   'positive': 2,
#   'negative': -1},
#  {'text': 'Is someone redesigning Fidelitys mobile app Just make it look like Robinhood k thanks',
#   'positive': 1,
#   'negative': -1},
#  {'text': 'I like the interface a bit better yeah but to be fair I havent really used Robinhood at all because my capital is already spread between webull ally and etrade I only opened robinhood acct for the free stonks I love webull desktop platform but the mobile app could be better',
#   'positive': 1,
#   'negative': -3},
#  {'text': 'TDAmeritrade thinkorswim please do something like this to your mobile app It makes it so much easier to see when sections are clearly defined and ',
#   'positive': 2,
#   'negative': -1},
#  {'text': 'Why cant you edit trendlines in the mobile app Come on the app is terrible We dont need to see tips over over again The time frames blow too TDAmeritrade ',
#   'positive': 1,
#   'negative': -4},
#  {'text': 'ugh was hoping it would be the other way as Schwabs mobile app for trading is unusable Really about as bad as you can get',
#   'positive': 2,
#   'negative': -3},
#  {'text': 'Td Ameritrade Think or swim Hands down is the best Margins are a little high but if you are doing micros the margin is only like  Desktop and mobile app are greatJust my opinion',
#   'positive': 3,
#   'negative': -1},
#  {'text': 'TDAmeritrade mobile app glitches constantly refuses to close orders etc Disaster Back to Fidelity',
#   'positive': 1,
#   'negative': -2},
#  {'text': 'I hate td Ameritrade they are overpriced in commissions but I do  of my trading for years mobile on multiple iPads I dont own a computer so I have to pay up for the td mobile iPad functionality which is superior than most mobile apps',
#   'positive': 3,
#   'negative': -4},
#  {'text': 'Why is the mobile app so messed up It sells short when I place a buy order Incorrectly processes the size of the trade too Also can take  seconds and plus to process an order',
#   'positive': 1,
#   'negative': -1},
#  {'text': 'TDAmeritrade your mobile app needs a dark mode please',
#   'positive': 2,
#   'negative': -1},
#  {'text': 'TDAmeritrade thinkorswim mobile app users need you to add a frequently used button on the main screen to make annotations quick instead of having to go in and out a million times to draw three lines in a chart Your mobile platform is growing fast Please improve SPY ',
#   'positive': 2,
#   'negative': -1},
#  {'text': 'Mobile app they switched us to is garbage It crashes  times a day Trader app worked great',
#   'positive': 1,
#   'negative': -1},
#  {'text': 'TDAmeritrade is TD Ameritrade having issue with online account access Cant login to my account from my phone and web site',
#   'positive': 2,
#   'negative': -1},
#  {'text': 'We are proud sponsors of TDAmeritrade Swing by Veo Village Kiosk  for a demo We help advisors work smarter Turnkey asset management platform Privatelabeled advisor and client portals plus mobile app Outsourced middle office and back office ',
#   'positive': 1,
#   'negative': -2},
#  {'text': 'TDAmeritrade I cant log into my mobile app while my phone is connected to WiFi Only app on my phone that has this issue Been going on for at least a year Was hoping switching over to the Think or Swim app would help Doesnt seem to be the case',
#   'positive': 2,
#   'negative': -1},
#  {'text': 'What do you mean by entered trades I tried to place sell order But I was receiving error message I tried Mobile app trader app and even Desktop',
#   'positive': 1,
#   'negative': -1},
#  {'text': 'TDAmeritrade god your mobile app is pure shut Figure it out',
#   'positive': 1,
#   'negative': -3}]

# %%
search(metadata[1][-6],online)
# Out:
# [{'text': 'CharlesSchwab why dont you have dual factor authentication for online account access EFF whitehatsec Bankrate WSJTech WSJ',
#   'positive': 1,
#   'negative': -1},
#  {'text': 'CharlesSchwab Can you please make your mobile app able to change Open Orders and Brackets with detail Both the Charles Schwab and Street Smart app arent able to change orders using brackets or trailing stops pretty much making the app pointless Please Thank You',
#   'positive': 3,
#   'negative': -2},
#  {'text': 'CharlesSchwab WellsFargo and EdwardJones praised for mobile apps by ryanWneal',
#   'positive': 3,
#   'negative': -1},
#  {'text': 'CharlesSchwab and WellsFargo rank highest in a tie in overall customer satisfaction with apps in the latest  US Mobile App Satisfaction Study Congratulations ',
#   'positive': 3,
#   'negative': -1},
#  {'text': 'CharlesSchwab and WellsFargo rank highest in a tie in overall customer satisfaction with apps in the latest  US Mobile App Satisfaction Study Congrats ',
#   'positive': 2,
#   'negative': -1},
#  {'text': 'Congrats to the local SMEs who were awarded with Exporters Awards  today These companies are proof that success in can be achieved through digital platforms Find out more about our Programme via DarellLeiking ',
#   'positive': 3,
#   'negative': -1},
#  {'text': 'interactive brokers allows too best mobile app for trading imo',
#   'positive': 2,
#   'negative': -2},
#  {'text': 'Yes I have an account Interactive Brokers is pretty good It has many sophisticated features I like it But its mobile app can use some improvement',
#   'positive': 3,
#   'negative': -2},
#  {'text': 'Interactive Brokers Love their mobile app Does options as well',
#   'positive': 3,
#   'negative': -2},
#  {'text': 'They said millennials and beyond were only interested in living for today Then along came RobinhoodApp And with a barrage of arrows in the form of zero commission trading and an elegant mobile app that myth was punctured bprafulkumar vladtenev',
#   'positive': 2,
#   'negative': -1},
#  {'text': 'I would like to switch away from robinhood which is the best trading platform to work with esp with a good mobile app tsla cc GerberKawasaki',
#   'positive': 2,
#   'negative': -1},
#  {'text': 'TDAmeritrade hey Im trying to create an account through your mobile app but it says that my identity can not be confirmed Printing the application and mailing it is a lot of work is there an easier way to start trading with you Thanks',
#   'positive': 2,
#   'negative': -1},
#  {'text': 'RT TDAmeritrade Managing your investments can be easier than ever before with our updated mobile app dashboard See how you can customize your everyday investing',
#   'positive': 1,
#   'negative': -1},
#  {'text': 'Of course And the one above is TdAmeritrade I tend to trade off my phone so thats the mobile app for iOS I use both mobile apps The one above is mobile Think or Swim Imo the best mobile apps out there Endless indicators charting ',
#   'positive': 2,
#   'negative': -1}]
